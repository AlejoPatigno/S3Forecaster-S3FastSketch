# %% [markdown]
# # S3-Forecaster and S3-FastSketch on Tourism Monthly
#
# This Kaggle notebook reproduces the complete experimental pipeline used in the M4 notebook for **Tourism Monthly**. It includes data loading, preprocessing, point and uncertainty optimization for both proposed methods, fixed-parameter baselines on CPU, consolidated metrics, ablation studies, shock/non-shock evaluation, data-efficiency analysis, multi-prior robustness, forecast figures, residual diagnostics, and reproducible exports.
#
# Baseline hyperparameters are taken from the corresponding original dataset notebook and are not re-optimized here.

# %% [markdown]
# ## 1. Clone and install the private repository
#
# Create a Kaggle secret named **`GITHUB_TOKEN`** containing a fine-grained GitHub token with read access to `AlejoPatigno/S3Forecaster-S3FastSketch`. The token is never printed, and the authenticated remote URL is removed immediately after cloning.

# %%
from pathlib import Path
import os
import shutil
import subprocess
import sys

REPO_OWNER = "AlejoPatigno"
REPO_NAME = "S3Forecaster-S3FastSketch"
REPO_DIR = Path("/kaggle/working") / REPO_NAME
CLEAN_REPO_URL = f"https://github.com/{REPO_OWNER}/{REPO_NAME}.git"


def _run(command, *, token=None, cwd=None):
    completed = subprocess.run(
        command,
        cwd=cwd,
        text=True,
        capture_output=True,
        env={**os.environ, "GIT_TERMINAL_PROMPT": "0"},
    )
    if completed.returncode != 0:
        stderr = completed.stderr
        stdout = completed.stdout
        if token:
            stderr = stderr.replace(token, "***")
            stdout = stdout.replace(token, "***")
        raise RuntimeError(
            f"Command failed: {' '.join(map(str, command))}\n"
            f"STDOUT:\n{stdout}\nSTDERR:\n{stderr}"
        )
    return completed


try:
    from kaggle_secrets import UserSecretsClient
    github_token = UserSecretsClient().get_secret("GITHUB_TOKEN")
except Exception:
    github_token = None

if REPO_DIR.exists():
    shutil.rmtree(REPO_DIR)

if github_token:
    authenticated_url = (
        f"https://x-access-token:{github_token}@github.com/"
        f"{REPO_OWNER}/{REPO_NAME}.git"
    )
    _run(["git", "clone", "--depth", "1", authenticated_url, str(REPO_DIR)], token=github_token)
else:
    # This succeeds only when the repository is public.
    _run(["git", "clone", "--depth", "1", CLEAN_REPO_URL, str(REPO_DIR)])

# Remove the credential-bearing remote from the local git configuration.
_run(["git", "-C", str(REPO_DIR), "remote", "set-url", "origin", CLEAN_REPO_URL])

required_paths = [
    REPO_DIR / "pyproject.toml",
    REPO_DIR / "s3paper" / "__init__.py",
    REPO_DIR / "s3paper" / "metrics.py",
    REPO_DIR / "s3paper" / "s3_forecaster_experiment.py",
    REPO_DIR / "s3paper" / "s3_fastsketch_experiment.py",
    REPO_DIR / "s3paper" / "baselines.py",
]
missing = [str(path.relative_to(REPO_DIR)) for path in required_paths if not path.exists()]
if missing:
    raise FileNotFoundError(
        "The repository was cloned, but the modular s3paper package is incomplete. "
        f"Missing files: {missing}"
    )

_run([sys.executable, "-m", "pip", "install", "-q", "-e", str(REPO_DIR)])
print(f"Repository installed from: {REPO_DIR}")
# Out:
# Repository installed from: /kaggle/working/S3Forecaster-S3FastSketch

# %%
# Run this cell immediately after cloning the repository

import os
import sys
import subprocess
import importlib
from pathlib import Path

# Locate the cloned repository
possible_paths = [
    Path("/kaggle/working/S3Forecaster-S3FastSketch"),
    Path.cwd() / "S3Forecaster-S3FastSketch",
]

REPO_DIR = next((path.resolve() for path in possible_paths if path.exists()), None)

if REPO_DIR is None:
    raise FileNotFoundError(
        "The repository folder 'S3Forecaster-S3FastSketch' was not found."
    )

print(f"Repository found at: {REPO_DIR}")

# Move into the repository
os.chdir(REPO_DIR)

# Install the repository as an editable Python package
subprocess.check_call(
    [
        sys.executable,
        "-m",
        "pip",
        "install",
        "-e",
        str(REPO_DIR),
    ]
)

# Make the repository immediately visible to the current kernel
repo_path = str(REPO_DIR)
if repo_path not in sys.path:
    sys.path.insert(0, repo_path)

importlib.invalidate_caches()

# Verify that the package exists
package_dir = REPO_DIR / "s3paper"

if not package_dir.exists():
    raise FileNotFoundError(
        f"The folder {package_dir} does not exist. "
        "Check that the repository contains the s3paper package."
    )

# Imports
from s3paper.data import apply_log_if_positive, inverse_transform
from s3paper.metrics import evaluate_forecast, paper_metric_row
from s3paper.residual_analysis import (
    analyze_forecast_residuals,
    plot_residual_diagnostics,
)

print("s3paper imported successfully.")
# Out:
# Repository found at: /kaggle/working/S3Forecaster-S3FastSketch
# Obtaining file:///kaggle/working/S3Forecaster-S3FastSketch
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (2.0.2)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (2.3.3)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.3 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (1.6.1)
# Requirement already satisfied: statsmodels>=0.14 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (0.14.6)
# Requirement already satisfied: optuna>=3.5 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (4.9.0)
# Requirement already satisfied: matplotlib>=3.7 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (2.9.0.post0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (2.0.49)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (6.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->s3forecaster-s3fastsketch==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->s3forecaster-s3fastsketch==0.1.0) (2026.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->s3forecaster-s3fastsketch==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->s3forecaster-s3fastsketch==0.1.0) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14->s3forecaster-s3fastsketch==0.1.0) (1.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (1.3.11)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (3.0.3)
# Building wheels for collected packages: s3forecaster-s3fastsketch
#   Building editable for s3forecaster-s3fastsketch (pyproject.toml): started
#   Building editable for s3forecaster-s3fastsketch (pyproject.toml): finished with status 'done'
#   Created wheel for s3forecaster-s3fastsketch: filename=s3forecaster_s3fastsketch-0.1.0-0.editable-py3-none-any.whl size=3038 sha256=2a9e54db8d3a83540a13294508d0507d30276480145107bf93a372bed31180bc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mkpnn_hr/wheels/19/d3/2c/efbc2252ef060622fd0513936439e580d709ac89ae9bba4cf8
# Successfully built s3forecaster-s3fastsketch
# Installing collected packages: s3forecaster-s3fastsketch
#   Attempting uninstall: s3forecaster-s3fastsketch
#     Found existing installation: s3forecaster-s3fastsketch 0.1.0
#     Uninstalling s3forecaster-s3fastsketch-0.1.0:
#       Successfully uninstalled s3forecaster-s3fastsketch-0.1.0
# Successfully installed s3forecaster-s3fastsketch-0.1.0
# s3paper imported successfully.

# %% [markdown]
# ## 2. Imports, reproducibility, and experiment configuration

# %%
# Force every deep-learning baseline, including ARKAN, to use CPU.
# Run this cell before importing TensorFlow, PyTorch, pykan, or s3paper.
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
os.environ["JAX_PLATFORM_NAME"] = "cpu"
os.environ["OMP_NUM_THREADS"] = "4"
os.environ["MKL_NUM_THREADS"] = "4"
os.environ["OPENBLAS_NUM_THREADS"] = "4"
os.environ["NUMEXPR_NUM_THREADS"] = "4"

import inspect
import json
import math
import subprocess
import sys
import time
import warnings
from dataclasses import asdict
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display

try:
    import tensorflow as tf
    try:
        tf.config.set_visible_devices([], "GPU")
    except RuntimeError:
        pass
except ImportError:
    tf = None

import torch
try:
    torch.set_num_threads(max(1, min(4, os.cpu_count() or 1)))
except RuntimeError:
    pass
try:
    torch.set_num_interop_threads(max(1, min(2, os.cpu_count() or 1)))
except RuntimeError:
    pass
torch.cuda.is_available = lambda: False

from s3paper.data import apply_log_if_positive, inverse_transform
from s3paper.metrics import evaluate_forecast, paper_metric_row
from s3paper.residual_analysis import (
    analyze_forecast_residuals,
    plot_residual_diagnostics,
)
from s3paper.s3_forecaster_experiment import run_s3_experiment
from s3paper.s3_fastsketch_experiment import run_fastsketch_experiment
from s3paper.baselines import build_baseline, fit_predict_baseline
from s3paper.utils import (
    count_trainable_parameters,
    ensure_series,
    parse_forecast_output,
    set_global_seed,
)

warnings.filterwarnings("ignore")
SEED = 42
set_global_seed(SEED)

DATASET_NAME = "Tourism Monthly"
DATASET_SLUG = "tourism"
SERIES_ID = None
SERIES_POSITION = 0
SEASONAL_PERIOD = 12
ALPHA = 0.10
VAL_SIZE = 12
APPLY_LOG_IF_POSITIVE = True
BASELINE_CALIBRATION_RATIO = 0.20
BASELINE_ACI_STEP_SIZE = 0.05
RUN_CHRONOS_BASELINE = True
RUN_CHRONOS_PRIOR = True

RUN_MODE = "paper"
if RUN_MODE == "paper":
    S3_POINT_TRIALS = 300
    S3_UQ_TRIALS = 200
    FASTSKETCH_POINT_TRIALS = 300
    FASTSKETCH_UQ_TRIALS = 200
else:
    S3_POINT_TRIALS = 10
    S3_UQ_TRIALS = 10
    FASTSKETCH_POINT_TRIALS = 10
    FASTSKETCH_UQ_TRIALS = 10

RUN_NEURAL_BASELINES = True
RUN_ARKAN = True

OUTPUT_DIR = Path(
    f"/kaggle/working/{DATASET_SLUG}_s3_results"
)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print({
    "dataset": DATASET_NAME,
    "series_id": SERIES_ID,
    "series_position": SERIES_POSITION,
    "run_mode": RUN_MODE,
    "device": "cpu",
    "s3_trials": (S3_POINT_TRIALS, S3_UQ_TRIALS),
    "fastsketch_trials": (
        FASTSKETCH_POINT_TRIALS,
        FASTSKETCH_UQ_TRIALS,
    ),
    "output_dir": str(OUTPUT_DIR),
})
# Out:
# 2026-07-03 17:40:20.778257: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# {'dataset': 'Tourism Monthly', 'series_id': None, 'series_position': 0, 'run_mode': 'paper', 'device': 'cpu', 's3_trials': (300, 200), 'fastsketch_trials': (300, 200), 'output_dir': '/kaggle/working/tourism_s3_results'}

# %% [markdown]
# ### Optional dependency for ARKAN

# %%
if RUN_ARKAN:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "pykan"],
        check=True,
    )
    print("Optional ARKAN dependency installed.")

if RUN_CHRONOS_BASELINE or RUN_CHRONOS_PRIOR:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "chronos-forecasting>=2.3"],
        check=True,
    )
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.1/78.1 kB 2.1 MB/s eta 0:00:00
# Optional ARKAN dependency installed.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 2.8 MB/s eta 0:00:00

# %% [markdown]
# ## 3. Load the Tourism Monthly series

# %%
from pathlib import Path
import re

DATASET_KEYWORDS = ['tourism-monthly', 'tourism_monthly', 'tourism']
SERIES_FILE_EXTENSIONS = ['.tsf']


def locate_series_file(search_root=Path("/kaggle/input")):
    search_root = Path(search_root)
    candidates = [
        path
        for path in search_root.rglob("*")
        if path.is_file() and path.suffix.lower() in SERIES_FILE_EXTENSIONS
    ]
    if not candidates:
        raise FileNotFoundError(
            f"No {SERIES_FILE_EXTENSIONS} file was found below {search_root}."
        )

    def score(path):
        text = str(path).lower()
        keyword_score = sum(keyword in text for keyword in DATASET_KEYWORDS)
        monthly_score = int("monthly" in text)
        return (-keyword_score, -monthly_score, len(text))

    candidates.sort(key=score)
    selected = candidates[0]
    print("Selected dataset file:", selected)
    return selected


def parse_tsf_date(value):
    value = str(value).strip().replace(" 00-00-00", "")
    parsed = pd.to_datetime(value, errors="coerce")
    if pd.isna(parsed):
        match = re.match(r"(\d{4})-(\d{2})-(\d{2})", value)
        if not match:
            raise ValueError(f"Could not parse date attribute: {value!r}")
        parsed = pd.Timestamp(
            f"{match.group(1)}-{match.group(2)}-{match.group(3)}"
        )
    return pd.Timestamp(parsed)


def parse_tsf_file(path):
    path = Path(path)
    metadata = {
        "frequency": None,
        "horizon": None,
        "missing": None,
        "equallength": None,
        "relation": None,
        "attributes": [],
    }

    lines = None
    used_encoding = None
    for encoding in ("utf-8", "cp1252", "latin-1"):
        try:
            lines = path.read_text(encoding=encoding).splitlines()
            used_encoding = encoding
            break
        except UnicodeDecodeError:
            continue

    if lines is None:
        raise UnicodeError(f"Could not decode {path}.")

    rows = []
    in_data = False

    for raw_line in lines:
        line = raw_line.strip()
        if not line or line.startswith("#"):
            continue

        lower = line.lower()
        if not in_data:
            if lower.startswith("@relation"):
                metadata["relation"] = line.split(maxsplit=1)[1].strip()
            elif lower.startswith("@attribute"):
                parts = line.split()
                if len(parts) >= 3:
                    metadata["attributes"].append(
                        (parts[1].strip(), parts[2].strip().lower())
                    )
            elif lower.startswith("@frequency"):
                metadata["frequency"] = line.split(maxsplit=1)[1].strip().lower()
            elif lower.startswith("@horizon"):
                metadata["horizon"] = int(float(line.split(maxsplit=1)[1].strip()))
            elif lower.startswith("@missing"):
                metadata["missing"] = (
                    line.split(maxsplit=1)[1].strip().lower() == "true"
                )
            elif lower.startswith("@equallength"):
                metadata["equallength"] = (
                    line.split(maxsplit=1)[1].strip().lower() == "true"
                )
            elif lower.startswith("@data"):
                in_data = True
            continue

        n_attributes = len(metadata["attributes"])
        parts = line.split(":", n_attributes)
        if len(parts) != n_attributes + 1:
            raise ValueError(
                f"Invalid TSF row: expected {n_attributes + 1} fields, "
                f"received {len(parts)}. Row={line[:160]!r}"
            )

        row = {}
        for (attribute_name, attribute_type), value in zip(
            metadata["attributes"], parts[:n_attributes]
        ):
            value = value.strip()
            if attribute_type in {
                "numeric", "integer", "int", "real", "float", "double"
            }:
                row[attribute_name] = float(value)
            elif attribute_type == "date":
                row[attribute_name] = parse_tsf_date(value)
            else:
                row[attribute_name] = value

        values = []
        for value in parts[-1].split(","):
            value = value.strip()
            if value in {"", "?"}:
                values.append(np.nan)
            else:
                values.append(float(value))
        row["values"] = np.asarray(values, dtype=float)
        rows.append(row)

    if not rows:
        raise ValueError(f"No time series were parsed from {path}.")

    print("TSF encoding:", used_encoding)
    return metadata, rows


def row_identifier(row, position):
    for key in ("series_name", "series_id", "id"):
        if key in row:
            return str(row[key])
    attribute_names = [name for name, _ in metadata["attributes"]]
    if attribute_names:
        return str(row.get(attribute_names[0], f"series_{position}"))
    return f"series_{position}"


def clean_values(values):
    values = pd.Series(np.asarray(values, dtype=float))
    missing_count = int(values.isna().sum())
    if missing_count:
        values = values.interpolate(limit_direction="both").ffill().bfill()
    if values.isna().any():
        raise ValueError("The selected series still contains missing values.")
    return values.to_numpy(dtype=float), missing_count


series_file = locate_series_file()
metadata, parsed_rows = parse_tsf_file(series_file)

if SERIES_ID is None:
    selected_position = int(SERIES_POSITION)
    if not 0 <= selected_position < len(parsed_rows):
        raise IndexError(
            f"SERIES_POSITION={selected_position} is outside "
            f"the available range 0..{len(parsed_rows)-1}."
        )
    selected_row = parsed_rows[selected_position]
    SERIES_ID = row_identifier(selected_row, selected_position)
else:
    selected_row = None
    for position, candidate in enumerate(parsed_rows):
        if row_identifier(candidate, position) == str(SERIES_ID):
            selected_row = candidate
            break
    if selected_row is None:
        raise KeyError(f"Series {SERIES_ID!r} was not found.")

horizon_value = selected_row.get("horizon", metadata.get("horizon"))
if horizon_value is None:
    raise ValueError(
        "The dataset does not provide a global or per-series forecast horizon."
    )
horizon = int(horizon_value)

full_values, missing_count = clean_values(selected_row["values"])
if horizon <= 0 or horizon >= len(full_values):
    raise ValueError(
        f"Invalid horizon={horizon} for series length={len(full_values)}."
    )

train_values = full_values[:-horizon]
test_values = full_values[-horizon:]

start_timestamp = selected_row.get("start_timestamp", pd.Timestamp("2000-01-01"))
start_timestamp = pd.Timestamp(start_timestamp)

train_index = pd.date_range(
    start=start_timestamp,
    periods=len(train_values),
    freq="MS",
)
test_index = pd.date_range(
    start=train_index[-1] + pd.offsets.MonthBegin(1),
    periods=len(test_values),
    freq="MS",
)

raw_train = pd.Series(train_values, index=train_index, name="y")
raw_test = pd.Series(test_values, index=test_index, name="y")

info_df = pd.DataFrame(
    [{
        "series_id": SERIES_ID,
        "relation": metadata.get("relation"),
        "frequency": metadata.get("frequency"),
        "horizon": horizon,
        "train_length": len(raw_train),
        "test_length": len(raw_test),
        "missing_values_imputed": missing_count,
        "source_file": str(series_file),
    }]
)

print("Selected series:", SERIES_ID)
print("Train length:", len(raw_train))
print("Test horizon:", len(raw_test))
display(info_df)
# Out:
# Selected dataset file: /kaggle/input/datasets/alejopatio/tourism-monthly/tourism_monthly_dataset.tsf
# TSF encoding: cp1252
# Selected series: T1
# Train length: 163
# Test horizon: 24
#   series_id relation frequency  horizon  train_length  test_length  \
# 0        T1  Tourism   monthly       24           163           24
#
#    missing_values_imputed                                        source_file
# 0                       0  /kaggle/input/datasets/alejopatio/tourism-mont...

# %% [markdown]
# ## 4. Preprocessing and visual inspection

# %%
train_series, test_series, transformation = apply_log_if_positive(
    raw_train,
    raw_test,
    enabled=APPLY_LOG_IF_POSITIVE,
)

print("Transformation:", transformation)
print("Train finite:", np.isfinite(train_series).all())
print("Test finite:", np.isfinite(test_series).all())

fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(raw_train.index, raw_train.values, label="Train")
ax.plot(raw_test.index, raw_test.values, label="Test")
ax.set_xlabel("Time")
ax.set_ylabel("Tourism value")
ax.legend()
fig.tight_layout()
plt.show()
# Out:
# Transformation: log
# Train finite: True
# Test finite: True

# %% [markdown]
# ## 5. Fixed Tourism Monthly baseline hyperparameters

# %%
CHRONOS_KWARGS = {
    "model_id": "amazon/chronos-bolt-small",
    "device_map": "cpu",
}

BASELINE_PARAMS_ORIGINAL = {'CNN': {'input_window': 11,
         'filters': 16,
         'kernel_size': 5,
         'dropout': 0.29160286721639495,
         'dense_units': 16,
         'learning_rate': 0.002926758115062129,
         'batch_size': 8,
         'epochs': 77},
 'LSTM': {'n_layers': 1,
          'input_window': 31,
          'units_1': 64,
          'dropout': 0.19405336203617027,
          'dense_units': 128,
          'learning_rate': 0.0015347768911945768,
          'batch_size': 32,
          'epochs': 82},
 'GaussianProcess': {'input_window': 15,
                     'kernel_type': 'matern32',
                     'length_scale': 0.2136812649209043,
                     'constant_value': 3.0538792898465466,
                     'noise_level': 1.0949470893615703e-06,
                     'alpha': 5.614356614858168e-07,
                     'normalize_y': True},
 'KernelRidgeRegressor': {'kernel': 'linear', 'input_window': 41, 'alpha': 3.6095989191635174},
 'AR': {'lags': 27, 'trend': 't', 'seasonal': False},
 'ARIMA': {'p': 6, 'd': 1, 'q': 6, 'trend': 'n'},
 'ARKAN': {'n_hidden_layers': 2,
           'window_size': 12,
           'h1': 164,
           'h2': 109,
           'grid': 4,
           'k': 1,
           'lr': 0.004953682563497158,
           'weight_decay': 3.3206258920079286e-07,
           'batch_size': 128,
           'max_epochs': 218,
           'clip_grad': 3.481350279592919,
           'patience': 29},
 'EasyTSF': {'model_type': 'NLinear',
             'window_size': 19,
             'lr': 0.0010957571403665725,
             'weight_decay': 0.00047336602946782555,
             'batch_size': 16,
             'clip_grad': 3.120539116489036,
             'max_epochs': 230,
             'patience': 15},
 'ETS': {'error': 'add',
         'trend': 'add',
         'seasonal': 'add',
         'seasonal_periods': 12,
         'damped_trend': True}}


def adapt_original_baseline_params(original):
    compatibility_notes = {}

    gaussian_process = dict(original["GaussianProcess"])
    supported_gp_kernels = {"rbf", "matern32", "matern52"}
    if gaussian_process.get("kernel_type") not in supported_gp_kernels:
        reported_kernel = gaussian_process.get("kernel_type")
        gaussian_process["kernel_type"] = "matern52"
        compatibility_notes["GaussianProcess"] = (
            f"The original notebook reports kernel_type={reported_kernel!r}, "
            "which is not supported by the repository and was not part of its "
            "reported search space. It is mapped to 'matern52' so the notebook "
            "is executable; the original value remains preserved in "
            "BASELINE_PARAMS_ORIGINAL."
        )

    arkan_original = original["ARKAN"]
    adapted = {
        "CNN": dict(original["CNN"]),
        "LSTM": dict(original["LSTM"]),
        "GaussianProcess": gaussian_process,
        "KernelRidgeRegressor": dict(original["KernelRidgeRegressor"]),
        "AR": {**original["AR"], "period": SEASONAL_PERIOD},
        "ARIMA": dict(original["ARIMA"]),
        "ARKAN": {
            "n_hidden_layers": arkan_original["n_hidden_layers"],
            "window_size": arkan_original["window_size"],
            "h1": arkan_original["h1"],
            "h2": arkan_original.get("h2", 4),
            "grid": arkan_original["grid"],
            "k": arkan_original["k"],
            "learning_rate": arkan_original["lr"],
            "weight_decay": arkan_original["weight_decay"],
            "batch_size": arkan_original["batch_size"],
            "epochs": arkan_original["max_epochs"],
            "clip_grad": arkan_original["clip_grad"],
            "patience": arkan_original["patience"],
        },
        "NLinear": {
            "window_size": original["EasyTSF"]["window_size"],
            "learning_rate": original["EasyTSF"]["lr"],
            "weight_decay": original["EasyTSF"]["weight_decay"],
            "batch_size": original["EasyTSF"]["batch_size"],
            "clip_grad": original["EasyTSF"]["clip_grad"],
            "epochs": original["EasyTSF"]["max_epochs"],
            "patience": original["EasyTSF"]["patience"],
        },
        "ETS": dict(original["ETS"]),
        
    }
    return adapted, compatibility_notes


BASELINE_PARAMS, BASELINE_COMPATIBILITY_NOTES = adapt_original_baseline_params(
    BASELINE_PARAMS_ORIGINAL
)
OMITTED_TRAINING_OPTIONS = {}

BASELINE_DISPLAY_NAMES = {
    "NLinear": "EasyTSF (NLinear)",
    "KernelRidgeRegressor": "Kernel Ridge",
    "GaussianProcess": "Gaussian Process",
}

BASELINE_ORDER = [
    "CNN",
    "LSTM",
    "GaussianProcess",
    "KernelRidgeRegressor",
    "AR",
    "ARIMA",
    "ARKAN",
    "NLinear",
    "ETS",
]

BASELINE_DISPLAY_NAMES["Chronos"] = "Chronos"

if RUN_CHRONOS_BASELINE:
    BASELINE_PARAMS["Chronos"] = dict(CHRONOS_KWARGS)
    if "Chronos" not in BASELINE_ORDER:
        BASELINE_ORDER.append("Chronos")

if not RUN_NEURAL_BASELINES:
    BASELINE_ORDER = [
        name
        for name in BASELINE_ORDER
        if name not in {"CNN", "LSTM", "NLinear"}
    ]
if not RUN_ARKAN:
    BASELINE_ORDER = [
        name
        for name in BASELINE_ORDER
        if name != "ARKAN"
    ]

print("Baselines to evaluate:", BASELINE_ORDER)
print("Original options not consumed by the repository classes:")
display(pd.DataFrame(OMITTED_TRAINING_OPTIONS).T)

if BASELINE_COMPATIBILITY_NOTES:
    print("Compatibility notes:")
    for model_name, note in BASELINE_COMPATIBILITY_NOTES.items():
        print(f"- {model_name}: {note}")
# Out:
# Baselines to evaluate: ['CNN', 'LSTM', 'GaussianProcess', 'KernelRidgeRegressor', 'AR', 'ARIMA', 'ARKAN', 'NLinear', 'ETS', 'Chronos']
# Original options not consumed by the repository classes:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 6. S3-Forecaster optimization and final test

# %%
s3_result = run_s3_experiment(
    train_series,
    test_series,
    point_trials=S3_POINT_TRIALS,
    uq_trials=S3_UQ_TRIALS,
    val_size=VAL_SIZE,
    seed=SEED,
)

print("S3-Forecaster best point parameters:")
print(s3_result["best_point_params"])
print("S3-Forecaster best UQ parameters:")
print(s3_result["best_uq_params"])
print("S3-Forecaster test metrics on modelling scale:")
display(pd.DataFrame([s3_result["metrics"]]))
# Out:
# [I 2026-07-03 17:40:33,660] A new study created in memory with name: no-name-d1c09626-f06f-4562-bdb6-72d2bfd583f8
# [I 2026-07-03 17:40:33,857] Trial 0 finished with value: 0.04084428197125157 and parameters: {'reservoir_size': 75, 'spectral_radius': 1.4507143064099162, 'ar_lags': 10, 'foundation_window': 16, 'regressor_type': 'Ridge', 'reg_alpha': 21.76624112345367, 'aci_step_size': 0.12421185223120967, 'oob_split_ratio': 0.7770181444490114}. Best is trial 0 with value: 0.04084428197125157.
# [I 2026-07-03 17:40:33,930] Trial 1 finished with value: 0.030863019640679324 and parameters: {'reservoir_size': 5, 'spectral_radius': 1.4699098521619942, 'ar_lags': 11, 'foundation_window': 7, 'regressor_type': 'Lasso', 'reg_alpha': 2.6079656598095835, 'aci_step_size': 0.092069553542002, 'oob_split_ratio': 0.6728072850495105}. Best is trial 1 with value: 0.030863019640679324.
# [I 2026-07-03 17:40:34,019] Trial 2 finished with value: 0.0184720029954737 and parameters: {'reservoir_size': 123, 'spectral_radius': 0.6394938606520418, 'ar_lags': 5, 'foundation_window': 11, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.442886696734996, 'aci_step_size': 0.12255876808378806, 'oob_split_ratio': 0.6116126031799994}. Best is trial 2 with value: 0.0184720029954737.
# [I 2026-07-03 17:40:34,127] Trial 3 finished with value: 0.06146493575354508 and parameters: {'reservoir_size': 122, 'spectral_radius': 0.6705241236872915, 'ar_lags': 2, 'foundation_window': 23, 'regressor_type': 'Ridge', 'reg_alpha': 0.18349072049055454, 'aci_step_size': 0.14000427503730983, 'oob_split_ratio': 0.7100381234349002}. Best is trial 2 with value: 0.0184720029954737.
# [I 2026-07-03 17:40:34,198] Trial 4 finished with value: 0.011055285658054149 and parameters: {'reservoir_size': 25, 'spectral_radius': 0.9951769101112702, 'ar_lags': 2, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.533074654001447, 'aci_step_size': 0.11387495307522313, 'oob_split_ratio': 0.6462136138813818}. Best is trial 4 with value: 0.011055285658054149.
# [I 2026-07-03 17:40:34,362] Trial 5 finished with value: 0.03597470918497814 and parameters: {'reservoir_size': 194, 'spectral_radius': 1.2751328233611146, 'ar_lags': 12, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.3380273704712439, 'aci_step_size': 0.018593184893002233, 'oob_split_ratio': 0.6813325826908161}. Best is trial 4 with value: 0.011055285658054149.
# [I 2026-07-03 17:40:34,436] Trial 6 finished with value: 0.025143478188599067 and parameters: {'reservoir_size': 78, 'spectral_radius': 0.7713490317738959, 'ar_lags': 11, 'foundation_window': 10, 'regressor_type': 'ElasticNet', 'reg_alpha': 14.625327121207683, 'aci_step_size': 0.024164622299156457, 'oob_split_ratio': 0.8467217341501293}. Best is trial 4 with value: 0.011055285658054149.
# [I 2026-07-03 17:40:34,610] Trial 7 finished with value: 0.030154113884069352 and parameters: {'reservoir_size': 155, 'spectral_radius': 0.6987156815341724, 'ar_lags': 2, 'foundation_window': 20, 'regressor_type': 'Lasso', 'reg_alpha': 0
. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:36,192] Trial 19 finished with value: 0.04925381845186579 and parameters: {'reservoir_size': 146, 'spectral_radius': 0.8324490859335177, 'ar_lags': 6, 'foundation_window': 13, 'regressor_type': 'Ridge', 'reg_alpha': 19.561885869354157, 'aci_step_size': 0.1398850684557224, 'oob_split_ratio': 0.826064117013573}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:36,340] Trial 20 finished with value: 0.013593917134179323 and parameters: {'reservoir_size': 117, 'spectral_radius': 1.0995362851153523, 'ar_lags': 8, 'foundation_window': 18, 'regressor_type': 'ElasticNet', 'reg_alpha': 46.478592094622805, 'aci_step_size': 0.09480118160550688, 'oob_split_ratio': 0.6820718454289916}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:36,505] Trial 21 finished with value: 0.007972076260952856 and parameters: {'reservoir_size': 94, 'spectral_radius': 0.8922554958727626, 'ar_lags': 4, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 9.196048413850825, 'aci_step_size': 0.14825119457320246, 'oob_split_ratio': 0.7498683930369459}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:36,606] Trial 22 finished with value: 0.007971290538447036 and parameters: {'reservoir_size': 97, 'spectral_radius': 0.7534851236496152, 'ar_lags': 5, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 25.25254223581972, 'aci_step_size': 0.17608881176000263, 'oob_split_ratio': 0.7525720700980351}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:36,739] Trial 23 finished with value: 0.013411272512242669 and parameters: {'reservoir_size': 137, 'spectral_radius': 0.7472786673568734, 'ar_lags': 6, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 22.51045105715679, 'aci_step_size': 0.17875712750027703, 'oob_split_ratio': 0.704273782737364}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:36,835] Trial 24 finished with value: 0.014662401654753928 and parameters: {'reservoir_size': 100, 'spectral_radius': 0.5958209364737007, 'ar_lags': 5, 'foundation_window': 19, 'regressor_type': 'ElasticNet', 'reg_alpha': 28.47758081762629, 'aci_step_size': 0.17901571969856006, 'oob_split_ratio': 0.762350000849809}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:37,002] Trial 25 finished with value: 0.013401793899034809 and parameters: {'reservoir_size': 169, 'spectral_radius': 0.8203878144648425, 'ar_lags': 3, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 13.301040636702474, 'aci_step_size': 0.134739661926019, 'oob_split_ratio': 0.7308423506959746}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:37,194] Trial 26 finished with value: 0.007973194503979394 and parameters: {'reservoir_size': 132, 'spectral_radius': 1.0461359525594478, 'ar_lags': 6, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 30.929438802253927, 'aci_step_size': 0.11013944234130954, 'oob_split_ratio': 0.8022788182567643}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:37,294] Trial 27 finished with value: 0.014645607058132962 and parameters: {'reservoir_size': 105, 'spectral_radius': 0.7233752952235806, 'ar_lags': 8, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 13.369526609534283, 'aci_step_size': 0.1724451914528157, 'oob_split_ratio': 0.6970021118359471}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:37,385] Trial 28 finished with value: 0.013407432086320047 and parameters: {'reservoir_size': 86, 'spectral_radius': 0.6104184963575423, 'ar_lags': 3, 'foundation_window': 22, 'regressor_type': 'Lasso', 'reg_alpha': 47.273634111974594, 'aci_step_size': 0.1495964593262574, 'oob_split_ratio': 0.7454668831547583}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:37,494] Trial 29 finished with value: 0.040116074841550976 and parameters: {'reservoir_size': 65, 'spectral_radius': 0.8697030210903287, 'ar_lags': 9, 'foundation_window': 15, 'regressor_type': 'Ridge', 'reg_alpha': 22.185129848815283, 'aci_step_size': 0.1911711678091193, 'oob_split_ratio': 0.7740710287928131}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:37,674] Trial 30 finished with value: 0.05995056685765055 and parameters: {'reservoir_size': 167, 'spectral_radius': 1.374998126458956, 'ar_lags': 6, 'foundation_window': 19, 'regressor_type': 'Ridge', 'reg_alpha': 30.827657695944474, 'aci_step_size': 0.1275513636603137, 'oob_split_ratio': 0.7870638585814898}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:37,771] Trial 31 finished with value: 0.007973298238162285 and parameters: {'reservoir_size': 80, 'spectral_radius': 0.9002477862292751, 'ar_lags': 5, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 5.377562150261681, 'aci_step_size': 0.15273578757567094, 'oob_split_ratio': 0.7605992239526401}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:37,871] Trial 32 finished with value: 0.007972722045056849 and parameters: {'reservoir_size': 66, 'spectral_radius': 0.8131845937809308, 'ar_lags': 3, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 8.618784754096422, 'aci_step_size': 0.16661994046617096, 'oob_split_ratio': 0.7357259792915358}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:37,968] Trial 33 finished with value: 0.01106429727104507 and parameters: {'reservoir_size': 90, 'spectral_radius': 1.05159394725858, 'ar_lags': 4, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 5.205357239405075, 'aci_step_size': 0.18318615142972344, 'oob_split_ratio': 0.7575587201695946}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:38,107] Trial 34 finished with value: 0.014645961465450023 and parameters: {'reservoir_size': 126, 'spectral_radius': 0.9163461283854362, 'ar_lags': 5, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 17.60216982466902, 'aci_step_size': 0.12916632896786778, 'oob_split_ratio': 0.7788227810539102}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:38,205] Trial 35 finished with value: 0.01106719186001213 and parameters: {'reservoir_size': 111, 'spectral_radius': 0.7745213634536056, 'ar_lags': 4, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 30.658419873111736, 'aci_step_size': 0.1451525774671366, 'oob_split_ratio': 0.7212243323138552}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:38,290] Trial 36 finished with value: 0.01340256452629747 and parameters: {'reservoir_size': 50, 'spectral_radius': 0.6555706489105266, 'ar_lags': 5, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 3.7794886287453755, 'aci_step_size': 0.10907926990229427, 'oob_split_ratio': 0.6955877430114975}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:38,438] Trial 37 finished with value: 0.011066446792892233 and parameters: {'reservoir_size': 187, 'spectral_radius': 1.0311134106516995, 'ar_lags': 3, 'foundation_window': 23, 'regressor_type': 'Lasso', 'reg_alpha': 12.238523247748128, 'aci_step_size': 0.12009280783483157, 'oob_split_ratio': 0.6581625540773453}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:38,522] Trial 38 finished with value: 0.050380273748561466 and parameters: {'reservoir_size': 71, 'spectral_radius': 0.7130802702063178, 'ar_lags': 6, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.10167185503295205, 'aci_step_size': 0.16908815493416696, 'oob_split_ratio': 0.7384740902985706}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:38,617] Trial 39 finished with value: 0.007972075343551802 and parameters: {'reservoir_size': 82, 'spectral_radius': 0.8550974246291171, 'ar_lags': 7, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.3598138693705446, 'aci_step_size': 0.15585901949740014, 'oob_split_ratio': 0.7565811811564691}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:38,698] Trial 40 finished with value: 0.05231151907584903 and parameters: {'reservoir_size': 1, 'spectral_radius': 0.7748251656588236, 'ar_lags': 7, 'foundation_window': 23, 'regressor_type': 'Ridge', 'reg_alpha': 1.0492291066285209, 'aci_step_size': 0.10014788200088423, 'oob_split_ratio': 0.8064997573982277}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:38,792] Trial 41 finished with value: 0.007971290538447036 and parameters: {'reservoir_size': 80, 'spectral_radius': 0.8653887033022156, 'ar_lags': 5, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.1519780533268413, 'aci_step_size': 0.15950324425998436, 'oob_split_ratio': 0.7531651862305402}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:38,895] Trial 42 finished with value: 0.0283848750521266 and parameters: {'reservoir_size': 104, 'spectral_radius': 0.8659772285820894, 'ar_lags': 6, 'foundation_window': 8, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.6516784813635854, 'aci_step_size': 0.13525686234998285, 'oob_split_ratio': 0.7679655440735025}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:39
 'foundation_window': 23, 'regressor_type': 'Ridge', 'reg_alpha': 0.9227369246092134, 'aci_step_size': 0.17657144718847922, 'oob_split_ratio': 0.764858420079795}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:40,703] Trial 57 finished with value: 0.007974682932279906 and parameters: {'reservoir_size': 141, 'spectral_radius': 0.7468069827306086, 'ar_lags': 10, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 16.806118245550145, 'aci_step_size': 0.1368002559051072, 'oob_split_ratio': 0.7230877316127325}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:40,815] Trial 58 finished with value: 0.020095829389718444 and parameters: {'reservoir_size': 98, 'spectral_radius': 0.9271872388581585, 'ar_lags': 6, 'foundation_window': 20, 'regressor_type': 'Lasso', 'reg_alpha': 0.2610831409139577, 'aci_step_size': 0.16541564199432912, 'oob_split_ratio': 0.7484443624810089}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:40,922] Trial 59 finished with value: 0.011064623264694234 and parameters: {'reservoir_size': 13, 'spectral_radius': 0.9913981652736719, 'ar_lags': 11, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 37.723329414923704, 'aci_step_size': 0.15579625400382352, 'oob_split_ratio': 0.7424481981158837}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:41,009] Trial 60 finished with value: 0.014614941854468192 and parameters: {'reservoir_size': 44, 'spectral_radius': 1.224676320957731, 'ar_lags': 8, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 24.288276434545534, 'aci_step_size': 0.14308386742867613, 'oob_split_ratio': 0.7916781862598059}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:41,092] Trial 61 finished with value: 0.007972075343551802 and parameters: {'reservoir_size': 83, 'spectral_radius': 0.8707835866768684, 'ar_lags': 7, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.2384568862110465, 'aci_step_size': 0.16088599402938558, 'oob_split_ratio': 0.7569731454576171}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:41,196] Trial 62 finished with value: 0.00797530910740536 and parameters: {'reservoir_size': 91, 'spectral_radius': 0.8481265658049474, 'ar_lags': 5, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.8237928886353115, 'aci_step_size': 0.18319745303605015, 'oob_split_ratio': 0.6090905526038778}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:41,276] Trial 63 finished with value: 0.01106439149059847 and parameters: {'reservoir_size': 81, 'spectral_radius': 0.8036639251637653, 'ar_lags': 7, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.7783903495270998, 'aci_step_size': 0.15014991318357707, 'oob_split_ratio': 0.7542927437661755}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:41,412] Trial 64 finished with value: 0.015211465005865073 and parameters: {'reservoir_size': 108, 'spectral_radius': 0.8904100361183823, 'ar_lags': 6, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.6129762533072518, 'aci_step_size': 0.15734657681630973, 'oob_split_ratio': 0.7301927314787073}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:41,503] Trial 65 finished with value: 0.007972360275768335 and parameters: {'reservoir_size': 60, 'spectral_radius': 0.7859491610616783, 'ar_lags': 9, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.6529580333541163, 'aci_step_size': 0.19149969399978595, 'oob_split_ratio': 0.7721126062268269}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:41,600] Trial 66 finished with value: 0.011064785952975463 and parameters: {'reservoir_size': 76, 'spectral_radius': 0.7356995097419672, 'ar_lags': 7, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 49.80566356602799, 'aci_step_size': 0.17711031835893726, 'oob_split_ratio': 0.763396177458975}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:41,779] Trial 67 finished with value: 0.05960835485752242 and parameters: {'reservoir_size': 101, 'spectral_radius': 0.8921288516569109, 'ar_lags': 5, 'foundation_window': 12, 'regressor_type': 'Ridge', 'reg_alpha': 10.704919333964448, 'aci_step_size': 0.16870819387406816, 'oob_split_ratio': 0.7519662346759776}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:41,870] Trial 68 finished with value: 0.007975026210144688 and parameters: {'reservoir_size': 68, 'spectral_radius': 1.4866651460047122, 'ar_lags': 4, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.43298970903334, 'aci_step_size': 0.13925147590903758, 'oob_split_ratio': 0.7146750519409043}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40
. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:44,901] Trial 96 finished with value: 0.011052109916011764 and parameters: {'reservoir_size': 74, 'spectral_radius': 0.8681932127812295, 'ar_lags': 5, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.7170308761229968, 'aci_step_size': 0.17530586680826704, 'oob_split_ratio': 0.7249970062745272}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:44,999] Trial 97 finished with value: 0.011066345560906873 and parameters: {'reservoir_size': 57, 'spectral_radius': 0.825202976009311, 'ar_lags': 4, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.134908008749051, 'aci_step_size': 0.14069826457445106, 'oob_split_ratio': 0.7736663065614527}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:45,186] Trial 98 finished with value: 0.00818813858171595 and parameters: {'reservoir_size': 104, 'spectral_radius': 0.9671760506150373, 'ar_lags': 9, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.8459604528540092, 'aci_step_size': 0.1600925087292629, 'oob_split_ratio': 0.6332499627344719}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:45,334] Trial 99 finished with value: 0.06009580251394143 and parameters: {'reservoir_size': 97, 'spectral_radius': 0.7561955578170193, 'ar_lags': 7, 'foundation_window': 23, 'regressor_type': 'Ridge', 'reg_alpha': 1.5354503651864895, 'aci_step_size': 0.16704531635113704, 'oob_split_ratio': 0.7673137840745758}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:45,448] Trial 100 finished with value: 0.014643138554515303 and parameters: {'reservoir_size': 80, 'spectral_radius': 0.7885422379432689, 'ar_lags': 10, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 3.907250082020501, 'aci_step_size': 0.15478755881867634, 'oob_split_ratio': 0.7529827361279967}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:45,563] Trial 101 finished with value: 0.007972075343551802 and parameters: {'reservoir_size': 84, 'spectral_radius': 0.842596042200359, 'ar_lags': 7, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.3324872654617141, 'aci_step_size': 0.14733642929772253, 'oob_split_ratio': 0.7578356952153409}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:45,680] Trial 102 finished with value: 0.007972075343551802 and parameters: {'reservoir_size': 89, 'spectral_radius': 0.8484985378039618, 'ar_lags': 7, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.940327653693817, 'aci_step_size': 0.1606749736500775, 'oob_split_ratio': 0.7604857090474665}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:45,786] Trial 103 finished with value: 0.007974534039733605 and parameters: {'reservoir_size': 73, 'spectral_radius': 0.8955571072564359, 'ar_lags': 7, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 26.291685114142414, 'aci_step_size': 0.16432180859284246, 'oob_split_ratio': 0.7447533432974387}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:45,876] Trial 104 finished with value: 0.014476758478317496 and parameters: {'reservoir_size': 65, 'spectral_radius': 0.7296946308740053, 'ar_lags': 6, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.5169998637003702, 'aci_step_size': 0.1706175493765936, 'oob_split_ratio': 0.7351798189058459}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:46,046] Trial 105 finished with value: 0.01106439149059847 and parameters: {'reservoir_size': 135, 'spectral_radius': 0.8190100916156934, 'ar_lags': 7, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.1920041850381393, 'aci_step_size': 0.18093923558544958, 'oob_split_ratio': 0.7495713761168689}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:46,182] Trial 106 finished with value: 0.007974787514788327 and parameters: {'reservoir_size': 95, 'spectral_radius': 0.9218600605266917, 'ar_lags': 5, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.919243181700988, 'aci_step_size': 0.1582524841692398, 'oob_split_ratio': 0.7692688486325325}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:46,344] Trial 107 finished with value: 0.01106497056334102 and parameters: {'reservoir_size': 101, 'spectral_radius': 0.8685721057804658, 'ar_lags': 8, 'foundation_window': 23, 'regressor_type': 'Lasso', 'reg_alpha': 33.25190124032873, 'aci_step_size': 0.1519610060845874, 'oob_split_ratio': 0.776228811002278}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:46,484] Trial 108 finished with value: 0.007973850378754985 and parameters: {'reservoir_size': 86, 'spectral_radius': 0.8379616885007347, 'ar_lags': 4, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.0565949172524445, 'aci_step_size': 0.1772861014034061, 'oob_split_ratio': 0.7572843570030647}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:46,611] Trial 109 finished with value: 0.013403475467902277 and parameters: {'reservoir_size': 114, 'spectral_radius': 0.7990561329336764, 'ar_lags': 6, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 44.2960259922405, 'aci_step_size': 0.1323008294013807, 'oob_split_ratio': 0.6024246673876477}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:46,780] Trial 110 finished with value: 0.014690890334124782 and parameters: {'reservoir_size': 124, 'spectral_radius': 0.9834033631177745, 'ar_lags': 6, 'foundation_window': 20, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.6133498179240935, 'aci_step_size': 0.14426785002508608, 'oob_split_ratio': 0.7635971830045126}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:46,885] Trial 111 finished with value: 0.007972075343551802 and parameters: {'reservoir_size': 83, 'spectral_radius': 0.8966304636836258, 'ar_lags': 7, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.182793592437882, 'aci_step_size': 0.16339746752068182, 'oob_split_ratio': 0.7612718356305502}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:46,989] Trial 112 finished with value: 0.01106439149059847 and parameters: {'reservoir_size': 91, 'spectral_radius': 0.8806765710049278, 'ar_lags': 7, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.3837928388984437, 'aci_step_size': 0.16150317089522928, 'oob_split_ratio': 0.7524518769305857}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:47,091] Trial 113 finished with value: 0.007974534039733605 and parameters: {'reservoir_size': 84, 'spectral_radius': 0.9368242504004062, 'ar_lags': 7, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.8372093109793025, 'aci_step_size': 0.1709486431931625, 'oob_split_ratio': 0.7433247111008989}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:47,171] Trial 114 finished with value: 0.011064653072942764 and parameters: {'reservoir_size': 79, 'spectral_radius': 0.855061012455654, 'ar_lags': 8, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.2062066522081287, 'aci_step_size': 0.15619764693531032, 'oob_split_ratio': 0.7580947102611301}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:47,271] Trial 115 finished with value: 0.007974753649405761 and parameters: {'reservoir_size': 75, 'spectral_radius': 0.880784353334541, 'ar_lags': 6, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.2790293040210183, 'aci_step_size': 0.16659579149160764, 'oob_split_ratio': 0.7821852969267475}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:47,354] Trial 116 finished with value: 0.011064785952975463 and parameters: {'reservoir_size': 89, 'spectral_radius': 0.7694630952670575, 'ar_lags': 7, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.9445705378293736, 'aci_step_size': 0.13813237420735036, 'oob_split_ratio': 0.7680021391107854}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:47,452] Trial 117 finished with value: 0.02876253558730496 and parameters: {'reservoir_size': 67, 'spectral_radius': 0.8226500108871813, 'ar_lags': 8, 'foundation_window': 9, 'regressor_type': 'ElasticNet', 'reg_alpha': 16.27002976724691, 'aci_step_size': 0.04914759223272588, 'oob_split_ratio': 0.7731323084014974}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:47,683] Trial 118 finished with value: 0.009685464202209783 and parameters: {'reservoir_size': 99, 'spectral_radius': 0.9075027046054837, 'ar_lags': 9, 'foundation_window': 15, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.0274195509633854, 'aci_step_size': 0.17473799464420517, 'oob_split_ratio': 0.7492790555572005}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:47,816] Trial 119 finished with value: 0.06767008623018261 and parameters: {'reservoir_size': 83, 'spectral_radius': 0.7895117084000757, 'ar_lags': 5, 'foundation_window': 22, 'regressor_type': 'Ridge', 'reg_alpha': 0.18075029041577262, 'aci_step_size': 0.14755181319817176, 'oob_split_ratio': 0.7413223299637792}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40:48,022] Trial 120 finished with value: 0.007972803490069428 and parameters: {'reservoir_size': 108, 'spectral_radius': 0.848526897420682, 'ar_lags': 6, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.739234210561105, 'aci_step_size': 0.15960470444734223, 'oob_split_ratio': 0.7572378905809458}. Best is trial 14 with value: 0.007971290538447036.
# [I 2026-07-03 17:40
. Best is trial 167 with value: 9.823734728783883.
# [I 2026-07-03 17:41:16,001] Trial 192 finished with value: 9.903010244717263 and parameters: {'target_miscoverage': 0.1460385867212972, 'aci_step_size': 0.044113674369983, 'interval_scale': 0.504126659218827}. Best is trial 167 with value: 9.823734728783883.
# [I 2026-07-03 17:41:16,055] Trial 193 finished with value: 10.757533838141164 and parameters: {'target_miscoverage': 0.13639182144285297, 'aci_step_size': 0.037591782516112116, 'interval_scale': 0.5476273841227731}. Best is trial 167 with value: 9.823734728783883.
# [I 2026-07-03 17:41:16,114] Trial 194 finished with value: 9.83087188842726 and parameters: {'target_miscoverage': 0.14953396382334475, 'aci_step_size': 0.02086396335378944, 'interval_scale': 0.5004543547720582}. Best is trial 167 with value: 9.823734728783883.
# [I 2026-07-03 17:41:16,169] Trial 195 finished with value: 47.07477758851728 and parameters: {'target_miscoverage': 0.14922091886626482, 'aci_step_size': 0.0234760247145414, 'interval_scale': 2.3964077359031166}. Best is trial 167 with value: 9.823734728783883.
# [I 2026-07-03 17:41:16,225] Trial 196 finished with value: 10.38267503195009 and parameters: {'target_miscoverage': 0.16282926823135657, 'aci_step_size': 0.016002006209492818, 'interval_scale': 0.5285446695769932}. Best is trial 167 with value: 9.823734728783883.
# [I 2026-07-03 17:41:16,279] Trial 197 finished with value: 10.927538917994365 and parameters: {'target_miscoverage': 0.15341697702109247, 'aci_step_size': 0.031052501712258738, 'interval_scale': 0.5562817317240335}. Best is trial 167 with value: 9.823734728783883.
# [I 2026-07-03 17:41:16,333] Trial 198 finished with value: 9.857299228679468 and parameters: {'target_miscoverage': 0.14239319059305253, 'aci_step_size': 0.015042393280022971, 'interval_scale': 0.5017996756819784}. Best is trial 167 with value: 9.823734728783883.
# [I 2026-07-03 17:41:16,407] Trial 199 finished with value: 11.532938027045372 and parameters: {'target_miscoverage': 0.1482310025564284, 'aci_step_size': 0.027771644544331477, 'interval_scale': 0.5871004245051232}. Best is trial 167 with value: 9.823734728783883.
# S3-Forecaster best point parameters:
# {'reservoir_size': 28, 'spectral_radius': 1.1705887837833915, 'ar_lags': 6, 'foundation_window': 13, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.567251046404731, 'aci_step_size': 0.18944330583467753, 'oob_split_ratio': 0.7313554635552422}
# S3-Forecaster best UQ parameters:
# {'target_miscoverage': 0.13892342376377637, 'aci_step_size': 0.07562469723274942, 'interval_scale': 0.5000910276308896}
# S3-Forecaster test metrics on modelling scale:
#        mae       mse      rmse        r2  mape_percent      mape  \
# 0  0.06639  0.006765  0.082253  0.963558      0.825873  0.008259
#
#    smape_percent     smape  ecp  coverage_error        iw  mean_width  \
# 0       0.821149  0.008211  1.0             0.1  0.806415    0.806415
#
#         mis  interval_score       msis     scale  elapsed_seconds  \
# 0  0.806415        0.806415  10.151697  0.079436         0.083968
#
#    trainable_params
# 0               842

# %% [markdown]
# ## 7. S3-FastSketch optimization and final test

# %%
fastsketch_result = run_fastsketch_experiment(
    train_series,
    test_series,
    point_trials=FASTSKETCH_POINT_TRIALS,
    uq_trials=FASTSKETCH_UQ_TRIALS,
    val_size=VAL_SIZE,
    seed=SEED,
)

print("S3-FastSketch best point parameters:")
print(fastsketch_result["best_point_params"])
print("S3-FastSketch best UQ parameters:")
print(fastsketch_result["best_uq_params"])
print("S3-FastSketch test metrics on modelling scale:")
display(pd.DataFrame([fastsketch_result["metrics"]]))
# Out:
# [I 2026-07-03 17:41:16,693] A new study created in memory with name: no-name-0226218b-2b94-469d-b298-685b27a8053e
# [I 2026-07-03 17:41:16,974] Trial 0 finished with value: 0.05036071927068044 and parameters: {'foundation_window': 6, 'ar_lags': 6, 'ema_spans': (2, 4), 'conv_scales': (2, 4, 8), 'use_calendar': False, 'ridge_alpha': 0
. Best is trial 21 with value: 0.013062089843873569.
# [I 2026-07-03 17:41:32,009] Trial 62 finished with value: 0.029238670650161877 and parameters: {'foundation_window': 2, 'ar_lags': 3, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.0010313732096816223, 'shrinkage_max': 1.320781502991979, 'oob_split_ratio': 0.7026568621758027}. Best is trial 21 with value: 0.013062089843873569.
# [I 2026-07-03 17:41:32,240] Trial 63 finished with value: 0.017897888574493353 and parameters: {'foundation_window': 3, 'ar_lags': 3, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.0024874393415494295, 'shrinkage_max': 1.0184832286512915, 'oob_split_ratio': 0.7157901393870385}. Best is trial 21 with value: 0.013062089843873569.
# [I 2026-07-03 17:41:32,474] Trial 64 finished with value: 0.01898103064922294 and parameters: {'foundation_window': 2, 'ar_lags': 4, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.004576815567065824, 'shrinkage_max': 1.1968739117467668, 'oob_split_ratio': 0.7354596906108996}. Best is trial 21 with value: 0.013062089843873569.
# [I 2026-07-03 17:41:32,703] Trial 65 finished with value: 0.04071406698866325 and parameters: {'foundation_window': 5, 'ar_lags': 2, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.0017759117852131194, 'shrinkage_max': 1.4153767133614428, 'oob_split_ratio': 0.6903167182778994}. Best is trial 21 with value: 0.013062089843873569.
# [I 2026-07-03 17:41:32,985] Trial 66 finished with value: 0.061673688206855364 and parameters: {'foundation_window': 11, 'ar_lags': 3, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3, 4), 'use_calendar': True, 'ridge_alpha': 0.0036876505858886963, 'shrinkage_max': 1.5449305191164184, 'oob_split_ratio': 0.7113267973854092}. Best is trial 21 with value: 0.013062089843873569.
# [I 2026-07-03 17:41:33,202] Trial 67 finished with value: 0.03316474973840387 and parameters: {'foundation_window': 3, 'ar_lags': 2, 'ema_spans': (3, 6), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.006240558949476957, 'shrinkage_max': 1.6948825179532747, 'oob_split_ratio': 0.7280642048891018}. Best is trial 21 with value: 0.013062089843873569.
# [I 2026-07-03 17:41:33,489] Trial 68 finished with value: 0.0595855640496268 and parameters: {'foundation_window': 4, 'ar_lags': 3, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 4, 8), 'use_calendar': False, 'ridge_alpha': 0.0014317585750712532, 'shrinkage_max': 1.286507788132831, 'oob_split_ratio': 0.6597756982951118}. Best is trial 21 with value: 0.013062089843873569.
# [I 2026-07-03 17:41:33,717] Trial 69 finished with value: 0.03183258348985965 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (2, 4, 8), 'conv_scales': (3, 6), 'use_calendar': True, 'ridge_alpha': 0.0023754580892656175, 'shrinkage_max': 0.8454245068908102, 'oob_split_ratio': 0.6762718326069055}. Best is trial 21 with value: 0.013062089843873569.
# [I 2026-07-03 17:41:33,950] Trial 70 finished with value: 0.012731663504917173 and parameters: {'foundation_window': 3, 'ar_lags': 3, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.018840686385944067, 'shrinkage_max': 0.5137049711139166, 'oob_split_ratio': 0.6953374893868108}. Best is trial 70 with value: 0.012731663504917173.
# [I 2026-07-03 17:41:34,181] Trial 71 finished with value: 0.013497442288166074 and parameters: {'foundation_window': 3, 'ar_lags': 3, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.5131282172563436, 'shrinkage_max': 0.2993819426533265, 'oob_split_ratio': 0.6953344871517871}. Best is trial 70 with value: 0.012731663504917173.
# [I 2026-07-03 17:41:34,421] Trial 72 finished with value: 0.012318797502315943 and parameters: {'foundation_window': 3, 'ar_lags': 3, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.2840414714093079, 'shrinkage_max': 0.38957553697951, 'oob_split_ratio': 0.6917494897705546}. Best is trial 72 with value: 0.012318797502315943.
# [I 2026-07-03 17:41:34,648] Trial 73 finished with value: 0.01040007308244127 and parameters: {'foundation_window': 4, 'ar_lags': 4, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 1.029992196181584, 'shrinkage_max': 0.27122281856976194, 'oob_split_ratio': 0.6936958895393409}. Best is trial 73 with value: 0.01040007308244127.
# [I 2026-07-03 17:41:34,876] Trial 74 finished with value: 0.01007115435177849 and parameters: {'foundation_window': 4, 'ar_lags': 4, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.6426912276173037, 'shrinkage_max': 0.28247204721579483, 'oob_split_ratio': 0.6938247702118112}. Best is trial 74 with value: 0.01007115435177849.
# [I 2026-07-03 17:41:35,113] Trial 75 finished with value: 0.01016323717251334 and parameters: {'foundation_window': 4, 'ar_lags': 4, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.6581032343831383, 'shrinkage_max': 0.25239953946586446, 'oob_split_ratio': 0.6929722566872858}. Best is trial 74 with value: 0.01007115435177849.
# [I 2026-07-03 17:41:35,365] Trial 76 finished with value: 0.014485051921578737 and parameters: {'foundation_window': 5, 'ar_lags': 4, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0
. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:44,480] Trial 114 finished with value: 0.012120043350897135 and parameters: {'foundation_window': 4, 'ar_lags': 5, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3, 4), 'use_calendar': True, 'ridge_alpha': 0.12372928998459432, 'shrinkage_max': 0.2936615670045541, 'oob_split_ratio': 0.6817565743948375}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:44,763] Trial 115 finished with value: 0.012261905793882935 and parameters: {'foundation_window': 4, 'ar_lags': 5, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3, 4), 'use_calendar': True, 'ridge_alpha': 0.11862251040888826, 'shrinkage_max': 0.2984273513390915, 'oob_split_ratio': 0.6799858757038038}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:45,050] Trial 116 finished with value: 0.01599481867305801 and parameters: {'foundation_window': 5, 'ar_lags': 5, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3, 4), 'use_calendar': True, 'ridge_alpha': 2.171537647553573, 'shrinkage_max': 0.3592793813120508, 'oob_split_ratio': 0.6748223298445707}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:45,334] Trial 117 finished with value: 0.013148984539028888 and parameters: {'foundation_window': 4, 'ar_lags': 6, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3, 4), 'use_calendar': True, 'ridge_alpha': 0.044972142367397695, 'shrinkage_max': 0.2545299291491806, 'oob_split_ratio': 0.7001023254093993}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:45,620] Trial 118 finished with value: 0.01621626267653482 and parameters: {'foundation_window': 4, 'ar_lags': 5, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3, 4), 'use_calendar': True, 'ridge_alpha': 0.24310308172145537, 'shrinkage_max': 0.4649865243078452, 'oob_split_ratio': 0.6832228318708217}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:45,905] Trial 119 finished with value: 0.01583181064062591 and parameters: {'foundation_window': 5, 'ar_lags': 5, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 4, 8), 'use_calendar': True, 'ridge_alpha': 1.3242466920959757, 'shrinkage_max': 0.31248035153167264, 'oob_split_ratio': 0.6674021145535206}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:46,199] Trial 120 finished with value: 0.01988460622183428 and parameters: {'foundation_window': 4, 'ar_lags': 5, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3, 4), 'use_calendar': True, 'ridge_alpha': 0.8234597326760906, 'shrinkage_max': 0.4980149443429714, 'oob_split_ratio': 0.6398181642276531}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:46,457] Trial 121 finished with value: 0.012422421740778544 and parameters: {'foundation_window': 4, 'ar_lags': 4, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 3.2946223273053366, 'shrinkage_max': 0.4077118537384081, 'oob_split_ratio': 0.656657910972369}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:46,680] Trial 122 finished with value: 0.018990963973773492 and parameters: {'foundation_window': 4, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.5168268681851493, 'shrinkage_max': 0.36347294067766706, 'oob_split_ratio': 0.6305938610677593}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:46,901] Trial 123 finished with value: 0.011517619025505159 and parameters: {'foundation_window': 4, 'ar_lags': 4, 'ema_spans': (2, 4), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.3743122589472257, 'shrinkage_max': 0.2514148573863041, 'oob_split_ratio': 0.671052874406836}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:47,137] Trial 124 finished with value: 0.012509797388866218 and parameters: {'foundation_window': 3, 'ar_lags': 4, 'ema_spans': (2, 4), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.07724290439529481, 'shrinkage_max': 0.2798717003379027, 'oob_split_ratio': 0.6715716367411235}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:47,361] Trial 125 finished with value: 0.014429212558141703 and parameters: {'foundation_window': 4, 'ar_lags': 4, 'ema_spans': (2, 4), 'conv_scales': (3, 6), 'use_calendar': True, 'ridge_alpha': 0.11793250578388881, 'shrinkage_max': 0.3520527127356598, 'oob_split_ratio': 0.6883063450492753}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:47,584] Trial 126 finished with value: 0.01614382168357421 and parameters: {'foundation_window': 5, 'ar_lags': 5, 'ema_spans': (2, 4), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.168592757992389, 'shrinkage_max': 0.306760158042984, 'oob_split_ratio': 0.6789688574410728}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:47,811] Trial 127 finished with value: 0.01292139505084712 and parameters: {'foundation_window': 3, 'ar_lags': 4, 'ema_spans': (2, 4), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.35121400232238204, 'shrinkage_max': 0.2518749469894544, 'oob_split_ratio': 0.6707134856086105}. Best is trial 88 with value: 0.009965176216112735.
# [I 2026-07-03 17:41:48,041] Trial 128 finished with value: 0.01193974422965186 and parameters: {'foundation_window': 4, 'ar_lags': 5, 'ema_spans': (2, 4, 8), 'conv_scales': (3, 6), 'use_calendar': True, 'ridge_alpha': 0.8087823345192874, 'shrinkage_max': 0.4338786285911549, 'oob_split_ratio': 0.6518687912053461}. Best is trial 88 with value: 0.009965176216112735.
# ...
# [I 2026-07-03 17:43:11,682] Trial 156 finished with value: 7.920763355975481 and parameters: {'aci_target': 0.19079148050663333, 'aci_step_size': 0.006128175944993726, 'interval_scale': 0.82358351780376, 'interval_power': 0.04255038279956597, 'min_width_factor': 0.6103867055849518}. Best is trial 64 with value: 6.722420918001139.
# [I 2026-07-03 17:43
. Best is trial 172 with value: 6.7181030471805645.
# [I 2026-07-03 17:43:20,362] Trial 194 finished with value: 7.716628091868838 and parameters: {'aci_target': 0.18763353628869042, 'aci_step_size': 0.009765075649282189, 'interval_scale': 0.8200280436705615, 'interval_power': 0.026447905804241355, 'min_width_factor': 0.6194425859962824}. Best is trial 172 with value: 6.7181030471805645.
# [I 2026-07-03 17:43:20,586] Trial 195 finished with value: 7.843277005110592 and parameters: {'aci_target': 0.18416542017624127, 'aci_step_size': 0.007289390610234469, 'interval_scale': 0.7792490120817365, 'interval_power': 0.06532448444519039, 'min_width_factor': 0.7190365443630343}. Best is trial 172 with value: 6.7181030471805645.
# [I 2026-07-03 17:43:20,809] Trial 196 finished with value: 7.482048142075411 and parameters: {'aci_target': 0.1967240122105691, 'aci_step_size': 0.006601729393772106, 'interval_scale': 0.8151526541235157, 'interval_power': 0.021588799160817736, 'min_width_factor': 0.5756599574772474}. Best is trial 172 with value: 6.7181030471805645.
# [I 2026-07-03 17:43:21,053] Trial 197 finished with value: 7.744163528141222 and parameters: {'aci_target': 0.19043984536745662, 'aci_step_size': 0.0075507149939271, 'interval_scale': 0.8578200678850089, 'interval_power': 0.0011542189255446785, 'min_width_factor': 0.5437796126993528}. Best is trial 172 with value: 6.7181030471805645.
# [I 2026-07-03 17:43:21,279] Trial 198 finished with value: 7.168453155630408 and parameters: {'aci_target': 0.19968483356988928, 'aci_step_size': 0.008978122228043183, 'interval_scale': 0.7508409694171166, 'interval_power': 0.04462552277189697, 'min_width_factor': 0.6551754548238604}. Best is trial 172 with value: 6.7181030471805645.
# [I 2026-07-03 17:43:21,505] Trial 199 finished with value: 8.094538006142635 and parameters: {'aci_target': 0.18043084383992647, 'aci_step_size': 0.006113076216048298, 'interval_scale': 0.7882062257084211, 'interval_power': 0.07531796869798384, 'min_width_factor': 0.6818244352283918}. Best is trial 172 with value: 6.7181030471805645.
# S3-FastSketch best point parameters:
# {'foundation_window': 4, 'ar_lags': 4, 'ema_spans': (2, 4, 8), 'conv_scales': (3, 6), 'use_calendar': True, 'ridge_alpha': 0.054244387218088816, 'shrinkage_max': 0.3180924468616432, 'oob_split_ratio': 0.6470448025925963}
# S3-FastSketch best UQ parameters:
# {'aci_target': 0.19176000672673, 'aci_step_size': 0.006508211591617808, 'interval_scale': 0.7506496384046828, 'interval_power': 5.675722723025691e-05, 'min_width_factor': 0.6852458737519903}
# S3-FastSketch test metrics on modelling scale:
#         mae       mse      rmse        r2  mape_percent      mape  \
# 0  0.153111  0.034356  0.185354  0.814943      1.890507  0.018905
#
#    smape_percent    smape       ecp  coverage_error        iw  mean_width  \
# 0          1.917  0.01917  0.708333        0.191667  0.463193    0.463193
#
#         mis  interval_score      msis     scale  elapsed_seconds  \
# 0  0.777754        0.777754  9.790895  0.079436         0.410966
#
#    trainable_params
# 0                27

# %% [markdown]
# ## 8. Baselines with fixed parameters and a common ACI wrapper
#
# Each baseline is fitted twice:
#
# 1. on a chronological training core to obtain calibration residuals;
# 2. on the complete training series to produce the final test forecast.
#
# The interval for test step `t` is formed before observing `y_t`. After scoring that step, the ACI state is updated for the next one. Thus, the procedure is sequential and does not use future test observations.

# %%
def finite_sample_conformal_quantile(scores, alpha):
    scores = np.asarray(scores, dtype=float).reshape(-1)
    scores = scores[np.isfinite(scores)]
    if len(scores) == 0:
        raise ValueError("No finite calibration scores were produced.")
    level = min(1.0, math.ceil((len(scores) + 1) * (1.0 - alpha)) / len(scores))
    try:
        return float(np.quantile(scores, level, method="higher"))
    except TypeError:
        return float(np.quantile(scores, level, interpolation="higher"))


def adaptive_conformal_path(y_true, y_pred, calibration_scores, alpha=0.10, step_size=0.05):
    y_true = np.asarray(y_true, dtype=float).reshape(-1)
    y_pred = np.asarray(y_pred, dtype=float).reshape(-1)
    buffer = list(np.asarray(calibration_scores, dtype=float).reshape(-1))
    alpha_t = float(alpha)
    lower, upper, alpha_path = [], [], []

    for observed, predicted in zip(y_true, y_pred):
        q = finite_sample_conformal_quantile(buffer, alpha_t)
        lo = float(predicted - q)
        up = float(predicted + q)
        lower.append(lo)
        upper.append(up)
        alpha_path.append(alpha_t)

        miss = float(observed < lo or observed > up)
        alpha_t = float(np.clip(alpha_t + step_size * (alpha - miss), 0.01, 0.50))
        buffer.append(abs(float(observed - predicted)))

    return np.asarray(lower), np.asarray(upper), np.asarray(alpha_path)


def evaluate_fixed_baseline_with_aci(
    model_name,
    params,
    train,
    test,
    *,
    calibration_ratio=0.20,
    alpha=0.10,
    aci_step_size=0.05,
    seasonal_period=12,
):
    train = ensure_series(train, name="train")
    test = ensure_series(test, name="test")

    split = int(np.floor((1.0 - calibration_ratio) * len(train)))
    split = max(split, seasonal_period + 5)
    split = min(split, len(train) - 2)
    train_core = train.iloc[:split]
    calibration = train.iloc[split:]

    _, calibration_forecast = fit_predict_baseline(
        model_name,
        train_core,
        len(calibration),
        params,
    )
    calibration_output = parse_forecast_output(calibration_forecast)
    if len(calibration_output.pred) != len(calibration):
        raise ValueError(
            f"{model_name} returned {len(calibration_output.pred)} calibration values; "
            f"expected {len(calibration)}."
        )
    calibration_scores = np.abs(calibration.to_numpy() - calibration_output.pred)

    start = time.perf_counter()
    model, test_forecast = fit_predict_baseline(model_name, train, len(test), params)
    elapsed = time.perf_counter() - start
    test_output = parse_forecast_output(test_forecast)

    if test_output.has_interval:
        lower, upper = test_output.lower, test_output.upper
        interval_source = "native"
        alpha_path = np.full(len(test), alpha)
    else:
        lower, upper, alpha_path = adaptive_conformal_path(
            test,
            test_output.pred,
            calibration_scores,
            alpha=alpha,
            step_size=aci_step_size,
        )
        interval_source = "external_aci"

    forecast = pd.DataFrame(
        {
            "pred": test_output.pred,
            "lower": lower,
            "upper": upper,
            "aci_alpha": alpha_path,
        },
        index=test.index,
    )

    metrics = evaluate_forecast(
        test,
        forecast["pred"],
        y_train=train,
        lower=forecast["lower"],
        upper=forecast["upper"],
        alpha=alpha,
        seasonal_period=seasonal_period,
        elapsed_seconds=elapsed,
        trainable_params=count_trainable_parameters(model),
    )

    return {
        "model": model,
        "forecast": forecast,
        "metrics": metrics,
        "interval_source": interval_source,
        "calibration_size": len(calibration),
    }

# %%
baseline_results = {}
baseline_failures = []

for baseline_name in BASELINE_ORDER:
    display_name = BASELINE_DISPLAY_NAMES.get(baseline_name, baseline_name)
    print(f"\nEvaluating {display_name} with fixed original parameters...")
    try:
        result = evaluate_fixed_baseline_with_aci(
            baseline_name,
            BASELINE_PARAMS[baseline_name],
            train_series,
            test_series,
            calibration_ratio=BASELINE_CALIBRATION_RATIO,
            alpha=ALPHA,
            aci_step_size=BASELINE_ACI_STEP_SIZE,
            seasonal_period=SEASONAL_PERIOD,
        )
        baseline_results[display_name] = result
        print(result["metrics"])
    except Exception as exc:
        baseline_failures.append(
            {
                "model": display_name,
                "exception_type": type(exc).__name__,
                "error": str(exc),
            }
        )
        print(f"FAILED: {type(exc).__name__}: {exc}")

if baseline_failures:
    print("\nBaseline failures were retained for audit:")
    display(pd.DataFrame(baseline_failures))
# Out:
# Evaluating CNN with fixed original parameters...
# {'mae': 0.12706242337668952, 'mse': 0.02730554319072488, 'rmse': 0.16524389002539513, 'r2': 0.8529207501764642, 'mape_percent': 1.545368776732164, 'mape': 0.01545368776732164, 'smape_percent': 1.5550285381813898, 'smape': 0.015550285381813897, 'ecp': 0.9166666666666666, 'coverage_error': 0.016666666666666607, 'iw': 0.6913152336086239, 'mean_width': 0.6913152336086239, 'mis': 0.7870685709590188, 'interval_score': 0.7870685709590188, 'msis': 9.908157236844541, 'scale': 0.07943642315568229, 'elapsed_seconds': 11.004459380000071, 'trainable_params': 2192}
#
# Evaluating LSTM with fixed original parameters...
# {'mae': 0.11383043698044508, 'mse': 0.019856250975835123, 'rmse': 0.14091221017298367, 'r2': 0.8930458010875355, 'mape_percent': 1.4096451545563278, 'mape': 0.014096451545563278, 'smape_percent': 1.4240560327272431, 'smape': 0.01424056032727243, 'ecp': 0.875, 'coverage_error': 0.025000000000000022, 'iw': 0.495395641396345, 'mean_width': 0.495395641396345, 'mis': 0.6119290682912157, 'interval_score': 0.6119290682912157, 'msis': 7.703381446215619, 'scale': 0.07943642315568229, 'elapsed_seconds': 11.111264923000022, 'trainable_params': 28312}
#
# Evaluating Gaussian Process with fixed original parameters...
# {'mae': 0.09385978298462516, 'mse': 0.013288781643308522, 'rmse': 0.11527697794142819, 'r2': 0.928420979523656, 'mape_percent': 1.1658499195783425, 'mape': 0.011658499195783425, 'smape_percent': 1.1759243148669114, 'smape': 0.011759243148669114, 'ecp': 1.0, 'coverage_error': 0.09999999999999998, 'iw': 0.8237381418627169, 'mean_width': 0.8237381418627169, 'mis': 0.8237381418627169, 'interval_score': 0.8237381418627169, 'msis': 10.369778863888747, 'scale': 0.07943642315568229, 'elapsed_seconds': 4.159517966000067, 'trainable_params': 3000}
#
# Evaluating Kernel Ridge with fixed original parameters...
# {'mae': 0.12403684670051207, 'mse': 0.021833945580190358, 'rmse': 0.14776314012699635, 'r2': 0.8823930982001809, 'mape_percent': 1.5374986139404405, 'mape': 0.015374986139404405, 'smape_percent': 1.5542084556679825, 'smape': 0.015542084556679825, 'ecp': 0.75, 'coverage_error': 0.15000000000000002, 'iw': 0.34494684313335594, 'mean_width': 0.34494684313335594, 'mis': 0.526351632469114, 'interval_score': 0.526351632469114, 'msis': 6.62607418057522, 'scale': 0.07943642315568229, 'elapsed_seconds': 0.005262888000061139, 'trainable_params': 2376}
#
# Evaluating AR with fixed original parameters...
# {'mae': 0.09413630397163804, 'mse': 0.013186157888614677, 'rmse': 0.11483099707228304, 'r2': 0.928973754641478, 'mape_percent': 1.1698765935654756, 'mape': 0.011698765935654757, 'smape_percent': 1.179916837756164, 'smape': 0.01179916837756164, 'ecp': 0.9166666666666666, 'coverage_error': 0.016666666666666607, 'iw': 0.4345660262789412, 'mean_width': 0.4345660262789412, 'mis': 0.4779611852250665, 'interval_score': 0.4779611852250665, 'msis': 6.016902149387333, 'scale': 0.07943642315568229, 'elapsed_seconds': 0.011823564999986047, 'trainable_params': 28}
#
# Evaluating ARIMA with fixed original parameters...
# {'mae': 0.13399922527078742, 'mse': 0.025123063348671915, 'rmse': 0.15850256574791435, 'r2': 0.8646765133078556, 'mape_percent': 1.69084760818444, 'mape': 0.016908476081844398, 'smape_percent': 1.687632156942549, 'smape': 0.01687632156942549, 'ecp': 0.9583333333333334, 'coverage_error': 0.05833333333333335, 'iw': 0.6655392186650456, 'mean_width': 0.6655392186650456, 'mis': 0.6655437886263735, 'interval_score': 0.6655437886263735, 'msis': 8.378320198556995, 'scale': 0.07943642315568229, 'elapsed_seconds': 1.1696932339999648, 'trainable_params': 13}
#
# Evaluating ARKAN with fixed original parameters...
# {'mae': 0.07225386141115771, 'mse': 0.008980026128773482, 'rmse': 0.09476299978775198, 'r2': 0.9516297662642949, 'mape_percent': 0.8938146666865168, 'mape': 0.008938146666865168, 'smape_percent': 0.8923404185206245, 'smape': 0.008923404185206246, 'ecp': 1.0, 'coverage_error': 0.09999999999999998, 'iw': 0.6233638485436241, 'mean_width': 0.6233638485436241, 'mis': 0.6233638485436241, 'interval_score': 0.6233638485436241, 'msis': 7.84733027721973, 'scale': 0.07943642315568229, 'elapsed_seconds': 2.6219268370000464, 'trainable_params': 219483}
#
# Evaluating EasyTSF (NLinear) with fixed original parameters...
# {'mae': 0.05549372455920273, 'mse': 0.0047178858086938886, 'rmse': 0.06868686780377956, 'r2': 0.9745874637743333, 'mape_percent': 0.6856693329581981, 'mape': 0.006856693329581981, 'smape_percent': 0.6856192739980462, 'smape': 0.006856192739980462, 'ecp': 1.0, 'coverage_error': 0.09999999999999998, 'iw': 0.41640237265853025, 'mean_width': 0.41640237265853025, 'mis': 0.41640237265853025, 'interval_score': 0.41640237265853025, 'msis': 5.241957733198161, 'scale': 0.07943642315568229, 'elapsed_seconds': 1.3918457590000344, 'trainable_params': 20}
#
# Evaluating ETS with fixed original parameters...
# {'mae': 0.07301885684779201, 'mse': 0.00911059097381209, 'rmse': 0.09544941578559865, 'r2': 0.9509264885698182, 'mape_percent': 0.9211752173073363, 'mape': 0.009211752173073363, 'smape_percent': 0.9281898903506329, 'smape': 0.009281898903506329, 'ecp': 0.7916666666666666, 'coverage_error': 0.10833333333333339, 'iw': 0.3013629186741243, 'mean_width': 0.3013629186741243, 'mis': 0.3779238043490314, 'interval_score': 0.3779238043490314, 'msis': 4.757563210120414, 'scale': 0.07943642315568229, 'elapsed_seconds': 0.1375575370000206, 'trainable_params': 18}
#
# Evaluating Chronos with fixed original parameters...
# config.json: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/191M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# {'mae': 0.11003075317801665, 'mse': 0.01591583235655926, 'rmse': 0.12615796588626205, 'r2': 0.9142705689108926, 'mape_percent': 1.390265979527997, 'mape': 0.01390265979527997, 'smape_percent': 1.4028971529827279, 'smape': 0.014028971529827279, 'ecp': 0.9166666666666666, 'coverage_error': 0.016666666666666607, 'iw': 0.4287303452094573, 'mean_width': 0.4287303452094573, 'mis': 0.45116308125594884, 'interval_score': 0.45116308125594884, 'msis': 5.679549296570713, 'scale': 0.07943642315568229, 'elapsed_seconds': 0.8093428070000073, 'trainable_params': 0}

# %% [markdown]
# ## 9. Consolidated results on modelling and original scales

# %%
def forecast_to_frame(forecast, index):
    out = parse_forecast_output(forecast)
    frame = pd.DataFrame({"pred": out.pred}, index=index)
    if out.lower is not None and out.upper is not None:
        frame["lower"] = out.lower
        frame["upper"] = out.upper
    return frame


def inverse_forecast_frame(frame, transformation):
    result = frame.copy()
    for column in ("pred", "lower", "upper"):
        if column in result:
            result[column] = inverse_transform(result[column].to_numpy(), transformation)
    if "lower" in result and "upper" in result:
        lower = np.minimum(result["lower"].to_numpy(), result["upper"].to_numpy())
        upper = np.maximum(result["lower"].to_numpy(), result["upper"].to_numpy())
        result["lower"] = lower
        result["upper"] = upper
    return result


all_results = {
    "S3-Forecaster": s3_result,
    "S3-FastSketch": fastsketch_result,
    **baseline_results,
}

model_scale_rows = []
original_scale_rows = []
original_forecasts = {}

for model_name, result in all_results.items():
    model_metrics = result["metrics"]
    model_scale_rows.append(paper_metric_row(model_name, model_metrics))

    model_frame = forecast_to_frame(result["forecast"], test_series.index)
    original_frame = inverse_forecast_frame(model_frame, transformation)
    original_forecasts[model_name] = original_frame

    original_metrics = evaluate_forecast(
        raw_test,
        original_frame["pred"],
        y_train=raw_train,
        lower=original_frame.get("lower"),
        upper=original_frame.get("upper"),
        alpha=ALPHA,
        seasonal_period=SEASONAL_PERIOD,
        elapsed_seconds=model_metrics.get("elapsed_seconds"),
        trainable_params=model_metrics.get("trainable_params"),
    )
    original_scale_rows.append(paper_metric_row(model_name, original_metrics))

model_scale_results = pd.DataFrame(model_scale_rows).sort_values("MAPE (%)").reset_index(drop=True)
original_scale_results = pd.DataFrame(original_scale_rows).sort_values("MAPE (%)").reset_index(drop=True)

print("Results on modelling scale:")
display(model_scale_results)
print("Results on original Tourism Monthly scale:")
display(original_scale_results)
# Out:
# Results on modelling scale:
#                 Model       MAE       MSE      RMSE       R^2  MAPE (%)  \
# 0   EasyTSF (NLinear)  0.055494  0.004718  0.068687  0.974587  0.685669
# 1       S3-Forecaster  0.066390  0.006765  0.082253  0.963558  0.825873
# 2               ARKAN  0.072254  0.008980  0.094763  0.951630  0.893815
# 3                 ETS  0.073019  0.009111  0.095449  0.950926  0.921175
# 4    Gaussian Process  0.093860  0.013289  0.115277  0.928421  1.165850
# 5                  AR  0.094136  0.013186  0.114831  0.928974  1.169877
# 6             Chronos  0.110031  0.015916  0.126158  0.914271  1.390266
# 7                LSTM  0.113830  0.019856  0.140912  0.893046  1.409645
# 8        Kernel Ridge  0.124037  0.021834  0.147763  0.882393  1.537499
# 9                 CNN  0.127062  0.027306  0.165244  0.852921  1.545369
# 10              ARIMA  0.133999  0.025123  0.158503  0.864677  1.690848
# 5   1585.952646   8.345506
# 6   1420.947748   7.477227
# 7   2021.141503  10.635531
# 8   1595.253213   8.394447
# 9   2818.205508  14.829795
# 10  2361.129820  12.424598
# 11  2403.632768  12.648254

# %% [markdown]
# # 10.IMPORTS AND FINAL FIXED PARAMETERS

# %%
# ============================================================
# CELL 1 — IMPORTS AND FINAL FIXED PARAMETERS
# Run after the core S3, FastSketch and baseline experiments.
# ============================================================

import copy
import gc
import math
import subprocess
import sys
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display

from s3paper.ablation_study import (
    run_fastsketch_ablation,
    run_s3_ablation_study,
)
from s3paper.baselines import fit_predict_baseline
from s3paper.data_efficiency import make_params_feasible
from s3paper.metrics import evaluate_forecast
from s3paper.multi_prior_robustness import (
    ChronosPrior,
    ETSPrior,
    ProphetPrior,
    RollingPrior,
    run_multi_prior_robustness,
)
from s3paper.s3_fastsketch_experiment import evaluate_fastsketch
from s3paper.s3_forecaster_experiment import evaluate_s3_forecaster
from s3paper.shock_analysis import analyze_forecast_shocks
from s3paper.utils import (
    count_trainable_parameters,
    ensure_series,
    parse_forecast_output,
    set_global_seed,
)

SEED = 42
set_global_seed(SEED)

OUTPUT_DIR = Path(
    globals().get(
        "OUTPUT_DIR",
        "/kaggle/working/tourism_s3_results",
    )
)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

required_objects = [
    "train_series",
    "test_series",
    "s3_result",
    "fastsketch_result",
    "BASELINE_PARAMS",
]

missing_objects = [
    name for name in required_objects
    if name not in globals()
]

if missing_objects:
    raise NameError(
        f"Run the core experiment cells first. Missing: {missing_objects}"
    )

# ------------------------------------------------------------
# Add the original batch size and gradient clipping parameters.
# ------------------------------------------------------------
if "BASELINE_PARAMS_ORIGINAL" in globals():
    BASELINE_PARAMS = copy.deepcopy(BASELINE_PARAMS)

    BASELINE_PARAMS["ARKAN"].update(
        {
            "batch_size": int(
                BASELINE_PARAMS_ORIGINAL["ARKAN"]["batch_size"]
            ),
            "clip_grad": float(
                BASELINE_PARAMS_ORIGINAL["ARKAN"]["clip_grad"]
            ),
        }
    )

    BASELINE_PARAMS["NLinear"].update(
        {
            "batch_size": int(
                BASELINE_PARAMS_ORIGINAL["EasyTSF"]["batch_size"]
            ),
            "clip_grad": float(
                BASELINE_PARAMS_ORIGINAL["EasyTSF"]["clip_grad"]
            ),
        }
    )

    OMITTED_TRAINING_OPTIONS = {}

BASELINE_ORDER = list(
    globals().get(
        "BASELINE_ORDER",
        [
            "CNN",
            "LSTM",
            "GaussianProcess",
            "KernelRidgeRegressor",
            "AR",
            "ARIMA",
            "ARKAN",
            "NLinear",
            "ETS",
        ],
    )
)

BASELINE_DISPLAY_NAMES = {
    "CNN": "CNN",
    "LSTM": "LSTM",
    "GaussianProcess": "Gaussian Process",
    "KernelRidgeRegressor": "Kernel Ridge",
    "AR": "AR",
    "ARIMA": "ARIMA",
    "ARKAN": "ARKAN",
    "NLinear": "EasyTSF (NLinear)",
    "ETS": "ETS",
    **globals().get("BASELINE_DISPLAY_NAMES", {}),
}

S3_POINT_PARAMS = copy.deepcopy(
    s3_result["best_point_params"]
)
S3_UQ_PARAMS = copy.deepcopy(
    s3_result["best_uq_params"]
)

FASTSKETCH_POINT_PARAMS = copy.deepcopy(
    fastsketch_result["best_point_params"]
)
FASTSKETCH_UQ_PARAMS = copy.deepcopy(
    fastsketch_result["best_uq_params"]
)

S3_ABLATION_PARAMS = copy.deepcopy(S3_POINT_PARAMS)

if "aci_step_size" in S3_UQ_PARAMS:
    S3_ABLATION_PARAMS["aci_step_size"] = (
        S3_UQ_PARAMS["aci_step_size"]
    )

SEASONAL_PERIOD = int(
    globals().get("SEASONAL_PERIOD", 12)
)
ALPHA = float(
    globals().get("ALPHA", 0.10)
)
BASELINE_CALIBRATION_RATIO = float(
    globals().get("BASELINE_CALIBRATION_RATIO", 0.20)
)
BASELINE_ACI_STEP_SIZE = float(
    globals().get("BASELINE_ACI_STEP_SIZE", 0.05)
)

print("Device: CPU")
print("S3 parameters:", S3_POINT_PARAMS)
print("S3 UQ parameters:", S3_UQ_PARAMS)
print("FastSketch parameters:", FASTSKETCH_POINT_PARAMS)
print("FastSketch UQ parameters:", FASTSKETCH_UQ_PARAMS)
print("Baselines:", BASELINE_ORDER)
# Out:
# Device: CPU
# S3 parameters: {'reservoir_size': 28, 'spectral_radius': 1.1705887837833915, 'ar_lags': 6, 'foundation_window': 13, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.567251046404731, 'aci_step_size': 0.18944330583467753, 'oob_split_ratio': 0.7313554635552422}
# S3 UQ parameters: {'target_miscoverage': 0.13892342376377637, 'aci_step_size': 0.07562469723274942, 'interval_scale': 0.5000910276308896}
# FastSketch parameters: {'foundation_window': 4, 'ar_lags': 4, 'ema_spans': (2, 4, 8), 'conv_scales': (3, 6), 'use_calendar': True, 'ridge_alpha': 0.054244387218088816, 'shrinkage_max': 0.3180924468616432, 'oob_split_ratio': 0.6470448025925963}
# FastSketch UQ parameters: {'aci_target': 0.19176000672673, 'aci_step_size': 0.006508211591617808, 'interval_scale': 0.7506496384046828, 'interval_power': 5.675722723025691e-05, 'min_width_factor': 0.6852458737519903}
# Baselines: ['CNN', 'LSTM', 'GaussianProcess', 'KernelRidgeRegressor', 'AR', 'ARIMA', 'ARKAN', 'NLinear', 'ETS', 'Chronos']

# %% [markdown]
# # 11.ABLATION STUDY

# %%
# ============================================================
# CELL 2 — ABLATION STUDY
# ============================================================

s3_ablation = run_s3_ablation_study(
    train_series=train_series,
    test_series=test_series,
    best_params=S3_ABLATION_PARAMS,
    alpha=ALPHA,
    seasonal_period=SEASONAL_PERIOD,
)

fastsketch_ablation = run_fastsketch_ablation(
    train_series=train_series,
    test_series=test_series,
    point_params=FASTSKETCH_POINT_PARAMS,
    uq_params=FASTSKETCH_UQ_PARAMS,
    series_id=(
        SERIES_ID
        if "SERIES_ID" in globals()
        else "Tourism Monthly-series"
    ),
    seasonal_period=SEASONAL_PERIOD,
    alpha=ALPHA,
    verbose=True,
)

s3_ablation_table = (
    s3_ablation["results"].copy()
)
s3_ablation_table.insert(
    0,
    "model",
    "S3-Forecaster",
)

fastsketch_ablation_table = (
    fastsketch_ablation["results"].copy()
)
fastsketch_ablation_table.insert(
    0,
    "model",
    "S3-FastSketch",
)

print("S3-Forecaster ablation")
display(s3_ablation_table)

print("S3-FastSketch ablation")
display(fastsketch_ablation_table)

s3_ablation_table.to_csv(
    OUTPUT_DIR / "tourism_s3_ablation.csv",
    index=False,
)

fastsketch_ablation_table.to_csv(
    OUTPUT_DIR / "tourism_fastsketch_ablation.csv",
    index=False,
)


def plot_ablation_metric(
    table,
    metric,
    *,
    label_column="variant",
    figsize=(12, 5),
):
    valid = table[
        (table["status"] == "ok")
        & table[metric].notna()
        & np.isfinite(table[metric])
    ].copy()

    fig, ax = plt.subplots(figsize=figsize)

    ax.bar(
        valid[label_column].astype(str),
        valid[metric].astype(float),
    )

    ax.set_xlabel(
        "Ablation variant",
        fontsize=14,
    )
    ax.set_ylabel(
        metric.replace("_", " ").upper(),
        fontsize=14,
    )

    ax.tick_params(
        axis="x",
        rotation=40,
        labelsize=11,
    )
    ax.tick_params(
        axis="y",
        labelsize=12,
    )

    fig.tight_layout()
    plt.show()

    return fig, ax


plot_ablation_metric(
    s3_ablation_table,
    "mape_percent",
)

plot_ablation_metric(
    s3_ablation_table,
    "msis",
)

plot_ablation_metric(
    fastsketch_ablation_table,
    "mape_percent",
)

plot_ablation_metric(
    fastsketch_ablation_table,
    "msis",
)
# Out:
# [OK] Full: MAPE=1.891%, MSIS=9.7909
# [OK] Foundation only: MAPE=1.583%, MSIS=9.3070
# [OK] Without foundation: MAPE=78.218%, MSIS=601.4005
# [OK] Without AR lags: MAPE=1.760%, MSIS=9.8304
# [OK] Without EMA residual: MAPE=1.700%, MSIS=8.4855
# [OK] Without volatility: MAPE=2.061%, MSIS=11.0341
# [OK] Without momentum: MAPE=2.400%, MSIS=13.7325
# [OK] Without causal convolutions: MAPE=2.286%, MSIS=13.2961
# [OK] Without seasonal residual: MAPE=2.194%, MSIS=12.2250
# [OK] Without calendar: MAPE=1.740%, MSIS=6.8355
# [OK] Without multiscale sketch: MAPE=2.022%, MSIS=10.6982
# [OK] Without signed shrinkage: MAPE=4.444%, MSIS=69.8016
# [OK] Static conformal (without ACI): MAPE=1.891%, MSIS=10.1715
# S3-Forecaster ablation
#            model                        variant                mode  \
# 0  S3-Forecaster                      base only           base_only
# 1  S3-Forecaster        base + residual adapter       base_residual
# 2  S3-Forecaster         base + residual + gate  base_residual_gate
# 3  S3-Forecaster               full model + ACI            full_aci
# 4  S3-Forecaster  full model + static conformal         full_static
#
#    gate_value  alpha_final status error       mae       mse      rmse  ...  \
# 0    1.000000     0.100000     ok  None  0.057311  0.004639  0.068113  ...
# 1    1.000000     0.100000     ok  None  0.066789  0.006863  0.082842  ...
# 2    0.971022     0.100000     ok  None  0.066390  0.006765  0.082253  ...
# 3    0.971022     0.251249     ok  None  0.066390  0.006765  0.082253  ...
# 4    0.971022     0.100000     ok  None  0.066390  0.006765  0.082253  ...
#
#    ecp  coverage_error        iw  mean_width       mis  interval_score  \
# 0  NaN             NaN       NaN         NaN       NaN             NaN
# 1  NaN             NaN       NaN         NaN       NaN             NaN
# 2  NaN             NaN       NaN         NaN       NaN             NaN
# 3  1.0             0.1  0.995719    0.995719  0.995719        0.995719
# 4  1.0             0.1  1.403896    1.403896  1.403896        1.403896
#
#         msis     scale  elapsed_seconds  trainable_params
# 0        NaN       NaN         0.010175                 0
# 1        NaN       NaN         0.049570               840
# 2        NaN       NaN         0.064176               840
# 3  12.534791  0.079436         0.082655               840
# 4  17.673205  0.079436         0.077646               840
#
# [5 rows x 25 columns]
# S3-FastSketch ablation
#             model series_id                         variant  n_features  \
# 0   S3-FastSketch        T1                            Full          25
# 1   S3-FastSketch        T1                 Foundation only           0
# 2   S3-FastSketch        T1              Without foundation          25
# 3   S3-FastSketch        T1                 Without AR lags          21
# 4   S3-FastSketch        T1            Without EMA residual          22
# 5   S3-FastSketch        T1              Without volatility          22
# 6   S3-FastSketch        T1                Without momentum          22
# 7   S3-FastSketch        T1     Without causal convolutions          17
# 8   S3-FastSketch        T1       Without seasonal residual          23
# 9   S3-FastSketch        T1                Without calendar          23
# 10  S3-FastSketch        T1       Without multiscale sketch           8
# 11  S3-FastSketch        T1        Without signed shrinkage          25
# 12  S3-FastSketch        T1  Static conformal (without ACI)          25
#
#                     gamma  final_alpha_t status error       mae        mse  \
# 0   (0.3180924468616432,)       0.182302     ok  None  0.153111   0.034356
# 1                  (0.0,)       0.182302     ok  None  0.127791   0.020767
# 2   (0.3180924468616432,)       0.175794     ok  None  6.285420  39.805765
# 3   (0.3180924468616432,)       0.182302     ok  None  0.142757   0.030976
# 4   (0.3180924468616432,)       0.182302     ok  None  0.137814   0.028788
# 5   (0.3180924468616432,)       0.182302     ok  None  0.166869   0.039104
# 6   (0.3180924468616432,)       0.182302     ok  None  0.194135   0.050598
# 7   (0.3180924468616432,)       0.182302     ok  None  0.184731   0.045729
# 8   (0.3180924468616432,)       0.182302     ok  None  0.177468   0.043591
# 9   (0.3180924468616432,)       0.182302     ok  None  0.138988   0.024204
# 10  (0.3180924468616432,)       0.182302     ok  None  0.163433   0.036635
# 11                 (1.0,)       0.169286     ok  None  0.358435   0.205807
# 12  (0.3180924468616432,)       0.191760     ok  None  0.153111   0.034356
#
#     ...  interval_score        msis     scale  elapsed_seconds  \
# 0   ...        0.777754    9.790895  0.079436         0.445922
# 1   ...        0.739316    9.307013  0.079436         0.418452
# 2   ...       47.773107  601.400529  0.079436         0.359975
# 3   ...        0.780892    9.830406  0.079436         0.412465
# 4   ...        0.674058    8.485504  0.079436         0.407602
# 5   ...        0.876506   11.034056  0.079436         0.414538
# 6   ...        1.090858   13.732471  0.079436         0.417526
# 7   ...        1.056198   13.296139  0.079436         0.413365
# 8   ...        0.971111   12.225004  0.079436         0.412987
# 9   ...        0.542986    6.835476  0.079436         0.407127
# 10  ...        0.849823   10.698158  0.079436         0.435164
# 11  ...        5.544792   69.801632  0.079436         0.418967
# 12  ...        0.807989   10.171520  0.079436         0.414088
#
#     trainable_params  delta_mape_percent  delta_rmse  delta_coverage_error  \
# 0                 27            0.000000    0.000000              0.000000
# 1                  0           -0.307081   -0.041246             -0.091667
# 2                 27           76.327065    6.123827              0.708333
# 3                 23           -0.130256   -0.009353             -0.083333
# 4                 24           -0.190517   -0.015683             -0.125000
# 5                 24            0.170618    0.012393              0.041667
# 6                 24            0.508999    0.039586              0.125000
# 7                 19            0.395353    0.028489              0.083333
# 8                 25            0.303495    0.023429              0.041667
# 9                 25           -0.150607   -0.029779             -0.133333
# 10                10            0.131630    0.006049              0.000000
# 11                27            2.553606    0.268305              0.458333
# 12                27            0.000000    0.000000              0.000000
#
#     delta_mean_width  delta_msis
# 0           0.000000    0.000000
# 1           0.276123   -0.483882
# 2           8.196284  591.609634
# 3          -0.030013    0.039511
# 4           0.005187   -1.305391
# 5          -0.008280    1.243161
# 6          -0.001583    3.941576
# 7          -0.032885    3.505244
# 8          -0.009801    2.434109
# 9           0.069197   -2.955419
# 10         -0.025615    0.907263
# 11         -0.249808   60.010737
# 12         -0.015775    0.380625
#
# [13 rows x 31 columns]
# (<Figure size 1200x500 with 1 Axes>,
#  <Axes: xlabel='Ablation variant', ylabel='MSIS'>)

# %% [markdown]
# # 12.SHOCK / NON-SHOCK ANALYSIS

# %%
# ============================================================
# CELL 3 — SHOCK / NON-SHOCK ANALYSIS
# Uses all forecasts produced by the core experiment.
# ============================================================

results_for_shock = {
    "S3-Forecaster": s3_result,
    "S3-FastSketch": fastsketch_result,
    **globals().get("baseline_results", {}),
}

shock_objects = {}
shock_summary_parts = []
shock_failures = []

for model_name, result in results_for_shock.items():
    print(f"Analyzing shocks for {model_name}...")

    try:
        analysis = analyze_forecast_shocks(
            train_series=train_series,
            test_series=test_series,
            forecast=result["forecast"],
            model_name=model_name,
            alpha=ALPHA,
            seasonal_period=SEASONAL_PERIOD,
            threshold_method="iqr",
            iqr_k=1.5,
        )

        shock_objects[model_name] = analysis
        shock_summary_parts.append(
            analysis["summary"]
        )

        safe_name = (
            model_name.lower()
            .replace(" ", "_")
            .replace("(", "")
            .replace(")", "")
            .replace("-", "_")
        )

        analysis["details"].to_csv(
            OUTPUT_DIR
            / f"tourism_shock_details_{safe_name}.csv"
        )

    except Exception as exc:
        shock_failures.append(
            {
                "model": model_name,
                "exception_type": type(exc).__name__,
                "error": str(exc),
            }
        )

shock_summary = (
    pd.concat(
        shock_summary_parts,
        ignore_index=True,
    )
    if shock_summary_parts
    else pd.DataFrame()
)

if not shock_summary.empty:
    shock_summary = (
        shock_summary
        .sort_values(["model", "subset"])
        .reset_index(drop=True)
    )

print("Shock/non-shock results")
display(shock_summary)

if shock_failures:
    print("Shock-analysis failures")
    display(pd.DataFrame(shock_failures))

shock_summary.to_csv(
    OUTPUT_DIR / "tourism_shock_nonshock_summary.csv",
    index=False,
)

pd.DataFrame(shock_failures).to_csv(
    OUTPUT_DIR / "tourism_shock_nonshock_failures.csv",
    index=False,
)


def plot_shock_metric(
    summary,
    metric,
    *,
    figsize=(14, 6),
):
    valid = summary[
        (summary["status"] == "ok")
        & summary[metric].notna()
        & np.isfinite(summary[metric])
    ]

    pivot = valid.pivot_table(
        index="model",
        columns="subset",
        values=metric,
        aggfunc="first",
    )

    preferred_columns = [
        subset
        for subset in (
            "overall",
            "shock",
            "non_shock",
        )
        if subset in pivot.columns
    ]

    pivot = pivot[preferred_columns]

    fig, ax = plt.subplots(figsize=figsize)

    pivot.plot(
        kind="bar",
        ax=ax,
    )

    ax.set_xlabel(
        "Model",
        fontsize=14,
    )
    ax.set_ylabel(
        metric.replace("_", " ").upper(),
        fontsize=14,
    )

    ax.tick_params(
        axis="x",
        rotation=40,
        labelsize=11,
    )
    ax.tick_params(
        axis="y",
        labelsize=12,
    )

    ax.legend(
        title="Subset",
        fontsize=11,
    )

    fig.tight_layout()
    plt.show()

    return pivot, fig, ax


shock_mape_pivot, _, _ = plot_shock_metric(
    shock_summary,
    "mape_percent",
)

shock_rmse_pivot, _, _ = plot_shock_metric(
    shock_summary,
    "rmse",
)

shock_msis_pivot, _, _ = plot_shock_metric(
    shock_summary,
    "msis",
)

shock_mape_pivot.to_csv(
    OUTPUT_DIR / "tourism_shock_mape_pivot.csv"
)

shock_rmse_pivot.to_csv(
    OUTPUT_DIR / "tourism_shock_rmse_pivot.csv"
)

shock_msis_pivot.to_csv(
    OUTPUT_DIR / "tourism_shock_msis_pivot.csv"
)
# Out:
# Analyzing shocks for S3-Forecaster...
# Analyzing shocks for S3-FastSketch...
# Analyzing shocks for CNN...
# Analyzing shocks for LSTM...
# Analyzing shocks for Gaussian Process...
# Analyzing shocks for Kernel Ridge...
# Analyzing shocks for AR...
# Analyzing shocks for ARIMA...
# Analyzing shocks for ARKAN...
# Analyzing shocks for EasyTSF (NLinear)...
# Analyzing shocks for ETS...
# Analyzing shocks for Chronos...
# Shock/non-shock results
#        subset  n_points  fraction status       mae       mse      rmse  \
# 0   non_shock        24       1.0     ok  0.094136  0.013186  0.114831
# 1     overall        24       1.0     ok  0.094136  0.013186  0.114831
# 2       shock         0       0.0  empty       NaN       NaN       NaN
# 3   non_shock        24       1.0     ok  0.133999  0.025123  0.158503
# 4     overall        24       1.0     ok  0.133999  0.025123  0.158503
# 5       shock         0       0.0  empty       NaN       NaN       NaN
# 6   non_shock        24       1.0     ok  0.072254  0.008980  0.094763
# 7     overall        24       1.0     ok  0.072254  0.008980  0.094763
# 8       shock         0       0.0  empty       NaN       NaN       NaN
# 9   non_shock        24       1.0     ok  0.127062  0.027306  0.165244
# 10    overall        24       1.0     ok  0.127062  0.027306  0.165244
# 11      shock         0       0.0  empty       NaN       NaN       NaN
# 12  non_shock        24       1.0     ok  0.110031  0.015916  0.126158
# 13    overall        24       1.0     ok  0.110031  0.015916  0.126158
# 14      shock         0       0.0  empty       NaN       NaN       NaN
# 15  non_shock        24       1.0     ok  0.073019  0.009111  0.095449
# 16    overall        24       1.0     ok  0.073019  0.009111  0.095449
# 17      shock         0       0.0  empty       NaN       NaN       NaN
# 18  non_shock        24       1.0     ok  0.055494  0.004718  0.068687
# 19    overall        24       1.0     ok  0.055494  0.004718  0.068687
# 20      shock         0       0.0  empty       NaN       NaN       NaN
# 21  non_shock        24       1.0     ok  0.093860  0.013289  0.115277
# 22    overall        24       1.0     ok  0.093860  0.013289  0.115277
# 23      shock         0       0.0  empty       NaN       NaN       NaN
# 24  non_shock        24       1.0     ok  0.124037  0.021834  0.147763
# 25    overall        24       1.0     ok  0.124037  0.021834  0.147763
# 26      shock         0       0.0  empty       NaN       NaN       NaN
# 27  non_shock        24       1.0     ok  0.113830  0.019856  0.140912
# 28    overall        24       1.0     ok  0.113830  0.019856  0.140912
# 29      shock         0       0.0  empty       NaN       NaN       NaN
# 30  non_shock        24       1.0     ok  0.153111  0.034356  0.185354
# 31    overall        24       1.0     ok  0.153111  0.034356  0.185354
# 32      shock         0       0.0  empty       NaN       NaN       NaN
# 33  non_shock        24       1.0     ok  0.066390  0.006765  0.082253
# 34    overall        24       1.0     ok  0.066390  0.006765  0.082253
# 35      shock         0       0.0  empty       NaN       NaN       NaN
#
#           r2  mape_percent      mape  ...  mean_width       mis  \
# 0   0.928974      1.169877  0.011699  ...    0.434566  0.477961
# 1   0.928974      1.169877  0.011699  ...    0.434566  0.477961
# 2        NaN           NaN       NaN  ...         NaN       NaN
# 3   0.864677      1.690848  0.016908  ...    0.665539  0.665544
# 4   0.864677      1.690848  0.016908  ...    0.665539  0.665544
# 5        NaN           NaN       NaN  ...         NaN       NaN
# 6   0.951630      0.893815  0.008938  ...    0.623364  0.623364
# 7   0.951630      0.893815  0.008938  ...    0.623364  0.623364
# 8        NaN           NaN       NaN  ...         NaN       NaN
# 9   0.852921      1.545369  0.015454  ...    0.691315  0.787069
# 10  0.852921      1.545369  0.015454  ...    0.691315  0.787069
# 11       NaN           NaN       NaN  ...         NaN       NaN
# 12  0.914271      1.390266  0.013903  ...    0.428730  0.451163
# 13  0.914271      1.390266  0.013903  ...    0.428730  0.451163
# 14       NaN           NaN       NaN  ...         NaN       NaN
# 15  0.950926      0.921175  0.009212  ...    0.301363  0.377924
# 16  0.950926      0.921175  0.009212  ...    0.301363  0.377924
# 17       NaN           NaN       NaN  ...         NaN       NaN
# 18  0.974587      0.685669  0.006857  ...    0.416402  0.416402
# 19  0.974587      0.685669  0.006857  ...    0.416402  0.416402
# 20       NaN           NaN       NaN  ...         NaN       NaN
# 21  0.928421      1.165850  0.011658  ...    0.823738  0.823738
# 22  0.928421      1.165850  0.011658  ...    0.823738  0.823738
# 23       NaN           NaN       NaN  ...         NaN       NaN
# 24  0.882393      1.537499  0.015375  ...    0.344947  0.526352
# 25  0.882393      1.537499  0.015375  ...    0.344947  0.526352
# 26       NaN           NaN       NaN  ...         NaN       NaN
# 27  0.893046      1.409645  0.014096  ...    0.495396  0.611929
# 28  0.893046      1.409645  0.014096  ...    0.495396  0.611929
# 29       NaN           NaN       NaN  ...         NaN       NaN
# 30  0.814943      1.890507  0.018905  ...    0.463193  0.777754
# 31  0.814943      1.890507  0.018905  ...    0.463193  0.777754
# 32       NaN           NaN       NaN  ...         NaN       NaN
# 33  0.963558      0.825873  0.008259  ...    0.806415  0.806415
# 34  0.963558      0.825873  0.008259  ...    0.806415  0.806415
# 35       NaN           NaN       NaN  ...         NaN       NaN
#
#     interval_score       msis     scale  elapsed_seconds  trainable_params  \
# 0         0.477961   6.016902  0.079436              NaN               NaN
# 1         0.477961   6.016902  0.079436              NaN               NaN
# 2              NaN        NaN       NaN              NaN               NaN
# 3         0.665544   8.378320  0.079436              NaN               NaN
# 4         0.665544   8.378320  0.079436              NaN               NaN
# 5              NaN        NaN       NaN              NaN               NaN
# 6         0.623364   7.847330  0.079436              NaN               NaN
# 7         0.623364   7.847330  0.079436              NaN               NaN
# 8              NaN        NaN       NaN              NaN               NaN
# 9         0.787069   9.908157  0.079436              NaN               NaN
# 10        0.787069   9.908157  0.079436              NaN               NaN
# 11             NaN        NaN       NaN              NaN               NaN
# 12        0.451163   5.679549  0.079436              NaN               NaN
# 13        0.451163   5.679549  0.079436              NaN               NaN
# 14             NaN        NaN       NaN              NaN               NaN
# 15        0.377924   4.757563  0.079436              NaN               NaN
# 16        0.377924   4.757563  0.079436              NaN               NaN
# 17             NaN        NaN       NaN              NaN               NaN
# 18        0.416402   5.241958  0.079436              NaN               NaN
# 19        0.416402   5.241958  0.079436              NaN               NaN
# 20             NaN        NaN       NaN              NaN               NaN
# 21        0.823738  10.369779  0.079436              NaN               NaN
# 22        0.823738  10.369779  0.079436              NaN               NaN
# 23             NaN        NaN       NaN              NaN               NaN
# 24        0.526352   6.626074  0.079436              NaN               NaN
# 25        0.526352   6.626074  0.079436              NaN               NaN
# 26             NaN        NaN       NaN              NaN               NaN
# 27        0.611929   7.703381  0.079436              NaN               NaN
# 28        0.611929   7.703381  0.079436              NaN               NaN
# 29             NaN        NaN       NaN              NaN               NaN
# 30        0.777754   9.790895  0.079436              NaN               NaN
# 31        0.777754   9.790895  0.079436              NaN               NaN
# 32             NaN        NaN       NaN              NaN               NaN
# 33        0.806415  10.151697  0.079436              NaN               NaN
# 34        0.806415  10.151697  0.079436              NaN               NaN
# 35             NaN        NaN       NaN              NaN               NaN
#
#                 model  threshold  threshold_method
# 0                  AR   0.239842               iqr
# 1                  AR   0.239842               iqr
# 2                  AR   0.239842               iqr
# 3               ARIMA   0.239842               iqr
# 4               ARIMA   0.239842               iqr
# 5               ARIMA   0.239842               iqr
# 6               ARKAN   0.239842               iqr
# 7               ARKAN   0.239842               iqr
# 8               ARKAN   0.239842               iqr
# 9                 CNN   0.239842               iqr
# 10                CNN   0.239842               iqr
# 11                CNN   0.239842               iqr
# 12            Chronos   0.239842               iqr
# 13            Chronos   0.239842               iqr
# 14            Chronos   0.239842               iqr
# 15                ETS   0.239842               iqr
# 16                ETS   0.239842               iqr
# 17                ETS   0.239842               iqr
# 18  EasyTSF (NLinear)   0.239842               iqr
# 19  EasyTSF (NLinear)   0.239842               iqr
# 20  EasyTSF (NLinear)   0.239842               iqr
# 21   Gaussian Process   0.239842               iqr
# 22   Gaussian Process   0.239842               iqr
# 23   Gaussian Process   0.239842               iqr
# 24       Kernel Ridge   0.239842               iqr
# 25       Kernel Ridge   0.239842               iqr
# 26       Kernel Ridge   0.239842               iqr
# 27               LSTM   0.239842               iqr
# 28               LSTM   0.239842               iqr
# 29               LSTM   0.239842               iqr
# 30      S3-FastSketch   0.239842               iqr
# 31      S3-FastSketch   0.239842               iqr
# 32      S3-FastSketch   0.239842               iqr
# 33      S3-Forecaster   0.239842               iqr
# 34      S3-Forecaster   0.239842               iqr
# 35      S3-Forecaster   0.239842               iqr
#
# [36 rows x 25 columns]

# %% [markdown]
# # 13.DATA-EFFICIENCY ANALYSIS

# %%
# ============================================================
# CELL 4 — COMMON ACI FOR DATA-EFFICIENCY BASELINES
# ============================================================

def finite_sample_conformal_quantile(
    scores,
    alpha,
):
    scores = np.asarray(
        scores,
        dtype=float,
    ).reshape(-1)

    scores = scores[
        np.isfinite(scores)
    ]

    if len(scores) == 0:
        raise ValueError(
            "No finite calibration scores were produced."
        )

    level = min(
        1.0,
        math.ceil(
            (len(scores) + 1)
            * (1.0 - alpha)
        )
        / len(scores),
    )

    try:
        return float(
            np.quantile(
                scores,
                level,
                method="higher",
            )
        )
    except TypeError:
        return float(
            np.quantile(
                scores,
                level,
                interpolation="higher",
            )
        )


def adaptive_conformal_path(
    y_true,
    y_pred,
    calibration_scores,
    *,
    alpha=0.10,
    step_size=0.05,
):
    y_true = np.asarray(
        y_true,
        dtype=float,
    ).reshape(-1)

    y_pred = np.asarray(
        y_pred,
        dtype=float,
    ).reshape(-1)

    buffer = list(
        np.asarray(
            calibration_scores,
            dtype=float,
        ).reshape(-1)
    )

    alpha_t = float(alpha)

    lower = []
    upper = []
    alpha_path = []

    for observed, predicted in zip(
        y_true,
        y_pred,
    ):
        q = finite_sample_conformal_quantile(
            buffer,
            alpha_t,
        )

        lo = float(predicted - q)
        up = float(predicted + q)

        lower.append(lo)
        upper.append(up)
        alpha_path.append(alpha_t)

        miss = float(
            observed < lo
            or observed > up
        )

        alpha_t = float(
            np.clip(
                alpha_t
                + step_size
                * (alpha - miss),
                0.01,
                0.50,
            )
        )

        buffer.append(
            abs(
                float(
                    observed - predicted
                )
            )
        )

    return (
        np.asarray(lower),
        np.asarray(upper),
        np.asarray(alpha_path),
    )


def evaluate_fixed_baseline_with_aci_cpu(
    model_name,
    params,
    train,
    test,
    *,
    calibration_ratio=0.20,
    alpha=0.10,
    aci_step_size=0.05,
    seasonal_period=12,
):
    train = ensure_series(
        train,
        name="train",
    )
    test = ensure_series(
        test,
        name="test",
    )

    split = int(
        np.floor(
            (1.0 - calibration_ratio)
            * len(train)
        )
    )

    split = max(
        split,
        seasonal_period + 5,
    )
    split = min(
        split,
        len(train) - 2,
    )

    train_core = train.iloc[:split]
    calibration = train.iloc[split:]

    if len(calibration) < 2:
        raise ValueError(
            "At least two chronological "
            "calibration points are required."
        )

    _, calibration_forecast = (
        fit_predict_baseline(
            model_name,
            train_core,
            len(calibration),
            params,
        )
    )

    calibration_output = (
        parse_forecast_output(
            calibration_forecast
        )
    )

    if (
        len(calibration_output.pred)
        != len(calibration)
    ):
        raise ValueError(
            f"{model_name} returned "
            f"{len(calibration_output.pred)} "
            "calibration values; expected "
            f"{len(calibration)}."
        )

    calibration_scores = np.abs(
        calibration.to_numpy(dtype=float)
        - calibration_output.pred
    )

    start = time.perf_counter()

    model, test_forecast = (
        fit_predict_baseline(
            model_name,
            train,
            len(test),
            params,
        )
    )

    elapsed = (
        time.perf_counter() - start
    )

    test_output = (
        parse_forecast_output(
            test_forecast
        )
    )

    if test_output.has_interval:
        lower = test_output.lower
        upper = test_output.upper

        alpha_path = np.full(
            len(test),
            alpha,
            dtype=float,
        )

        interval_source = "native"

    else:
        (
            lower,
            upper,
            alpha_path,
        ) = adaptive_conformal_path(
            test.to_numpy(dtype=float),
            test_output.pred,
            calibration_scores,
            alpha=alpha,
            step_size=aci_step_size,
        )

        interval_source = "external_aci"

    forecast = pd.DataFrame(
        {
            "pred": test_output.pred,
            "lower": lower,
            "upper": upper,
            "aci_alpha": alpha_path,
        },
        index=test.index,
    )

    metrics = evaluate_forecast(
        test,
        forecast["pred"],
        y_train=train,
        lower=forecast["lower"],
        upper=forecast["upper"],
        alpha=alpha,
        seasonal_period=seasonal_period,
        elapsed_seconds=elapsed,
        trainable_params=(
            count_trainable_parameters(
                model
            )
        ),
    )

    return {
        "model": model,
        "forecast": forecast,
        "metrics": metrics,
        "interval_source": interval_source,
        "calibration_size": len(calibration),
    }

# ============================================================
# CELL 5 — FEASIBLE PARAMETERS FOR RESTRICTED HISTORIES
# No hyperparameter optimization is performed.
# ============================================================

def make_baseline_params_feasible_for_aci(
    model_name,
    params,
    *,
    n_history,
    test_horizon,
    calibration_ratio=0.20,
    seasonal_period=12,
):
    p = copy.deepcopy(params)

    split = int(
        np.floor(
            (1.0 - calibration_ratio)
            * n_history
        )
    )

    split = max(
        split,
        seasonal_period + 5,
    )
    split = min(
        split,
        n_history - 2,
    )

    calibration_horizon = (
        n_history - split
    )

    direct_models = {
        "CNN",
        "LSTM",
        "GaussianProcess",
        "KernelRidge",
        "KernelRidgeRegressor",
    }

    if (
        model_name in direct_models
        and "input_window" in p
    ):
        # At least eight direct windows are
        # required by the repository class.
        max_for_calibration = (
            split
            - calibration_horizon
            - 7
        )

        max_for_test = (
            n_history
            - test_horizon
            - 7
        )

        max_window = max(
            1,
            min(
                max_for_calibration,
                max_for_test,
            ),
        )

        p["input_window"] = int(
            np.clip(
                p["input_window"],
                1,
                max_window,
            )
        )

        if "kernel_size" in p:
            p["kernel_size"] = int(
                np.clip(
                    p["kernel_size"],
                    1,
                    max(
                        1,
                        p["input_window"],
                    ),
                )
            )

    if (
        model_name == "NLinear"
        and "window_size" in p
    ):
        max_window = max(
            1,
            min(
                split - 10,
                n_history - 10,
            ),
        )

        p["window_size"] = int(
            np.clip(
                p["window_size"],
                1,
                max_window,
            )
        )

    if (
        model_name == "ARKAN"
        and "window_size" in p
    ):
        max_window = max(
            1,
            min(
                split - 12,
                n_history - 12,
            ),
        )

        p["window_size"] = int(
            np.clip(
                p["window_size"],
                1,
                max_window,
            )
        )

    if model_name == "AR":
        p["lags"] = int(
            min(
                max(
                    1,
                    int(
                        p.get("lags", 1)
                    ),
                ),
                max(
                    1,
                    split // 3,
                ),
            )
        )

        if (
            p.get("seasonal", False)
            and split
            <= p["lags"]
            + seasonal_period
            + 2
        ):
            p["seasonal"] = False

        p["period"] = int(
            p.get(
                "period",
                seasonal_period,
            )
        )

    if model_name == "ARIMA":
        max_order = max(
            1,
            split // 4,
        )

        p["p"] = int(
            np.clip(
                int(p.get("p", 1)),
                0,
                max_order,
            )
        )

        p["q"] = int(
            np.clip(
                int(p.get("q", 0)),
                0,
                max_order,
            )
        )

        p["d"] = int(
            np.clip(
                int(p.get("d", 0)),
                0,
                2,
            )
        )

        if (
            p["p"] == 0
            and p["q"] == 0
            and p["d"] == 0
        ):
            p["p"] = 1

    if (
        model_name == "ETS"
        and p.get("seasonal_periods")
    ):
        required = (
            2
            * int(
                p["seasonal_periods"]
            )
            + 2
        )

        if split < required:
            p["seasonal"] = None
            p["seasonal_periods"] = None

    if model_name == "Chronos":
        return p

    return p


def make_s3_params_feasible(
    params,
    *,
    n_history,
    test_horizon,
):
    p = make_params_feasible(
        "S3-Forecaster",
        params,
        n_history,
        seasonal_period=SEASONAL_PERIOD,
    )

    minimum_required = (
        2 * test_horizon + 5
    )

    if n_history < minimum_required:
        raise ValueError(
            "The restricted history is too short "
            "for direct multi-horizon S3 training. "
            f"N={n_history}, minimum={minimum_required}."
        )

    maximum_ar_lags = max(
        1,
        n_history
        - 2 * test_horizon
        - 4,
    )

    p["ar_lags"] = int(
        min(
            p["ar_lags"],
            maximum_ar_lags,
        )
    )

    lower_split = (
        test_horizon
        + p["ar_lags"]
        + 2
    ) / n_history

    upper_split = (
        n_history
        - test_horizon
        - 1
    ) / n_history

    if lower_split >= upper_split:
        raise ValueError(
            "No feasible S3 train/calibration split "
            f"exists for N={n_history}."
        )

    p["oob_split_ratio"] = float(
        np.clip(
            p["oob_split_ratio"],
            lower_split,
            upper_split,
        )
    )

    return p


def clear_cpu_model_state():
    if tf is not None:
        try:
            tf.keras.backend.clear_session()
        except Exception:
            pass

    gc.collect()

# %%
# ============================================================
# CELL 6 — DATA-EFFICIENCY ANALYSIS FOR ALL MODELS ON CPU
# ============================================================

def run_complete_data_efficiency_cpu(
    train,
    test,
    *,
    history_sizes=(
        48,
        60,
        84,
        120,
        160,
    ),
):
    train = ensure_series(
        train,
        name="train",
    )

    test = ensure_series(
        test,
        name="test",
    )

    model_specs = [
        (
            "S3-Forecaster",
            "S3-Forecaster",
            S3_POINT_PARAMS,
        ),
        (
            "S3-FastSketch",
            "S3-FastSketch",
            FASTSKETCH_POINT_PARAMS,
        ),
    ]

    for internal_name in BASELINE_ORDER:
        model_specs.append(
            (
                BASELINE_DISPLAY_NAMES.get(
                    internal_name,
                    internal_name,
                ),
                internal_name,
                BASELINE_PARAMS[
                    internal_name
                ],
            )
        )

    rows = []
    forecasts = {}
    models = {}

    for (
        display_name,
        internal_name,
        fixed_params,
    ) in model_specs:

        forecasts[display_name] = {}
        models[display_name] = {}

        for history_size in history_sizes:
            if history_size > len(train):
                continue

            train_subset = (
                train
                .iloc[-int(history_size):]
                .copy()
            )

            start = time.perf_counter()

            try:
                if internal_name == "S3-Forecaster":
                    effective_params = (
                        make_s3_params_feasible(
                            fixed_params,
                            n_history=len(
                                train_subset
                            ),
                            test_horizon=len(test),
                        )
                    )

                elif internal_name == "S3-FastSketch":
                    effective_params = (
                        make_params_feasible(
                            internal_name,
                            fixed_params,
                            len(train_subset),
                            seasonal_period=(
                                SEASONAL_PERIOD
                            ),
                        )
                    )

                else:
                    effective_params = (
                        make_baseline_params_feasible_for_aci(
                            internal_name,
                            fixed_params,
                            n_history=len(
                                train_subset
                            ),
                            test_horizon=len(test),
                            calibration_ratio=(
                                BASELINE_CALIBRATION_RATIO
                            ),
                            seasonal_period=(
                                SEASONAL_PERIOD
                            ),
                        )
                    )

                print(
                    f"{display_name}: "
                    f"N={history_size}, CPU"
                )

                if internal_name == "S3-Forecaster":
                    output = evaluate_s3_forecaster(
                        train_subset,
                        test,
                        effective_params,
                        uq_params=S3_UQ_PARAMS,
                        seasonal_period=(
                            SEASONAL_PERIOD
                        ),
                        alpha=ALPHA,
                    )

                elif internal_name == "S3-FastSketch":
                    output = evaluate_fastsketch(
                        train_subset,
                        test,
                        effective_params,
                        uq_params=(
                            FASTSKETCH_UQ_PARAMS
                        ),
                        seasonal_period=(
                            SEASONAL_PERIOD
                        ),
                        alpha=ALPHA,
                    )

                else:
                    output = (
                        evaluate_fixed_baseline_with_aci_cpu(
                            internal_name,
                            effective_params,
                            train_subset,
                            test,
                            calibration_ratio=(
                                BASELINE_CALIBRATION_RATIO
                            ),
                            alpha=ALPHA,
                            aci_step_size=(
                                BASELINE_ACI_STEP_SIZE
                            ),
                            seasonal_period=(
                                SEASONAL_PERIOD
                            ),
                        )
                    )

                rows.append(
                    {
                        "model_name": display_name,
                        "internal_name": internal_name,
                        "history_size": int(
                            history_size
                        ),
                        "device": "cpu",
                        "status": "ok",
                        "error": None,
                        "effective_params": (
                            effective_params
                        ),
                        **output["metrics"],
                    }
                )

                forecasts[
                    display_name
                ][history_size] = (
                    output["forecast"]
                )

                models[
                    display_name
                ][history_size] = (
                    output["model"]
                )

            except Exception as exc:
                rows.append(
                    {
                        "model_name": display_name,
                        "internal_name": internal_name,
                        "history_size": int(
                            history_size
                        ),
                        "device": "cpu",
                        "status": "failed",
                        "error": (
                            f"{type(exc).__name__}: "
                            f"{exc}"
                        ),
                        "effective_params": (
                            locals().get(
                                "effective_params",
                                fixed_params,
                            )
                        ),
                        "elapsed_seconds": (
                            time.perf_counter()
                            - start
                        ),
                    }
                )

                forecasts[
                    display_name
                ][history_size] = None

                models[
                    display_name
                ][history_size] = None

            finally:
                clear_cpu_model_state()

    summary = (
        pd.DataFrame(rows)
        .sort_values(
            [
                "model_name",
                "history_size",
            ]
        )
        .reset_index(drop=True)
    )

    return {
        "summary": summary,
        "forecasts": forecasts,
        "models": models,
    }


minimum_s3_history = max(
    18,
    2 * len(test_series) + 5,
)

preferred_history_sizes = [
    36,
    48,
    60,
    84,
    120,
    160,
]

candidate_history_sizes = [
    size
    for size in preferred_history_sizes
    if minimum_s3_history <= size <= len(train_series)
]

fractional_history_sizes = [
    int(round(len(train_series) * fraction))
    for fraction in (0.60, 0.75, 0.90, 1.00)
]

candidate_history_sizes.extend(
    size
    for size in fractional_history_sizes
    if minimum_s3_history <= size <= len(train_series)
)

candidate_history_sizes.append(len(train_series))

DATA_EFFICIENCY_HISTORY_SIZES = tuple(
    sorted(
        {
            int(size)
            for size in candidate_history_sizes
            if minimum_s3_history <= int(size) <= len(train_series)
        }
    )
)

if not DATA_EFFICIENCY_HISTORY_SIZES:
    raise ValueError(
        "The selected training series is too short for the "
        "data-efficiency experiment with the current test horizon."
    )

print(
    "Data-efficiency history sizes:",
    DATA_EFFICIENCY_HISTORY_SIZES,
)

data_efficiency = (
    run_complete_data_efficiency_cpu(
        train_series,
        test_series,
        history_sizes=(
            DATA_EFFICIENCY_HISTORY_SIZES
        ),
    )
)

data_efficiency_summary = (
    data_efficiency["summary"]
)

print("Data-efficiency results")
display(data_efficiency_summary)

data_efficiency_summary.to_csv(
    OUTPUT_DIR
    / "tourism_data_efficiency_all_models_cpu.csv",
    index=False,
)
# Out:
# Data-efficiency history sizes: (60, 84, 98, 120, 122, 147, 160, 163)
# S3-Forecaster: N=60, CPU
# S3-Forecaster: N=84, CPU
# S3-Forecaster: N=98, CPU
# S3-Forecaster: N=120, CPU
# S3-Forecaster: N=122, CPU
# S3-Forecaster: N=147, CPU
# S3-Forecaster: N=160, CPU
# S3-Forecaster: N=163, CPU
# S3-FastSketch: N=60, CPU
# S3-FastSketch: N=84, CPU
# S3-FastSketch: N=98, CPU
# S3-FastSketch: N=120, CPU
# S3-FastSketch: N=122, CPU
# S3-FastSketch: N=147, CPU
# S3-FastSketch: N=160, CPU
# S3-FastSketch: N=163, CPU
# CNN: N=60, CPU
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fd3dee74cc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fd3e34a0a40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# CNN: N=84, CPU
# CNN: N=98, CPU
# CNN: N=120, CPU
# CNN: N=122, CPU
# CNN: N=147, CPU
# CNN: N=160, CPU
# CNN: N=163, CPU
# LSTM: N=60, CPU
# LSTM: N=84, CPU
# LSTM: N=98, CPU
# LSTM: N=120, CPU
# LSTM: N=122, CPU
# LSTM: N=147, CPU
# LSTM: N=160, CPU
# LSTM: N=163, CPU
# Gaussian Process: N=60, CPU
# Gaussian Process: N=84, CPU
# Gaussian Process: N=98, CPU
# Gaussian Process: N=120, CPU
# Gaussian Process: N=122, CPU
# Gaussian Process: N=147, CPU
# Gaussian Process: N=160, CPU
# Gaussian Process: N=163, CPU
# Kernel Ridge: N=60, CPU
# Kernel Ridge: N=84, CPU
# Kernel Ridge: N=98, CPU
# Kernel Ridge: N=120, CPU
# Kernel Ridge: N=122, CPU
# Kernel Ridge: N=147, CPU
# Kernel Ridge: N=160, CPU
# Kernel Ridge: N=163, CPU
# AR: N=60, CPU
# AR: N=84, CPU
# AR: N=98, CPU
# AR: N=120, CPU
# AR: N=122, CPU
# AR: N=147, CPU
# AR: N=160, CPU
# AR: N=163, CPU
# ARIMA: N=60, CPU
# ARIMA: N=84, CPU
# ARIMA: N=98, CPU
# ARIMA: N=120, CPU
# ARIMA: N=122, CPU
# ARIMA: N=147, CPU
# ARIMA: N=160, CPU
# ARIMA: N=163, CPU
# ARKAN: N=60, CPU
# ARKAN: N=84, CPU
# ARKAN: N=98, CPU
# ARKAN: N=120, CPU
# ARKAN: N=122, CPU
# ARKAN: N=147, CPU
# ARKAN: N=160, CPU
# ARKAN: N=163, CPU
# EasyTSF (NLinear): N=60, CPU
# EasyTSF (NLinear): N=84, CPU
# EasyTSF (NLinear): N=98, CPU
# EasyTSF (NLinear): N=120, CPU
# EasyTSF (NLinear): N=122, CPU
# EasyTSF (NLinear): N=147, CPU
# EasyTSF (NLinear): N=160, CPU
# EasyTSF (NLinear): N=163, CPU
# ETS: N=60, CPU
# ETS: N=84, CPU
# ETS: N=98, CPU
# ETS: N=120, CPU
# ETS: N=122, CPU
# ETS: N=147, CPU
# ETS: N=160, CPU
# ETS: N=163, CPU
# Chronos: N=60, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=84, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=98, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=120, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=122, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=147, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=160, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=163, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Data-efficiency results
#        model_name  internal_name  history_size device status error  \
# 0              AR             AR            60    cpu     ok  None
# 1              AR             AR            84    cpu     ok  None
# 2              AR             AR            98    cpu     ok  None
# 3              AR             AR           120    cpu     ok  None
# 4              AR             AR           122    cpu     ok  None
# ..            ...            ...           ...    ...    ...   ...
# 91  S3-Forecaster  S3-Forecaster           120    cpu     ok  None
# 92  S3-Forecaster  S3-Forecaster           122    cpu     ok  None
# 93  S3-Forecaster  S3-Forecaster           147    cpu     ok  None
# 94  S3-Forecaster  S3-Forecaster           160    cpu     ok  None
# 95  S3-Forecaster  S3-Forecaster           163    cpu     ok  None
#
#                                      effective_params       mae       mse  \
# 0   {'lags': 16, 'trend': 't', 'seasonal': False, ...  0.066603  0.006807
# 1   {'lags': 22, 'trend': 't', 'seasonal': False, ...  0.080928  0.010484
# 2   {'lags': 26, 'trend': 't', 'seasonal': False, ...  0.197912  0.055390
# 3   {'lags': 27, 'trend': 't', 'seasonal': False, ...  0.096351  0.013758
# 4   {'lags': 27, 'trend': 't', 'seasonal': False, ...  0.087383  0.011310
# ..                                                ...       ...       ...
# 91  {'reservoir_size': 28, 'spectral_radius': 1.17...  0.056445  0.004198
# 92  {'reservoir_size': 28, 'spectral_radius': 1.17...  0.053126  0.003937
# 93  {'reservoir_size': 28, 'spectral_radius': 1.17...  0.052744  0.003881
# 94  {'reservoir_size': 28, 'spectral_radius': 1.17...  0.053136  0.004026
# 95  {'reservoir_size': 28, 'spectral_radius': 1.17...  0.066390  0.006765
#
#         rmse  ...       ecp  coverage_error        iw  mean_width       mis  \
# 0   0.082503  ...  0.958333        0.058333  0.463530    0.463530  0.473881
# 1   0.102390  ...  1.000000        0.100000  0.708327    0.708327  0.708327
# 2   0.235351  ...  0.875000        0.025000  0.648688    0.648688  0.785366
# 3   0.117294  ...  0.791667        0.108333  0.371851    0.371851  0.438280
# 4   0.106349  ...  0.750000        0.150000  0.315433    0.315433  0.377026
# ..       ...  ...       ...             ...       ...         ...       ...
# 91  0.064790  ...  1.000000        0.100000  0.806415    0.806415  0.806415
# 92  0.062744  ...  1.000000        0.100000  0.806415    0.806415  0.806415
# 93  0.062296  ...  1.000000        0.100000  0.806415    0.806415  0.806415
# 94  0.063450  ...  1.000000        0.100000  0.806414    0.806414  0.806414
# 95  0.082253  ...  1.000000        0.100000  0.806415    0.806415  0.806415
#
#     interval_score       msis     scale  elapsed_seconds  trainable_params
# 0         0.473881   7.308381  0.064841         0.007850                17
# 1         0.708327   8.882453  0.079745         0.009214                23
# 2         0.785366  10.015214  0.078417         0.010003                27
# 3         0.438280   5.940895  0.073773         0.010537                28
# 4         0.377026   5.192439  0.072611         0.010181                28
# ..             ...        ...       ...              ...               ...
# 91        0.806415  10.930979  0.073773         0.068695               842
# 92        0.806415  11.106018  0.072611         0.062141               842
# 93        0.806415  10.703813  0.075339         0.066056               842
# 94        0.806414  10.111943  0.079749         0.066658               842
# 95        0.806415  10.151697  0.079436         0.074385               842
#
# [96 rows x 25 columns]

# %%
# ============================================================
# CELL 7 — DATA-EFFICIENCY TABLES AND FIGURES
# ============================================================

def make_data_efficiency_pivot(
    summary,
    metric,
):
    valid = summary[
        (summary["status"] == "ok")
        & summary[metric].notna()
        & np.isfinite(summary[metric])
    ]

    return valid.pivot_table(
        index="model_name",
        columns="history_size",
        values=metric,
        aggfunc="first",
    )


def plot_data_efficiency(
    summary,
    metric,
    *,
    figsize=(13, 7),
):
    valid = summary[
        (summary["status"] == "ok")
        & summary[metric].notna()
        & np.isfinite(summary[metric])
    ].copy()

    fig, ax = plt.subplots(
        figsize=figsize
    )

    for model_name in (
        valid["model_name"]
        .drop_duplicates()
    ):
        subset = (
            valid[
                valid["model_name"]
                == model_name
            ]
            .sort_values(
                "history_size"
            )
        )

        ax.plot(
            subset["history_size"],
            subset[metric],
            marker="o",
            label=model_name,
        )

    ax.set_xlabel(
        "Available history (N)",
        fontsize=14,
    )

    ax.set_ylabel(
        metric.replace("_", " ").upper(),
        fontsize=14,
    )

    ax.tick_params(
        axis="both",
        labelsize=12,
    )

    ax.grid(alpha=0.3)

    ax.legend(
        bbox_to_anchor=(1.02, 1),
        loc="upper left",
        fontsize=11,
    )

    fig.tight_layout()
    plt.show()

    return fig, ax


data_efficiency_mape = (
    make_data_efficiency_pivot(
        data_efficiency_summary,
        "mape_percent",
    )
)

data_efficiency_rmse = (
    make_data_efficiency_pivot(
        data_efficiency_summary,
        "rmse",
    )
)

data_efficiency_msis = (
    make_data_efficiency_pivot(
        data_efficiency_summary,
        "msis",
    )
)

print("MAPE pivot")
display(data_efficiency_mape)

print("RMSE pivot")
display(data_efficiency_rmse)

print("MSIS pivot")
display(data_efficiency_msis)

data_efficiency_mape.to_csv(
    OUTPUT_DIR
    / "tourism_data_efficiency_mape_pivot.csv"
)

data_efficiency_rmse.to_csv(
    OUTPUT_DIR
    / "tourism_data_efficiency_rmse_pivot.csv"
)

data_efficiency_msis.to_csv(
    OUTPUT_DIR
    / "tourism_data_efficiency_msis_pivot.csv"
)

plot_data_efficiency(
    data_efficiency_summary,
    "mape_percent",
)

plot_data_efficiency(
    data_efficiency_summary,
    "rmse",
)

plot_data_efficiency(
    data_efficiency_summary,
    "msis",
)
# Out:
# MAPE pivot
# history_size            60        84        98        120       122       147  \
# model_name
# AR                 0.841346  1.001137  2.460434  1.203875  1.093493  1.078456
# ETS                 6.742737   5.465470   6.048572   6.674981   5.118984
# EasyTSF (NLinear)   9.700037   5.081470   5.157536   5.870941   6.034987
# Gaussian Process    7.629613   6.051495   5.539112   6.494196   6.974110
# Kernel Ridge        7.983583   5.917032   7.350345   9.360617   9.179793
# LSTM               28.716778   8.417236   9.659133  19.434062  11.364063
# S3-FastSketch      73.550019  12.146962  23.399742   7.992234  16.397512
# S3-Forecaster      12.420299  10.112414  10.283626  10.930979  11.106018
#
# history_size             147        160        163
# model_name
# AR                  5.664525   5.722624   6.016902
# ARIMA               9.190901   9.077895   8.378320
# ARKAN               5.083451   7.788281   7.847330
# CNN                 8.907318  14.197767  12.095330
# Chronos             6.350664   5.733865   5.679549
# ETS                 5.207812   4.937089   4.757563
# EasyTSF (NLinear)   6.252037   5.076616   5.241958
# Gaussian Process    8.508542   9.553591  10.369779
# Kernel Ridge        7.184241   6.697761   6.626074
# LSTM                7.537480   7.840451   6.434148
# S3-FastSketch       6.858626   7.623140   9.790895
# S3-Forecaster      10.703813  10.111943  10.151697
# (<Figure size 1300x700 with 1 Axes>,
#  <Axes: xlabel='Available history (N)', ylabel='MSIS'>)

# %% [markdown]
# # 14.MULTI-PRIOR ROBUSTNESS

# %%
# ============================================================
# CELL 8 — MULTI-PRIOR ROBUSTNESS
# Fixed model hyperparameters; no new HPO.
# ============================================================

try:
    import prophet  # noqa: F401
except ImportError:
    subprocess.run(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "-q",
            "prophet",
        ],
        check=True,
    )

import logging

logging.getLogger(
    "cmdstanpy"
).setLevel(logging.WARNING)

logging.getLogger(
    "prophet"
).setLevel(logging.WARNING)

prior_factories = {
    "Rolling": lambda: RollingPrior(
        window_size=int(
            S3_POINT_PARAMS[
                "foundation_window"
            ]
        )
    ),
    "ETS": lambda: ETSPrior(
        error="add",
        trend="add",
        seasonal="add",
        seasonal_periods=(
            SEASONAL_PERIOD
        ),
        damped_trend=True,
    ),
    "Prophet": lambda: ProphetPrior(
        yearly_seasonality=True,
        weekly_seasonality=False,
        daily_seasonality=False,
        seasonality_mode="additive",
        changepoint_prior_scale=0.05,
    ),
}

if RUN_CHRONOS_PRIOR:
    prior_factories["Chronos"] = lambda: ChronosPrior(**CHRONOS_KWARGS)

multi_prior = run_multi_prior_robustness(
    train_series=train_series,
    test_series=test_series,
    prior_factories=prior_factories,
    s3_params=S3_POINT_PARAMS,
    fastsketch_params=(
        FASTSKETCH_POINT_PARAMS
    ),
    s3_uq=S3_UQ_PARAMS,
    fastsketch_uq=(
        FASTSKETCH_UQ_PARAMS
    ),
    include_prior_only=True,
    alpha=ALPHA,
    seasonal_period=SEASONAL_PERIOD,
)

multi_prior_summary = (
    multi_prior["summary"]
)

print("Multi-prior robustness results")
display(multi_prior_summary)

multi_prior_summary.to_csv(
    OUTPUT_DIR
    / "tourism_multi_prior_robustness.csv",
    index=False,
)
# Out:
# 17:55:36 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:36 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:37 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:38 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:38 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:38 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:38 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:38 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:38 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:38 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:38 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:38 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:38 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:38 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:38 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:38 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:39 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:39 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:39 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:39 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:39 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:39 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:39 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:39 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:39 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:39 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:39 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:39 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:39 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:40 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:40 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:40 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:40 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:40 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:40 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:40 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:40 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:40 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:40 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:40 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:40 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:40 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:41 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:42 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:42 - cmdstanpy - INFO - Chain [1] done processing
# 17:55:42 - cmdstanpy - INFO - Chain [1] start processing
# 17:55:42 - cmdstanpy - INFO - Chain [1] done processing
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Multi-prior robustness results
#       prior          model status error       mae       mse      rmse  \
# 0   Chronos     Prior-only     ok  None  0.110031  0.015916  0.126158
# 1   Chronos  S3-FastSketch     ok  None  0.311462  0.129447  0.359787
# 2   Chronos  S3-Forecaster     ok  None  0.110031  0.015916  0.126158
# 3       ETS     Prior-only     ok  None  0.073019  0.009111  0.095449
# 4       ETS  S3-FastSketch     ok  None  0.050261  0.003800  0.061647
# 5       ETS  S3-Forecaster     ok  None  0.068900  0.007947  0.089144
# 6   Prophet     Prior-only     ok  None  0.108489  0.017264  0.131392
# 7   Prophet  S3-FastSketch     ok  None  0.102383  0.015468  0.124370
# 8   Prophet  S3-Forecaster     ok  None  0.107787  0.017019  0.130456
# 9   Rolling     Prior-only     ok  None  0.057311  0.004639  0.068113
# 10  Rolling  S3-FastSketch     ok  None  0.184302  0.045332  0.212913
# 11  Rolling  S3-Forecaster     ok  None  0.066390  0.006765  0.082253
#
#           r2  mape_percent      mape  ...       ecp  coverage_error        iw  \
# 0   0.914271      1.390266  0.013903  ...       NaN             NaN       NaN
# 1   0.302746      3.893799  0.038938  ...  0.166667        0.733333  0.234450
# 2   0.914271      1.390265  0.013903  ...  0.500000        0.400000  0.236700
# 3   0.950926      0.921175  0.009212  ...       NaN             NaN       NaN
# 4   0.979530      0.630759  0.006308  ...  0.791667        0.108333  0.139531
# 5   0.957196      0.868516  0.008685  ...  0.666667        0.233333  0.185958
# 6   0.907009      1.377758  0.013778  ...       NaN             NaN       NaN
# 7   0.916684      1.301482  0.013015  ...  0.500000        0.400000  0.143554
# 8   0.908330      1.369081  0.013691  ...  0.416667        0.483333  0.123660
# 9   0.975011      0.717871  0.007179  ...       NaN             NaN       NaN
# 10  0.755824      2.261279  0.022613  ...  0.833333        0.066667  0.574910
# 11  0.963558      0.825873  0.008259  ...  1.000000        0.100000  0.806415
#
#     mean_width       mis  interval_score       msis     scale  \
# 0          NaN       NaN             NaN        NaN       NaN
# 1     0.234450  4.327386        4.327386  54.476098  0.079436
# 2     0.236700  0.682951        0.682951   8.597450  0.079436
# 3          NaN       NaN             NaN        NaN       NaN
# 4     0.139531  0.303933        0.303933   3.826111  0.079436
# 5     0.185958  0.492284        0.492284   6.197203  0.079436
# 6          NaN       NaN             NaN        NaN       NaN
# 7     0.143554  1.087742        1.087742  13.693239  0.079436
# 8     0.123660  1.261693        1.261693  15.883059  0.079436
# 9          NaN       NaN             NaN        NaN       NaN
# 10    0.574910  0.775627        0.775627   9.764121  0.079436
# 11    0.806415  0.806415        0.806415  10.151697  0.079436
#
#     elapsed_seconds  trainable_params
# 0          6.367587                 0
# 1        153.670492                27
# 2         15.760811               842
# 3          0.132208                 0
# 4          4.007985                27
# 5          0.479407               842
# 6          2.230414                 0
# 7          3.849578                27
# 8          0.513458               842
# 9          0.003342                 0
# 10         0.518958                27
# 11         0.076704               842
#
# [12 rows x 22 columns]

# %%
# ============================================================
# CELL 9 — MULTI-PRIOR TABLES AND FIGURES
# ============================================================

def plot_multi_prior_metric(
    summary,
    metric,
    *,
    figsize=(12, 6),
):
    valid = summary[
        (summary["status"] == "ok")
        & summary[metric].notna()
        & np.isfinite(summary[metric])
    ].copy()

    pivot = valid.pivot_table(
        index="prior",
        columns="model",
        values=metric,
        aggfunc="first",
    )

    fig, ax = plt.subplots(
        figsize=figsize
    )

    pivot.plot(
        kind="bar",
        ax=ax,
    )

    ax.set_xlabel(
        "Foundation prior",
        fontsize=14,
    )

    ax.set_ylabel(
        metric.replace("_", " ").upper(),
        fontsize=14,
    )

    ax.tick_params(
        axis="both",
        labelsize=12,
    )

    ax.legend(
        title="Model",
        fontsize=11,
    )

    fig.tight_layout()
    plt.show()

    return pivot, fig, ax


multi_prior_mape, _, _ = (
    plot_multi_prior_metric(
        multi_prior_summary,
        "mape_percent",
    )
)

multi_prior_rmse, _, _ = (
    plot_multi_prior_metric(
        multi_prior_summary,
        "rmse",
    )
)

multi_prior_msis, _, _ = (
    plot_multi_prior_metric(
        multi_prior_summary,
        "msis",
    )
)

multi_prior_mape.to_csv(
    OUTPUT_DIR
    / "tourism_multi_prior_mape_pivot.csv"
)

multi_prior_rmse.to_csv(
    OUTPUT_DIR
    / "tourism_multi_prior_rmse_pivot.csv"
)

multi_prior_msis.to_csv(
    OUTPUT_DIR
    / "tourism_multi_prior_msis_pivot.csv"
)

print("Saved analysis files:")

for path in sorted(
    OUTPUT_DIR.glob("tourism_*")
):
    print(path.name)
# Out:
# Saved analysis files:
# tourism_data_efficiency_all_models_cpu.csv
# tourism_data_efficiency_mape_pivot.csv
# tourism_data_efficiency_msis_pivot.csv
# tourism_data_efficiency_rmse_pivot.csv
# tourism_fastsketch_ablation.csv
# tourism_multi_prior_mape_pivot.csv
# tourism_multi_prior_msis_pivot.csv
# tourism_multi_prior_rmse_pivot.csv
# tourism_multi_prior_robustness.csv
# tourism_s3_ablation.csv
# tourism_shock_details_ar.csv
# tourism_shock_details_arima.csv
# tourism_shock_details_arkan.csv
# tourism_shock_details_chronos.csv
# tourism_shock_details_cnn.csv
# tourism_shock_details_easytsf_nlinear.csv
# tourism_shock_details_ets.csv
# tourism_shock_details_gaussian_process.csv
# tourism_shock_details_kernel_ridge.csv
# tourism_shock_details_lstm.csv
# tourism_shock_details_s3_fastsketch.csv
# tourism_shock_details_s3_forecaster.csv
# tourism_shock_mape_pivot.csv
# tourism_shock_msis_pivot.csv
# tourism_shock_nonshock_failures.csv
# tourism_shock_nonshock_summary.csv
# tourism_shock_rmse_pivot.csv

# %% [markdown]
# ## 15. Forecast plots

# %%
def plot_forecast(model_name, history_points=60):
    frame = original_forecasts[model_name]
    fig, ax = plt.subplots(figsize=(12, 4))
    ax.plot(raw_train.index[-history_points:], raw_train.iloc[-history_points:], label="Train")
    ax.plot(raw_test.index, raw_test, label="Observed test")
    ax.plot(frame.index, frame["pred"], label=model_name)
    if {"lower", "upper"}.issubset(frame.columns):
        ax.fill_between(frame.index, frame["lower"], frame["upper"], alpha=0.20, label="90% interval")
    ax.set_xlabel("Time")
    ax.set_ylabel("Original Tourism Monthly scale")
    ax.legend()
    fig.tight_layout()
    plt.show()


plot_forecast("S3-Forecaster")
plot_forecast("S3-FastSketch")

# %% [markdown]
# ## 16. Residual analysis of the proposed approaches

# %%
residual_rows = []
residual_reports = {}

for model_name in ("S3-Forecaster", "S3-FastSketch"):
    forecast = original_forecasts[model_name]
    report = analyze_forecast_residuals(
        raw_test,
        forecast["pred"],
        seasonal_period=SEASONAL_PERIOD,
        alpha=0.05,
    )
    residual_reports[model_name] = report
    diagnostics = report["diagnostics"]
    residual_rows.append(
        {
            "Model": model_name,
            "Residual mean": diagnostics["mean"],
            "Residual std": diagnostics["std"],
            "Skewness": diagnostics["skewness"],
            "Excess kurtosis": diagnostics["excess_kurtosis"],
            "Seasonal ACF": diagnostics["seasonal_acf"],
            "Ljung-Box independence not rejected": diagnostics["serial_independence_not_rejected_all"],
            "Normality not rejected by all tests": diagnostics["normality_not_rejected_all"],
        }
    )

residual_summary = pd.DataFrame(residual_rows)
display(residual_summary)

# Publication-oriented diagnostic figures for the best proposed model by MAPE.
best_proposed = (
    original_scale_results[
        original_scale_results["Model"].isin(["S3-Forecaster", "S3-FastSketch"])
    ]
    .sort_values("MAPE (%)")
    .iloc[0]["Model"]
)
print("Residual figures for:", best_proposed)
figures = plot_residual_diagnostics(
    residual_reports[best_proposed]["residuals"],
    fitted=original_forecasts[best_proposed]["pred"],
    seasonal_period=SEASONAL_PERIOD,
)
plt.show()
# Out:
#            Model  Residual mean  Residual std  Skewness  Excess kurtosis  \
# 0  S3-Forecaster    -203.734782    268.147219 -1.072431         0.958403
# 1  S3-FastSketch     497.290380    419.753296  0.738556        -0.503436
#
#    Seasonal ACF  Ljung-Box independence not rejected  \
# 0      0.122202                                False
# 1      0.181913                                False
#
#    Normality not rejected by all tests
# 0                                False
# 1                                 True
# Residual figures for: S3-Forecaster

# %% [markdown]
# ## 17. Export all reproducible outputs

# %%
def json_ready(value):
    if isinstance(value, dict):
        return {str(key): json_ready(item) for key, item in value.items()}
    if isinstance(value, (list, tuple)):
        return [json_ready(item) for item in value]
    if isinstance(value, np.generic):
        return value.item()
    return value


model_scale_results.to_csv(OUTPUT_DIR / "tourism_results_model_scale.csv", index=False)
original_scale_results.to_csv(OUTPUT_DIR / "tourism_results_original_scale.csv", index=False)
residual_summary.to_csv(OUTPUT_DIR / "tourism_residual_summary.csv", index=False)
pd.DataFrame(baseline_failures).to_csv(OUTPUT_DIR / "tourism_baseline_failures.csv", index=False)

for model_name, frame in original_forecasts.items():
    safe_name = model_name.lower().replace(" ", "_").replace("(", "").replace(")", "")
    frame.to_csv(OUTPUT_DIR / f"forecast_{safe_name}.csv")

with open(OUTPUT_DIR / "s3_best_params.json", "w", encoding="utf-8") as file:
    json.dump(
        json_ready({
            "point": s3_result["best_point_params"],
            "uq": s3_result["best_uq_params"],
        }),
        file,
        indent=2,
    )

with open(OUTPUT_DIR / "fastsketch_best_params.json", "w", encoding="utf-8") as file:
    json.dump(
        json_ready({
            "point": fastsketch_result["best_point_params"],
            "uq": fastsketch_result["best_uq_params"],
        }),
        file,
        indent=2,
    )

with open(OUTPUT_DIR / "fixed_baseline_params_original.json", "w", encoding="utf-8") as file:
    json.dump(json_ready(BASELINE_PARAMS_ORIGINAL), file, indent=2)

s3_result["point_study"].trials_dataframe().to_csv(OUTPUT_DIR / "s3_point_trials.csv", index=False)
s3_result["uq_study"].trials_dataframe().to_csv(OUTPUT_DIR / "s3_uq_trials.csv", index=False)
fastsketch_result["point_study"].trials_dataframe().to_csv(OUTPUT_DIR / "fastsketch_point_trials.csv", index=False)
fastsketch_result["uq_study"].trials_dataframe().to_csv(OUTPUT_DIR / "fastsketch_uq_trials.csv", index=False)

print("Saved files:")
for path in sorted(OUTPUT_DIR.iterdir()):
    print(path.name)
# Out:
# Saved files:
# fastsketch_best_params.json
# fastsketch_point_trials.csv
# fastsketch_uq_trials.csv
# fixed_baseline_params_original.json
# forecast_ar.csv
# forecast_arima.csv
# forecast_arkan.csv
# forecast_chronos.csv
# forecast_cnn.csv
# forecast_easytsf_nlinear.csv
# forecast_ets.csv
# forecast_gaussian_process.csv
# forecast_kernel_ridge.csv
# forecast_lstm.csv
# forecast_s3-fastsketch.csv
# forecast_s3-forecaster.csv
# s3_best_params.json
# s3_point_trials.csv
# s3_uq_trials.csv
# tourism_baseline_failures.csv
# tourism_data_efficiency_all_models_cpu.csv
# tourism_data_efficiency_mape_pivot.csv
# tourism_data_efficiency_msis_pivot.csv
# tourism_data_efficiency_rmse_pivot.csv
# tourism_fastsketch_ablation.csv
# tourism_multi_prior_mape_pivot.csv
# tourism_multi_prior_msis_pivot.csv
# tourism_multi_prior_rmse_pivot.csv
# tourism_multi_prior_robustness.csv
# tourism_residual_summary.csv
# tourism_results_model_scale.csv
# tourism_results_original_scale.csv
# tourism_s3_ablation.csv
# tourism_shock_details_ar.csv
# tourism_shock_details_arima.csv
# tourism_shock_details_arkan.csv
# tourism_shock_details_chronos.csv
# tourism_shock_details_cnn.csv
# tourism_shock_details_easytsf_nlinear.csv
# tourism_shock_details_ets.csv
# tourism_shock_details_gaussian_process.csv
# tourism_shock_details_kernel_ridge.csv
# tourism_shock_details_lstm.csv
# tourism_shock_details_s3_fastsketch.csv
# tourism_shock_details_s3_forecaster.csv
# tourism_shock_mape_pivot.csv
# tourism_shock_msis_pivot.csv
# tourism_shock_nonshock_failures.csv
# tourism_shock_nonshock_summary.csv
# tourism_shock_rmse_pivot.csv

# %% [markdown]
# ## Notebook scope
#
# This notebook contains the same complete sequence of experiments as the final M4 notebook:
#
# 1. proposed-model point and uncertainty optimization;
# 2. fixed-parameter baseline evaluation on CPU;
# 3. consolidated point and interval metrics;
# 4. S3-Forecaster and S3-FastSketch ablation studies;
# 5. shock versus non-shock analysis;
# 6. data-efficiency curves;
# 7. multi-prior robustness;
# 8. forecast and residual figures;
# 9. export of all tables, forecasts, trials, and parameters.
#
# The dataset-specific components are limited to loading, temporal indexing, series selection, and the fixed baseline parameters reported by the original **Tourism Monthly** notebook.
