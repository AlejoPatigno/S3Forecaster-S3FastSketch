# %% [markdown]
# # S3-Forecaster and S3-FastSketch on CIF Monthly
#
# This Kaggle notebook reproduces the complete experimental pipeline used in the M4 notebook for **CIF Monthly**. It includes data loading, preprocessing, point and uncertainty optimization for both proposed methods, fixed-parameter baselines on CPU, consolidated metrics, ablation studies, shock/non-shock evaluation, data-efficiency analysis, multi-prior robustness, forecast figures, residual diagnostics, and reproducible exports.
#
# Baseline hyperparameters are taken from the corresponding original dataset notebook and are not re-optimized here.

# %% [markdown]
# ## 1. Clone and install the private repository
#
# Create a Kaggle secret named **`GITHUB_TOKEN`** containing a fine-grained GitHub token with read access to `AlejoPatigno/S3Forecaster-S3FastSketch`. The token is never printed, and the authenticated remote URL is removed immediately after cloning.

# %%
from pathlib import Path
import os
import shutil
import subprocess
import sys

REPO_OWNER = "AlejoPatigno"
REPO_NAME = "S3Forecaster-S3FastSketch"
REPO_DIR = Path("/kaggle/working") / REPO_NAME
CLEAN_REPO_URL = f"https://github.com/{REPO_OWNER}/{REPO_NAME}.git"


def _run(command, *, token=None, cwd=None):
    completed = subprocess.run(
        command,
        cwd=cwd,
        text=True,
        capture_output=True,
        env={**os.environ, "GIT_TERMINAL_PROMPT": "0"},
    )
    if completed.returncode != 0:
        stderr = completed.stderr
        stdout = completed.stdout
        if token:
            stderr = stderr.replace(token, "***")
            stdout = stdout.replace(token, "***")
        raise RuntimeError(
            f"Command failed: {' '.join(map(str, command))}\n"
            f"STDOUT:\n{stdout}\nSTDERR:\n{stderr}"
        )
    return completed


try:
    from kaggle_secrets import UserSecretsClient
    github_token = UserSecretsClient().get_secret("GITHUB_TOKEN")
except Exception:
    github_token = None

if REPO_DIR.exists():
    shutil.rmtree(REPO_DIR)

if github_token:
    authenticated_url = (
        f"https://x-access-token:{github_token}@github.com/"
        f"{REPO_OWNER}/{REPO_NAME}.git"
    )
    _run(["git", "clone", "--depth", "1", authenticated_url, str(REPO_DIR)], token=github_token)
else:
    # This succeeds only when the repository is public.
    _run(["git", "clone", "--depth", "1", CLEAN_REPO_URL, str(REPO_DIR)])

# Remove the credential-bearing remote from the local git configuration.
_run(["git", "-C", str(REPO_DIR), "remote", "set-url", "origin", CLEAN_REPO_URL])

required_paths = [
    REPO_DIR / "pyproject.toml",
    REPO_DIR / "s3paper" / "__init__.py",
    REPO_DIR / "s3paper" / "metrics.py",
    REPO_DIR / "s3paper" / "s3_forecaster_experiment.py",
    REPO_DIR / "s3paper" / "s3_fastsketch_experiment.py",
    REPO_DIR / "s3paper" / "baselines.py",
]
missing = [str(path.relative_to(REPO_DIR)) for path in required_paths if not path.exists()]
if missing:
    raise FileNotFoundError(
        "The repository was cloned, but the modular s3paper package is incomplete. "
        f"Missing files: {missing}"
    )

_run([sys.executable, "-m", "pip", "install", "-q", "-e", str(REPO_DIR)])
print(f"Repository installed from: {REPO_DIR}")
# Out:
# Repository installed from: /kaggle/working/S3Forecaster-S3FastSketch

# %%
# Run this cell immediately after cloning the repository

import os
import sys
import subprocess
import importlib
from pathlib import Path

# Locate the cloned repository
possible_paths = [
    Path("/kaggle/working/S3Forecaster-S3FastSketch"),
    Path.cwd() / "S3Forecaster-S3FastSketch",
]

REPO_DIR = next((path.resolve() for path in possible_paths if path.exists()), None)

if REPO_DIR is None:
    raise FileNotFoundError(
        "The repository folder 'S3Forecaster-S3FastSketch' was not found."
    )

print(f"Repository found at: {REPO_DIR}")

# Move into the repository
os.chdir(REPO_DIR)

# Install the repository as an editable Python package
subprocess.check_call(
    [
        sys.executable,
        "-m",
        "pip",
        "install",
        "-e",
        str(REPO_DIR),
    ]
)

# Make the repository immediately visible to the current kernel
repo_path = str(REPO_DIR)
if repo_path not in sys.path:
    sys.path.insert(0, repo_path)

importlib.invalidate_caches()

# Verify that the package exists
package_dir = REPO_DIR / "s3paper"

if not package_dir.exists():
    raise FileNotFoundError(
        f"The folder {package_dir} does not exist. "
        "Check that the repository contains the s3paper package."
    )

# Imports
from s3paper.data import apply_log_if_positive, inverse_transform
from s3paper.metrics import evaluate_forecast, paper_metric_row
from s3paper.residual_analysis import (
    analyze_forecast_residuals,
    plot_residual_diagnostics,
)

print("s3paper imported successfully.")
# Out:
# Repository found at: /kaggle/working/S3Forecaster-S3FastSketch
# Obtaining file:///kaggle/working/S3Forecaster-S3FastSketch
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (2.0.2)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (2.3.3)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.3 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (1.6.1)
# Requirement already satisfied: statsmodels>=0.14 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (0.14.6)
# Requirement already satisfied: optuna>=3.5 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (4.9.0)
# Requirement already satisfied: matplotlib>=3.7 in /usr/local/lib/python3.12/dist-packages (from s3forecaster-s3fastsketch==0.1.0) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (2.9.0.post0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (2.0.49)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (6.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->s3forecaster-s3fastsketch==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->s3forecaster-s3fastsketch==0.1.0) (2026.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->s3forecaster-s3fastsketch==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3->s3forecaster-s3fastsketch==0.1.0) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14->s3forecaster-s3fastsketch==0.1.0) (1.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (1.3.11)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7->s3forecaster-s3fastsketch==0.1.0) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna>=3.5->s3forecaster-s3fastsketch==0.1.0) (3.0.3)
# Building wheels for collected packages: s3forecaster-s3fastsketch
#   Building editable for s3forecaster-s3fastsketch (pyproject.toml): started
#   Building editable for s3forecaster-s3fastsketch (pyproject.toml): finished with status 'done'
#   Created wheel for s3forecaster-s3fastsketch: filename=s3forecaster_s3fastsketch-0.1.0-0.editable-py3-none-any.whl size=3038 sha256=0cfb640702bf86439651d20e1fcbb34bf9c7831ee7710ddceb3672649996f80f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rlkefg9g/wheels/19/d3/2c/efbc2252ef060622fd0513936439e580d709ac89ae9bba4cf8
# Successfully built s3forecaster-s3fastsketch
# Installing collected packages: s3forecaster-s3fastsketch
#   Attempting uninstall: s3forecaster-s3fastsketch
#     Found existing installation: s3forecaster-s3fastsketch 0.1.0
#     Uninstalling s3forecaster-s3fastsketch-0.1.0:
#       Successfully uninstalled s3forecaster-s3fastsketch-0.1.0
# Successfully installed s3forecaster-s3fastsketch-0.1.0
# s3paper imported successfully.

# %% [markdown]
# ## 2. Imports, reproducibility, and experiment configuration

# %%
# Force every deep-learning baseline, including ARKAN, to use CPU.
# Run this cell before importing TensorFlow, PyTorch, pykan, or s3paper.
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
os.environ["JAX_PLATFORM_NAME"] = "cpu"
os.environ["OMP_NUM_THREADS"] = "4"
os.environ["MKL_NUM_THREADS"] = "4"
os.environ["OPENBLAS_NUM_THREADS"] = "4"
os.environ["NUMEXPR_NUM_THREADS"] = "4"

import inspect
import json
import math
import subprocess
import sys
import time
import warnings
from dataclasses import asdict
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display

try:
    import tensorflow as tf
    try:
        tf.config.set_visible_devices([], "GPU")
    except RuntimeError:
        pass
except ImportError:
    tf = None

import torch
try:
    torch.set_num_threads(max(1, min(4, os.cpu_count() or 1)))
except RuntimeError:
    pass
try:
    torch.set_num_interop_threads(max(1, min(2, os.cpu_count() or 1)))
except RuntimeError:
    pass
torch.cuda.is_available = lambda: False

from s3paper.data import apply_log_if_positive, inverse_transform
from s3paper.metrics import evaluate_forecast, paper_metric_row
from s3paper.residual_analysis import (
    analyze_forecast_residuals,
    plot_residual_diagnostics,
)
from s3paper.s3_forecaster_experiment import run_s3_experiment
from s3paper.s3_fastsketch_experiment import run_fastsketch_experiment
from s3paper.baselines import build_baseline, fit_predict_baseline
from s3paper.utils import (
    count_trainable_parameters,
    ensure_series,
    parse_forecast_output,
    set_global_seed,
)

warnings.filterwarnings("ignore")
SEED = 42
set_global_seed(SEED)

DATASET_NAME = "CIF Monthly"
DATASET_SLUG = "cif"
SERIES_ID = None
SERIES_POSITION = 0
SEASONAL_PERIOD = 12
ALPHA = 0.10
VAL_SIZE = 12
APPLY_LOG_IF_POSITIVE = True
BASELINE_CALIBRATION_RATIO = 0.20
BASELINE_ACI_STEP_SIZE = 0.05

RUN_MODE = "paper"
if RUN_MODE == "paper":
    S3_POINT_TRIALS = 300
    S3_UQ_TRIALS = 200
    FASTSKETCH_POINT_TRIALS = 300
    FASTSKETCH_UQ_TRIALS = 200
else:
    S3_POINT_TRIALS = 10
    S3_UQ_TRIALS = 10
    FASTSKETCH_POINT_TRIALS = 10
    FASTSKETCH_UQ_TRIALS = 10

RUN_NEURAL_BASELINES = True
RUN_ARKAN = True

OUTPUT_DIR = Path(
    f"/kaggle/working/{DATASET_SLUG}_s3_results"
)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
RUN_CHRONOS_BASELINE = True
RUN_CHRONOS_PRIOR = True

CHRONOS_KWARGS = {
    "model_id": "amazon/chronos-bolt-small",
    "device_map": "cpu",
}

print({
    "dataset": DATASET_NAME,
    "series_id": SERIES_ID,
    "series_position": SERIES_POSITION,
    "run_mode": RUN_MODE,
    "device": "cpu",
    "s3_trials": (S3_POINT_TRIALS, S3_UQ_TRIALS),
    "fastsketch_trials": (
        FASTSKETCH_POINT_TRIALS,
        FASTSKETCH_UQ_TRIALS,
    ),
    "output_dir": str(OUTPUT_DIR),
})
# Out:
# 2026-07-03 20:19:22.718540: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# {'dataset': 'CIF Monthly', 'series_id': None, 'series_position': 0, 'run_mode': 'paper', 'device': 'cpu', 's3_trials': (300, 200), 'fastsketch_trials': (300, 200), 'output_dir': '/kaggle/working/cif_s3_results'}

# %% [markdown]
# ### Optional dependency for ARKAN

# %%
if RUN_ARKAN:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "pykan"],
        check=True,
    )
    print("Optional ARKAN dependency installed.")

if RUN_CHRONOS_BASELINE or RUN_CHRONOS_PRIOR:
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "chronos-forecasting>=2.3"],
        check=True,
    )
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.1/78.1 kB 2.6 MB/s eta 0:00:00
# Optional ARKAN dependency installed.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 3.1 MB/s eta 0:00:00

# %% [markdown]
# ## 3. Load the CIF Monthly series

# %%
from pathlib import Path
import re

DATASET_KEYWORDS = ['cif-dataset', 'cif_dataset', 'cif']
SERIES_FILE_EXTENSIONS = ['.ts', '.tsf']


def locate_series_file(search_root=Path("/kaggle/input")):
    search_root = Path(search_root)
    candidates = [
        path
        for path in search_root.rglob("*")
        if path.is_file() and path.suffix.lower() in SERIES_FILE_EXTENSIONS
    ]
    if not candidates:
        raise FileNotFoundError(
            f"No {SERIES_FILE_EXTENSIONS} file was found below {search_root}."
        )

    def score(path):
        text = str(path).lower()
        keyword_score = sum(keyword in text for keyword in DATASET_KEYWORDS)
        monthly_score = int("monthly" in text)
        return (-keyword_score, -monthly_score, len(text))

    candidates.sort(key=score)
    selected = candidates[0]
    print("Selected dataset file:", selected)
    return selected


def parse_tsf_date(value):
    value = str(value).strip().replace(" 00-00-00", "")
    parsed = pd.to_datetime(value, errors="coerce")
    if pd.isna(parsed):
        match = re.match(r"(\d{4})-(\d{2})-(\d{2})", value)
        if not match:
            raise ValueError(f"Could not parse date attribute: {value!r}")
        parsed = pd.Timestamp(
            f"{match.group(1)}-{match.group(2)}-{match.group(3)}"
        )
    return pd.Timestamp(parsed)


def parse_tsf_file(path):
    path = Path(path)
    metadata = {
        "frequency": None,
        "horizon": None,
        "missing": None,
        "equallength": None,
        "relation": None,
        "attributes": [],
    }

    lines = None
    used_encoding = None
    for encoding in ("utf-8", "cp1252", "latin-1"):
        try:
            lines = path.read_text(encoding=encoding).splitlines()
            used_encoding = encoding
            break
        except UnicodeDecodeError:
            continue

    if lines is None:
        raise UnicodeError(f"Could not decode {path}.")

    rows = []
    in_data = False

    for raw_line in lines:
        line = raw_line.strip()
        if not line or line.startswith("#"):
            continue

        lower = line.lower()
        if not in_data:
            if lower.startswith("@relation"):
                metadata["relation"] = line.split(maxsplit=1)[1].strip()
            elif lower.startswith("@attribute"):
                parts = line.split()
                if len(parts) >= 3:
                    metadata["attributes"].append(
                        (parts[1].strip(), parts[2].strip().lower())
                    )
            elif lower.startswith("@frequency"):
                metadata["frequency"] = line.split(maxsplit=1)[1].strip().lower()
            elif lower.startswith("@horizon"):
                metadata["horizon"] = int(float(line.split(maxsplit=1)[1].strip()))
            elif lower.startswith("@missing"):
                metadata["missing"] = (
                    line.split(maxsplit=1)[1].strip().lower() == "true"
                )
            elif lower.startswith("@equallength"):
                metadata["equallength"] = (
                    line.split(maxsplit=1)[1].strip().lower() == "true"
                )
            elif lower.startswith("@data"):
                in_data = True
            continue

        n_attributes = len(metadata["attributes"])
        parts = line.split(":", n_attributes)
        if len(parts) != n_attributes + 1:
            raise ValueError(
                f"Invalid TSF row: expected {n_attributes + 1} fields, "
                f"received {len(parts)}. Row={line[:160]!r}"
            )

        row = {}
        for (attribute_name, attribute_type), value in zip(
            metadata["attributes"], parts[:n_attributes]
        ):
            value = value.strip()
            if attribute_type in {
                "numeric", "integer", "int", "real", "float", "double"
            }:
                row[attribute_name] = float(value)
            elif attribute_type == "date":
                row[attribute_name] = parse_tsf_date(value)
            else:
                row[attribute_name] = value

        values = []
        for value in parts[-1].split(","):
            value = value.strip()
            if value in {"", "?"}:
                values.append(np.nan)
            else:
                values.append(float(value))
        row["values"] = np.asarray(values, dtype=float)
        rows.append(row)

    if not rows:
        raise ValueError(f"No time series were parsed from {path}.")

    print("TSF encoding:", used_encoding)
    return metadata, rows


def row_identifier(row, position):
    for key in ("series_name", "series_id", "id"):
        if key in row:
            return str(row[key])
    attribute_names = [name for name, _ in metadata["attributes"]]
    if attribute_names:
        return str(row.get(attribute_names[0], f"series_{position}"))
    return f"series_{position}"


def clean_values(values):
    values = pd.Series(np.asarray(values, dtype=float))
    missing_count = int(values.isna().sum())
    if missing_count:
        values = values.interpolate(limit_direction="both").ffill().bfill()
    if values.isna().any():
        raise ValueError("The selected series still contains missing values.")
    return values.to_numpy(dtype=float), missing_count


series_file = locate_series_file()
metadata, parsed_rows = parse_tsf_file(series_file)

if SERIES_ID is None:
    selected_position = int(SERIES_POSITION)
    if not 0 <= selected_position < len(parsed_rows):
        raise IndexError(
            f"SERIES_POSITION={selected_position} is outside "
            f"the available range 0..{len(parsed_rows)-1}."
        )
    selected_row = parsed_rows[selected_position]
    SERIES_ID = row_identifier(selected_row, selected_position)
else:
    selected_row = None
    for position, candidate in enumerate(parsed_rows):
        if row_identifier(candidate, position) == str(SERIES_ID):
            selected_row = candidate
            break
    if selected_row is None:
        raise KeyError(f"Series {SERIES_ID!r} was not found.")

horizon_value = selected_row.get("horizon", metadata.get("horizon"))
if horizon_value is None:
    raise ValueError(
        "The dataset does not provide a global or per-series forecast horizon."
    )
horizon = int(horizon_value)

full_values, missing_count = clean_values(selected_row["values"])
if horizon <= 0 or horizon >= len(full_values):
    raise ValueError(
        f"Invalid horizon={horizon} for series length={len(full_values)}."
    )

train_values = full_values[:-horizon]
test_values = full_values[-horizon:]

start_timestamp = selected_row.get("start_timestamp", pd.Timestamp("2000-01-01"))
start_timestamp = pd.Timestamp(start_timestamp)

train_index = pd.date_range(
    start=start_timestamp,
    periods=len(train_values),
    freq="MS",
)
test_index = pd.date_range(
    start=train_index[-1] + pd.offsets.MonthBegin(1),
    periods=len(test_values),
    freq="MS",
)

raw_train = pd.Series(train_values, index=train_index, name="y")
raw_test = pd.Series(test_values, index=test_index, name="y")

info_df = pd.DataFrame(
    [{
        "series_id": SERIES_ID,
        "relation": metadata.get("relation"),
        "frequency": metadata.get("frequency"),
        "horizon": horizon,
        "train_length": len(raw_train),
        "test_length": len(raw_test),
        "missing_values_imputed": missing_count,
        "source_file": str(series_file),
    }]
)

print("Selected series:", SERIES_ID)
print("Train length:", len(raw_train))
print("Test horizon:", len(raw_test))
display(info_df)
# Out:
# Selected dataset file: /kaggle/input/datasets/alejopatio/cif-dataset/cif_2016_dataset.ts
# TSF encoding: cp1252
# Selected series: T1
# Train length: 108
# Test horizon: 12
#   series_id  relation frequency  horizon  train_length  test_length  \
# 0        T1  CIF_2016   monthly       12           108           12
#
#    missing_values_imputed                                        source_file
# 0                       0  /kaggle/input/datasets/alejopatio/cif-dataset/...

# %% [markdown]
# ## 4. Preprocessing and visual inspection

# %%
train_series, test_series, transformation = apply_log_if_positive(
    raw_train,
    raw_test,
    enabled=APPLY_LOG_IF_POSITIVE,
)

print("Transformation:", transformation)
print("Train finite:", np.isfinite(train_series).all())
print("Test finite:", np.isfinite(test_series).all())

fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(raw_train.index, raw_train.values, label="Train")
ax.plot(raw_test.index, raw_test.values, label="Test")
ax.set_xlabel("Time")
ax.set_ylabel("CIF value")
ax.legend()
fig.tight_layout()
plt.show()
# Out:
# Transformation: log
# Train finite: True
# Test finite: True

# %% [markdown]
# ## 5. Fixed CIF Monthly baseline hyperparameters

# %%
BASELINE_PARAMS_ORIGINAL = {'CNN': {'input_window': 36,
         'filters': 96,
         'kernel_size': 3,
         'dropout': 0.06622251255415113,
         'dense_units': 32,
         'learning_rate': 0.001560230601036993,
         'batch_size': 8,
         'epochs': 120},
 'LSTM': {'n_layers': 1,
          'input_window': 40,
          'units_1': 32,
          'dropout': 0.055775401671866655,
          'dense_units': 128,
          'learning_rate': 0.00457452927556662,
          'batch_size': 16,
          'epochs': 130},
 'GaussianProcess': {'input_window': 11,
                     'kernel_type': 'matern32',
                     'length_scale': 1.1343330318588238,
                     'constant_value': 9.751694212319803,
                     'noise_level': 0.4778061060692703,
                     'alpha': 0.0005920498815183987,
                     'normalize_y': False},
 'KernelRidgeRegressor': {'kernel': 'linear', 'input_window': 31, 'alpha': 0.1881911740959234},
 'AR': {'lags': 1, 'trend': 't', 'seasonal': False},
 'ARIMA': {'p': 1, 'd': 0, 'q': 4, 'trend': 't'},
 'ARKAN': {'n_hidden_layers': 2,
           'window_size': 3,
           'h1': 187,
           'h2': 53,
           'grid': 9,
           'k': 4,
           'lr': 0.014411644831969477,
           'weight_decay': 0.0002687674155561058,
           'batch_size': 32,
           'max_epochs': 461,
           'clip_grad': 1.9310156373733873,
           'patience': 20},
 'EasyTSF': {'model_type': 'NLinear',
             'window_size': 4,
             'lr': 0.0005985624729868153,
             'weight_decay': 0.0016372550746123096,
             'batch_size': 16,
             'clip_grad': 4.586105224511578,
             'max_epochs': 230,
             'patience': 33},
 'ETS': {'error': 'add',
         'trend': 'add',
         'seasonal': 'add',
         'seasonal_periods': 12,
         'damped_trend': True}}


def adapt_original_baseline_params(original):
    compatibility_notes = {}

    gaussian_process = dict(original["GaussianProcess"])
    supported_gp_kernels = {"rbf", "matern32", "matern52"}
    if gaussian_process.get("kernel_type") not in supported_gp_kernels:
        reported_kernel = gaussian_process.get("kernel_type")
        gaussian_process["kernel_type"] = "matern52"
        compatibility_notes["GaussianProcess"] = (
            f"The original notebook reports kernel_type={reported_kernel!r}, "
            "which is not supported by the repository and was not part of its "
            "reported search space. It is mapped to 'matern52' so the notebook "
            "is executable; the original value remains preserved in "
            "BASELINE_PARAMS_ORIGINAL."
        )

    arkan_original = original["ARKAN"]
    adapted = {
        "CNN": dict(original["CNN"]),
        "LSTM": dict(original["LSTM"]),
        "GaussianProcess": gaussian_process,
        "KernelRidgeRegressor": dict(original["KernelRidgeRegressor"]),
        "AR": {**original["AR"], "period": SEASONAL_PERIOD},
        "ARIMA": dict(original["ARIMA"]),
        "ARKAN": {
            "n_hidden_layers": arkan_original["n_hidden_layers"],
            "window_size": arkan_original["window_size"],
            "h1": arkan_original["h1"],
            "h2": arkan_original.get("h2", 4),
            "grid": arkan_original["grid"],
            "k": arkan_original["k"],
            "learning_rate": arkan_original["lr"],
            "weight_decay": arkan_original["weight_decay"],
            "batch_size": arkan_original["batch_size"],
            "epochs": arkan_original["max_epochs"],
            "clip_grad": arkan_original["clip_grad"],
            "patience": arkan_original["patience"],
        },
        "NLinear": {
            "window_size": original["EasyTSF"]["window_size"],
            "learning_rate": original["EasyTSF"]["lr"],
            "weight_decay": original["EasyTSF"]["weight_decay"],
            "batch_size": original["EasyTSF"]["batch_size"],
            "clip_grad": original["EasyTSF"]["clip_grad"],
            "epochs": original["EasyTSF"]["max_epochs"],
            "patience": original["EasyTSF"]["patience"],
        },
        "ETS": dict(original["ETS"]),
    }
    return adapted, compatibility_notes


BASELINE_PARAMS, BASELINE_COMPATIBILITY_NOTES = adapt_original_baseline_params(
    BASELINE_PARAMS_ORIGINAL
)
OMITTED_TRAINING_OPTIONS = {}

BASELINE_DISPLAY_NAMES = {
    "NLinear": "EasyTSF (NLinear)",
    "KernelRidgeRegressor": "Kernel Ridge",
    "GaussianProcess": "Gaussian Process",
}

BASELINE_ORDER = [
    "CNN",
    "LSTM",
    "GaussianProcess",
    "KernelRidgeRegressor",
    "AR",
    "ARIMA",
    "ARKAN",
    "NLinear",
    "ETS",
]

if not RUN_NEURAL_BASELINES:
    BASELINE_ORDER = [
        name
        for name in BASELINE_ORDER
        if name not in {"CNN", "LSTM", "NLinear"}
    ]
if not RUN_ARKAN:
    BASELINE_ORDER = [
        name
        for name in BASELINE_ORDER
        if name != "ARKAN"
    ]

BASELINE_DISPLAY_NAMES["Chronos"] = "Chronos"

if RUN_CHRONOS_BASELINE:
    BASELINE_PARAMS["Chronos"] = dict(CHRONOS_KWARGS)
    if "Chronos" not in BASELINE_ORDER:
        BASELINE_ORDER.append("Chronos")

print("Baselines to evaluate:", BASELINE_ORDER)
print("Original options not consumed by the repository classes:")
display(pd.DataFrame(OMITTED_TRAINING_OPTIONS).T)

if BASELINE_COMPATIBILITY_NOTES:
    print("Compatibility notes:")
    for model_name, note in BASELINE_COMPATIBILITY_NOTES.items():
        print(f"- {model_name}: {note}")
# Out:
# Baselines to evaluate: ['CNN', 'LSTM', 'GaussianProcess', 'KernelRidgeRegressor', 'AR', 'ARIMA', 'ARKAN', 'NLinear', 'ETS', 'Chronos']
# Original options not consumed by the repository classes:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 6. S3-Forecaster optimization and final test

# %%
s3_result = run_s3_experiment(
    train_series,
    test_series,
    point_trials=S3_POINT_TRIALS,
    uq_trials=S3_UQ_TRIALS,
    val_size=VAL_SIZE,
    seed=SEED,
)

print("S3-Forecaster best point parameters:")
print(s3_result["best_point_params"])
print("S3-Forecaster best UQ parameters:")
print(s3_result["best_uq_params"])
print("S3-Forecaster test metrics on modelling scale:")
display(pd.DataFrame([s3_result["metrics"]]))
# Out:
# [I 2026-07-03 20:19:36,223] A new study created in memory with name: no-name-adadec5a-f4d4-4295-a85d-4582e8e64774
# [I 2026-07-03 20:19:36,346] Trial 0 finished with value: 0.0038923414152562973 and parameters: {'reservoir_size': 75, 'spectral_radius': 1.4507143064099162, 'ar_lags': 10, 'foundation_window': 16, 'regressor_type': 'Ridge', 'reg_alpha': 21.76624112345367, 'aci_step_size': 0.12421185223120967, 'oob_split_ratio': 0.7770181444490114}. Best is trial 0 with value: 0.0038923414152562973.
# [I 2026-07-03 20:19:36,418] Trial 1 finished with value: 0.006383734018136214 and parameters: {'reservoir_size': 5, 'spectral_radius': 1.4699098521619942, 'ar_lags': 11, 'foundation_window': 7, 'regressor_type': 'Lasso', 'reg_alpha': 2.6079656598095835, 'aci_step_size': 0.092069553542002, 'oob_split_ratio': 0.6728072850495105}. Best is trial 0 with value: 0.0038923414152562973.
# [I 2026-07-03 20:19:36,648] Trial 2 finished with value: 0.004565447467238669 and parameters: {'reservoir_size': 123, 'spectral_radius': 0.6394938606520418, 'ar_lags': 5, 'foundation_window': 11, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.442886696734996, 'aci_step_size': 0.12255876808378806, 'oob_split_ratio': 0.6116126031799994}. Best is trial 0 with value: 0.0038923414152562973.
# [I 2026-07-03 20:19:36,818] Trial 3 finished with value: 0.0038665376692551125 and parameters: {'reservoir_size': 122, 'spectral_radius': 0.6705241236872915, 'ar_lags': 2, 'foundation_window': 23, 'regressor_type': 'Ridge', 'reg_alpha': 0.18349072049055454, 'aci_step_size': 0.14000427503730983, 'oob_split_ratio': 0.7100381234349002}. Best is trial 3 with value: 0.0038665376692551125.
# [I 2026-07-03 20:19:36,889] Trial 4 finished with value: 0.0033418573304735814 and parameters: {'reservoir_size': 25, 'spectral_radius': 0.9951769101112702, 'ar_lags': 2, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.533074654001447, 'aci_step_size': 0.11387495307522313, 'oob_split_ratio': 0.6462136138813818}. Best is trial 4 with value: 0.0033418573304735814.
# [I 2026-07-03 20:19:37,038] Trial 5 finished with value: 0.003339910408775291 and parameters: {'reservoir_size': 194, 'spectral_radius': 1.2751328233611146, 'ar_lags': 12, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.3380273704712439, 'aci_step_size': 0.018593184893002233, 'oob_split_ratio': 0.6813325826908161}. Best is trial 5 with value: 0.003339910408775291.
# [I 2026-07-03 20:19:37,105] Trial 6 finished with value: 0.0039347757998878475 and parameters: {'reservoir_size': 78, 'spectral_radius': 0.7713490317738959, 'ar_lags': 11, 'foundation_window': 10, 'regressor_type': 'ElasticNet', 'reg_alpha': 14.625327121207683, 'aci_step_size': 0.024164622299156457, 'oob_split_ratio': 0.8467217341501293}. Best is trial 5 with value: 0.003339910408775291.
# [I 2026-07-03 20:19:37,221] Trial 7 finished with value: 0.0033652237898193263 and parameters: {'reservoir_size': 155, 'spectral_radius': 0.6987156815341724, 'ar_lags': 2, 'foundation_window': 20, 'regressor_type': 'Lasso', 'reg_alpha': 0.15843250684388685, 'aci_step_size': 0.0781084884234118, 'oob_split_ratio': 0.6289672648812824}. Best is trial 5 with value: 0.003339910408775291.
# [I 2026-07-03 20:19:37,377] Trial 8 finished with value: 0.0042016750981911976 and parameters: {'reservoir_size': 173, 'spectral_radius': 1.123298126827558, 'ar_lags': 5, 'foundation_window': 4, 'regressor_type': 'Lasso', 'reg_alpha': 5.257127272786866, 'aci_step_size': 0.17857042108950205, 'oob_split_ratio': 0.7180537312904873}. Best is trial 5 with value: 0.003339910408775291.
# [I 2026-07-03 20:19:37,457] Trial 9 finished with value: 0.0036954311126523357 and parameters: {'reservoir_size': 24, 'spectral_radius': 1.213244787222995, 'ar_lags': 10, 'foundation_window': 15, 'regressor_type': 'Ridge', 'reg_alpha': 1.4253462720121493, 'aci_step_size': 0.014829634081378086, 'oob_split_ratio': 0.6269728567483261}. Best is trial 5 with value: 0.003339910408775291.
# [I 2026-07-03 20:19:37,599] Trial 10 finished with value: 0.00364108401923667 and parameters: {'reservoir_size': 195, 'spectral_radius': 0.5059971829558172, 'ar_lags': 7, 'foundation_window': 17, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.6474637253710466, 'aci_step_size': 0.1923564417296298, 'oob_split_ratio': 0.7917539222238852}. Best is trial 5 with value: 0.003339910408775291.
# [I 2026-07-03 20:19:37,690] Trial 11 finished with value: 0.0033378983630106937 and parameters: {'reservoir_size': 56, 'spectral_radius': 1.0265920553944767, 'ar_lags': 8, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.5268069164082507, 'aci_step_size': 0.05983156197453722, 'oob_split_ratio': 0.6734364048648069}. Best is trial 11 with value: 0.0033378983630106937.
# [I 2026-07-03 20:19:37,786] Trial 12 finished with value: 0.0033755321559139745 and parameters: {'reservoir_size': 86, 'spectral_radius': 1.2676259977007913, 'ar_lags': 8, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.44661509763050367, 'aci_step_size': 0.053279815549930325, 'oob_split_ratio': 0.6943735713463794}. Best is trial 11 with value: 0.0033378983630106937.
# [I 2026-07-03 20:19:37,889] Trial 13 finished with value: 0.0035293815574457678 and parameters: {'reservoir_size': 126, 'spectral_radius': 0.9428959292826298, 'ar_lags': 12, 'foundation_window': 18, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.5293890714769286, 'aci_step_size': 0.04908055471420597, 'oob_split_ratio': 0.7317912058023405}. Best is trial 11 with value: 0.0033378983630106937.
# [I 2026-07-03 20:19:38,002] Trial 14 finished with value: 0.0033490067202206594 and parameters: {'reservoir_size': 50, 'spectral_radius': 1.3149074387957944, 'ar_lags': 8, 'foundation_window': 20, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.11261644110196563, 'aci_step_size': 0.045199350482976026, 'oob_split_ratio': 0.6677286607036933}. Best is trial 11 with value: 0.0033378983630106937.
# [I 2026-07-03 20:19:38,185] Trial 15 finished with value: 0.0033257718238789845 and parameters: {'reservoir_size': 200, 'spectral_radius': 1.0311240303514604, 'ar_lags': 6, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.3084108239925509, 'aci_step_size': 0.07076221027927616, 'oob_split_ratio': 0.671977324866266}. Best is trial 15 with value: 0.0033257718238789845.
# [I 2026-07-03 20:19:38,330] Trial 16 finished with value: 0.0034525893982697425 and parameters: {'reservoir_size': 151, 'spectral_radius': 0.9445658946145193, 'ar_lags': 5, 'foundation_window': 20, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.1411970994156353, 'aci_step_size': 0.08281076336814781, 'oob_split_ratio': 0.7539931378657342}. Best is trial 15 with value: 0.0033257718238789845.
# [I 2026-07-03 20:19:38,452] Trial 17 finished with value: 0.004222131625698456 and parameters: {'reservoir_size': 98, 'spectral_radius': 1.0547251853263182, 'ar_lags': 7, 'foundation_window': 13, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.30663233119591665, 'aci_step_size': 0.06635084224712481, 'oob_split_ratio': 0.6533208339077805}. Best is trial 15 with value: 0.0033257718238789845.
# [I 2026-07-03 20:19:38,566] Trial 18 finished with value: 0.003375716288490231 and parameters: {'reservoir_size': 54, 'spectral_radius': 0.8613875687871195, 'ar_lags': 4, 'foundation_window': 21, 'regressor_type': 'Lasso', 'reg_alpha': 0.9728861510909153, 'aci_step_size': 0.09541594162054969, 'oob_split_ratio': 0.7473843624734245}. Best is trial 15 with value: 0.0033257718238789845.
# [I 2026-07-03 20:19:38,696] Trial 19 finished with value: 0.004770539421789739 and parameters: {'reservoir_size': 106, 'spectral_radius': 1.1677924495840923, 'ar_lags': 7, 'foundation_window': 24, 'regressor_type': 'Ridge', 'reg_alpha': 5.8971561918008835, 'aci_step_size': 0.15929938415338968, 'oob_split_ratio': 0.7087390444700347}. Best is trial 15 with value: 0.0033257718238789845.
# [I 2026-07-03 20:19:38,879] Trial 20 finished with value: 0.00348115603629612 and parameters: {'reservoir_size': 151, 'spectral_radius': 0.8417635290416065, 'ar_lags': 9, 'foundation_window': 18, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.1986156377185969, 'aci_step_size': 0.034603657910975145, 'oob_split_ratio': 0.6100893526010003}. Best is trial 15 with value: 0.0033257718238789845.
# [I 2026-07-03 20:19:39,039] Trial 21 finished with value: 0.003334376041883663 and parameters: {'reservoir_size': 200, 'spectral_radius': 1.3500668693492142, 'ar_lags': 6, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.3266945579089226, 'aci_step_size': 0.061878601777694865, 'oob_split_ratio': 0.6850948346085195}. Best is trial 15 with value: 0.0033257718238789845.
# [I 2026-07-03 20:19:39,181] Trial 22 finished with value: 0.003307875021592121 and parameters: {'reservoir_size': 174, 'spectral_radius': 1.373142428521872, 'ar_lags': 6, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.2810062876535778, 'aci_step_size': 0.06739010300201942, 'oob_split_ratio': 0.6499602962546788}. Best is trial 22 with value: 0.003307875021592121.
# [I 2026-07-03 20:19:39,335] Trial 23 finished with value: 0.003400532904777863 and parameters: {'reservoir_size': 177, 'spectral_radius': 1.3962094961977074, 'ar_lags': 6, 'foundation_window': 19, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.26752666950547743, 'aci_step_size': 0.07129010785240768, 'oob_split_ratio': 0.6352719597125892}. Best is trial 22 with value: 0.003307875021592121.
# [I 2026-07-03 20:19:39,477] Trial 24 finished with value: 0.003305716165698681 and parameters: {'reservoir_size': 179, 'spectral_radius': 1.3510132170389462, 'ar_lags': 4, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.11955311354558766, 'aci_step_size': 0.09075315045601753, 'oob_split_ratio': 0.6533544742631381}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:39,669] Trial 25 finished with value: 0.003898028232724396 and parameters: {'reservoir_size': 181, 'spectral_radius': 1.1146343654052024, 'ar_lags': 4, 'foundation_window': 15, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.11712601486474643, 'aci_step_size': 0.09808102078575569, 'oob_split_ratio': 0.6511178517985496}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:39,803] Trial 26 finished with value: 0.0033901713622715556 and parameters: {'reservoir_size': 165, 'spectral_radius': 1.3876490096706746, 'ar_lags': 3, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.10870375890110157, 'aci_step_size': 0.11013944234130954, 'oob_split_ratio': 0.6041389958821448}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:40,023] Trial 27 finished with value: 0.003453647361612685 and parameters: {'reservoir_size': 139, 'spectral_radius': 1.2185139768199167, 'ar_lags': 4, 'foundation_window': 18, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.7439460001690228, 'aci_step_size': 0.034312119511320224, 'oob_split_ratio': 0.6610556146650607}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:40,191] Trial 28 finished with value: 0.0033560556750261805 and parameters: {'reservoir_size': 184, 'spectral_radius': 1.4621653341364202, 'ar_lags': 6, 'foundation_window': 22, 'regressor_type': 'Lasso', 'reg_alpha': 47.273634111974594, 'aci_step_size': 0.08527381635922907, 'oob_split_ratio': 0.6937442572065572}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:40,332] Trial 29 finished with value: 0.0045028273153527075 and parameters: {'reservoir_size': 164, 'spectral_radius': 1.3715952827080182, 'ar_lags': 3, 'foundation_window': 16, 'regressor_type': 'Ridge', 'reg_alpha': 0.22008476777092637, 'aci_step_size': 0.13983138434927644, 'oob_split_ratio': 0.6362804131070253}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:40,513] Trial 30 finished with value: 0.004796417563071844 and parameters: {'reservoir_size': 137, 'spectral_radius': 1.1072555133210167, 'ar_lags': 5, 'foundation_window': 19, 'regressor_type': 'Ridge', 'reg_alpha': 0.15861760371293887, 'aci_step_size': 0.10864559759243637, 'oob_split_ratio': 0.7751316741146226}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:40,778] Trial 31 finished with value: 0.0033560556750261805 and parameters: {'reservoir_size': 199, 'spectral_radius': 1.3341843298569376, 'ar_lags': 6, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.3653275698546264, 'aci_step_size': 0.07076653120479319, 'oob_split_ratio': 0.6886878864706945}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:40,971] Trial 32 finished with value: 0.003316649207044601 and parameters: {'reservoir_size': 186, 'spectral_radius': 1.4294995395927146, 'ar_lags': 6, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.27091036693293125, 'aci_step_size': 0.06096319154661023, 'oob_split_ratio': 0.6651610569235271}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:41,130] Trial 33 finished with value: 0.0033370449474967117 and parameters: {'reservoir_size': 185, 'spectral_radius': 1.495900424530075, 'ar_lags': 7, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.23036595790598766, 'aci_step_size': 0.040529682616652865, 'oob_split_ratio': 0.6626277814049618}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:41,328] Trial 34 finished with value: 0.0034106864497156103 and parameters: {'reservoir_size': 167, 'spectral_radius': 1.4251392057846117, 'ar_lags': 4, 'foundation_window': 19, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.14138942425614284, 'aci_step_size': 0.08627270156819113, 'oob_split_ratio': 0.6212789802324371}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:41,562] Trial 35 finished with value: 0.0033520603357913158 and parameters: {'reservoir_size': 187, 'spectral_radius': 1.4406807335354375, 'ar_lags': 5, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.6142990325685462, 'aci_step_size': 0.0976841407827495, 'oob_split_ratio': 0.6493913819982733}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:41,779] Trial 36 finished with value: 0.0033839413560175628 and parameters: {'reservoir_size': 168, 'spectral_radius': 1.2681405741037168, 'ar_lags': 3, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.762436950077437, 'aci_step_size': 0.12306445827407048, 'oob_split_ratio': 0.7063303669266444}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:41,904] Trial 37 finished with value: 0.0033257718238789845 and parameters: {'reservoir_size': 156, 'spectral_radius': 1.4932386863865053, 'ar_lags': 6, 'foundation_window': 21, 'regressor_type': 'Lasso', 'reg_alpha': 0.45524068604650714, 'aci_step_size': 0.055699168552268294, 'oob_split_ratio': 0.6717609681649891}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:42,109] Trial 38 finished with value: 0.006333093693081515 and parameters: {'reservoir_size': 141, 'spectral_radius': 1.2057561392220941, 'ar_lags': 7, 'foundation_window': 7, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.20109504334619702, 'aci_step_size': 0.07426141731114609, 'oob_split_ratio': 0.6396079687314181}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:42,314] Trial 39 finished with value: 0.003592275063483386 and parameters: {'reservoir_size': 189, 'spectral_radius': 1.3024457531388358, 'ar_lags': 9, 'foundation_window': 17, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.2575785709049964, 'aci_step_size': 0.026438218717624792, 'oob_split_ratio': 0.6143052633894694}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:42,540] Trial 40 finished with value: 0.004335136169424109 and parameters: {'reservoir_size': 174, 'spectral_radius': 1.4208193555641664, 'ar_lags': 5, 'foundation_window': 23, 'regressor_type': 'Ridge', 'reg_alpha': 0.10228238006653452, 'aci_step_size': 0.13193287998522066, 'oob_split_ratio': 0.6761895381212043}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:42,767] Trial 41 finished with value: 0.003316649207044601 and parameters: {'reservoir_size': 157, 'spectral_radius': 1.4845744976465598, 'ar_lags': 6, 'foundation_window': 21, 'regressor_type': 'Lasso', 'reg_alpha': 0.40648320353415446, 'aci_step_size': 0.05631125262976994, 'oob_split_ratio': 0.6615543890589483}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:42,933] Trial 42 finished with value: 0.003359638544931267 and parameters: {'reservoir_size': 158, 'spectral_radius': 1.372006830124303, 'ar_lags': 6, 'foundation_window': 20, 'regressor_type': 'Lasso', 'reg_alpha': 0.37966374362556354, 'aci_step_size': 0.06361319357018351, 'oob_split_ratio': 0.6595978693092024}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:43,138] Trial 43 finished with value: 0.003307875021592121 and parameters: {'reservoir_size': 174, 'spectral_radius': 1.4525293527641372, 'ar_lags': 6, 'foundation_window': 22, 'regressor_type': 'Lasso', 'reg_alpha': 0.17419294799136956, 'aci_step_size': 0.08057840794874738, 'oob_split_ratio': 0.6459498094114329}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:43,357] Trial 44 finished with value: 0.00336042915118881 and parameters: {'reservoir_size': 145, 'spectral_radius': 1.432128587644772, 'ar_lags': 8, 'foundation_window': 24, 'regressor_type': 'Lasso', 'reg_alpha': 0.17319162840387298, 'aci_step_size': 0.08122459587854704, 'oob_split_ratio': 0.6446217888589824}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:43,527] Trial 45 finished with value: 0.004003736762597126 and parameters: {'reservoir_size': 123, 'spectral_radius': 1.4669901011381665, 'ar_lags': 5, 'foundation_window': 22, 'regressor_type': 'Lasso', 'reg_alpha': 0.133300381917512, 'aci_step_size': 0.10491856190621646, 'oob_split_ratio': 0.8429113191223484}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:43,669] Trial 46 finished with value: 0.003408603674933569 and parameters: {'reservoir_size': 176, 'spectral_radius': 1.3292117466400257, 'ar_lags': 7, 'foundation_window': 20, 'regressor_type': 'Lasso', 'reg_alpha': 0.5375584279852056, 'aci_step_size': 0.09038545818419011, 'oob_split_ratio': 0.6204391941540778}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:43,834] Trial 47 finished with value: 0.004667907432120604 and parameters: {'reservoir_size': 131, 'spectral_radius': 1.2601768164177223, 'ar_lags': 4, 'foundation_window': 3, 'regressor_type': 'Lasso', 'reg_alpha': 0.1627228117834529, 'aci_step_size': 0.0504559295878054, 'oob_split_ratio': 0.6337885053083055}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:43,974] Trial 48 finished with value: 0.0033920472837807906 and parameters: {'reservoir_size': 162, 'spectral_radius': 1.3933445553149413, 'ar_lags': 2, 'foundation_window': 23, 'regressor_type': 'Lasso', 'reg_alpha': 0.23716975553020123, 'aci_step_size': 0.0451434427469566, 'oob_split_ratio': 0.7008800640118695}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:44,107] Trial 49 finished with value: 0.003427739885843578 and parameters: {'reservoir_size': 149, 'spectral_radius': 1.2935009908156465, 'ar_lags': 9, 'foundation_window': 19, 'regressor_type': 'Lasso', 'reg_alpha': 0.4192589621801453, 'aci_step_size': 0.07867714268958882, 'oob_split_ratio': 0.6813691664321971}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:44,301] Trial 50 finished with value: 0.0033270694131170876 and parameters: {'reservoir_size': 191, 'spectral_radius': 1.4876998569362427, 'ar_lags': 5, 'foundation_window': 22, 'regressor_type': 'Lasso', 'reg_alpha': 0.6415568346425792, 'aci_step_size': 0.11786007243466659, 'oob_split_ratio': 0.6541061916005066}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:44,501] Trial 51 finished with value: 0.0033257718238789845 and parameters: {'reservoir_size': 172, 'spectral_radius': 0.6432305185839629, 'ar_lags': 6, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.3080424687967906, 'aci_step_size': 0.05937289132168779, 'oob_split_ratio': 0.669170640331499}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:44,700] Trial 52 finished with value: 0.0034447548930321534 and parameters: {'reservoir_size': 191, 'spectral_radius': 0.5806634205785264, 'ar_lags': 7, 'foundation_window': 20, 'regressor_type': 'Lasso', 'reg_alpha': 0.26424820770685153, 'aci_step_size': 0.06756618950466566, 'oob_split_ratio': 0.7200989395895482}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:44,888] Trial 53 finished with value: 0.00337383217871986 and parameters: {'reservoir_size': 180, 'spectral_radius': 1.442546065674771, 'ar_lags': 6, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.1720549259326079, 'aci_step_size': 0.07566932661233547, 'oob_split_ratio': 0.6789712111812739}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:45,096] Trial 54 finished with value: 0.003336283618393004 and parameters: {'reservoir_size': 197, 'spectral_radius': 0.8017394850979683, 'ar_lags': 7, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.3249945904134135, 'aci_step_size': 0.0904123870573961, 'oob_split_ratio': 0.6274253099446665}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:45,313] Trial 55 finished with value: 0.0033096717515099044 and parameters: {'reservoir_size': 173, 'spectral_radius': 0.7356932420242067, 'ar_lags': 8, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.13384994498409683, 'aci_step_size': 0.05696814735341227, 'oob_split_ratio': 0.6443619801818883}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:45,463] Trial 56 finished with value: 0.003372603984355094 and parameters: {'reservoir_size': 175, 'spectral_radius': 0.7261069265339829, 'ar_lags': 11, 'foundation_window': 23, 'regressor_type': 'Lasso', 'reg_alpha': 0.1402739351256436, 'aci_step_size': 0.05438751342572005, 'oob_split_ratio': 0.6449007902873588}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:45,642] Trial 57 finished with value: 0.0035616323095497334 and parameters: {'reservoir_size': 162, 'spectral_radius': 1.3473652281908042, 'ar_lags': 8, 'foundation_window': 22, 'regressor_type': 'Ridge', 'reg_alpha': 0.1914311466752936, 'aci_step_size': 0.03938560060863554, 'oob_split_ratio': 0.6617159665070683}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:45,774] Trial 58 finished with value: 0.003434561220206954 and parameters: {'reservoir_size': 114, 'spectral_radius': 0.961677072731498, 'ar_lags': 8, 'foundation_window': 18, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.13505273281501365, 'aci_step_size': 0.010810473233398926, 'oob_split_ratio': 0.6421571499172825}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:45,873] Trial 59 finished with value: 0.003361677420154425 and parameters: {'reservoir_size': 13, 'spectral_radius': 0.8947628606255013, 'ar_lags': 10, 'foundation_window': 20, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.5174498567608087, 'aci_step_size': 0.025208550688402394, 'oob_split_ratio': 0.6551939334108275}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:46,081] Trial 60 finished with value: 0.0033848678975543045 and parameters: {'reservoir_size': 156, 'spectral_radius': 0.5471479907178489, 'ar_lags': 5, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.9334752035129669, 'aci_step_size': 0.10091624477011608, 'oob_split_ratio': 0.6252567339804415}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:46,278] Trial 61 finished with value: 0.0033257718238789845 and parameters: {'reservoir_size': 182, 'spectral_radius': 1.0068055833350933, 'ar_lags': 6, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.2665432032377876, 'aci_step_size': 0.06447617704156605, 'oob_split_ratio': 0.6677609125780173}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:46,431] Trial 62 finished with value: 0.003379374521510193 and parameters: {'reservoir_size': 170, 'spectral_radius': 1.407226522325281, 'ar_lags': 6, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.20738182741781105, 'aci_step_size': 0.07220565622348188, 'oob_split_ratio': 0.6935128360621489}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:46,617] Trial 63 finished with value: 0.0034353902666313997 and parameters: {'reservoir_size': 194, 'spectral_radius': 1.1467629322264237, 'ar_lags': 7, 'foundation_window': 19, 'regressor_type': 'ElasticNet', 'reg_alpha': 7.147458467935256, 'aci_step_size': 0.057888618834222055, 'oob_split_ratio': 0.6503809891539463}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:46,848] Trial 64 finished with value: 0.0033968710645207703 and parameters: {'reservoir_size': 182, 'spectral_radius': 1.0598243338967133, 'ar_lags': 4, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.10813583844801147, 'aci_step_size': 0.04737452113997179, 'oob_split_ratio': 0.6015997656677076}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:47,014] Trial 65 finished with value: 0.005005029386896176 and parameters: {'reservoir_size': 200, 'spectral_radius': 1.468212639191704, 'ar_lags': 3, 'foundation_window': 10, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.3755616285322308, 'aci_step_size': 0.0831464898384456, 'oob_split_ratio': 0.6861204193236001}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:47,218] Trial 66 finished with value: 0.00332902139244185 and parameters: {'reservoir_size': 189, 'spectral_radius': 1.3758421273155492, 'ar_lags': 5, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.3092488322362677, 'aci_step_size': 0.19972192845934014, 'oob_split_ratio': 0.6340111887485457}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:47,444] Trial 67 finished with value: 0.0033257718238789845 and parameters: {'reservoir_size': 170, 'spectral_radius': 1.241521138268946, 'ar_lags': 6, 'foundation_window': 21, 'regressor_type': 'Lasso', 'reg_alpha': 0.1305272808512838, 'aci_step_size': 0.06820391376286405, 'oob_split_ratio': 0.6668694832471894}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:47,602] Trial 68 finished with value: 0.0053431790535691595 and parameters: {'reservoir_size': 150, 'spectral_radius': 1.0819963477994206, 'ar_lags': 7, 'foundation_window': 20, 'regressor_type': 'Ridge', 'reg_alpha': 0.6484570751755581, 'aci_step_size': 0.09075169113931633, 'oob_split_ratio': 0.6130812079326114}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:47,742] Trial 69 finished with value: 0.0036261071943186163 and parameters: {'reservoir_size': 185, 'spectral_radius': 0.7135171635116319, 'ar_lags': 9, 'foundation_window': 17, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.21313804429769628, 'aci_step_size': 0.033967025552593594, 'oob_split_ratio': 0.676097307718877}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:47,944] Trial 70 finished with value: 0.006332896843311152 and parameters: {'reservoir_size': 161, 'spectral_radius': 1.1847226698633335, 'ar_lags': 5, 'foundation_window': 7, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.16110196213492478, 'aci_step_size': 0.16561113031392116, 'oob_split_ratio': 0.6585071553893032}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:48,089] Trial 71 finished with value: 0.0033257718238789845 and parameters: {'reservoir_size': 153, 'spectral_radius': 1.4963508468659594, 'ar_lags': 6, 'foundation_window': 21, 'regressor_type': 'Lasso', 'reg_alpha': 0.45585304105425556, 'aci_step_size': 0.05636997836616703, 'oob_split_ratio': 0.6686899321827922}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:48,230] Trial 72 finished with value: 0.003341139070090305 and parameters: {'reservoir_size': 176, 'spectral_radius': 1.4504200718186426, 'ar_lags': 6, 'foundation_window': 23, 'regressor_type': 'Lasso', 'reg_alpha': 0.4366041502114393, 'aci_step_size': 0.0629407175158175, 'oob_split_ratio': 0.6737942304653476}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:48,395] Trial 73 finished with value: 0.003329801720383942 and parameters: {'reservoir_size': 133, 'spectral_radius': 1.4093046632994468, 'ar_lags': 7, 'foundation_window': 21, 'regressor_type': 'Lasso', 'reg_alpha': 0.27209423239274166, 'aci_step_size': 0.07723581460969701, 'oob_split_ratio': 0.6466819362862146}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:48,529] Trial 74 finished with value: 0.0034140037937088297 and parameters: {'reservoir_size': 158, 'spectral_radius': 1.497620831821291, 'ar_lags': 6, 'foundation_window': 19, 'regressor_type': 'Lasso', 'reg_alpha': 0.4972937310120394, 'aci_step_size': 0.05241274101445127, 'oob_split_ratio': 0.639692250242158}. Best is trial 24 with value: 0.003305716165698681.
# [I 2026-07-03 20:19:48,715] Trial 75 finished with value: 0.0032851438699171114 and parameters: {'reservoir_size': 144, 'spectral_radius': 1.347382332775692, 'ar_lags': 8, 'foundation_window': 21, 'regressor_type': 'Lasso', 'reg_alpha': 0.36547920155034824, 'aci_step_size': 0.04549638804319939, 'oob_split_ratio': 0.6528416195277348}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:48,895] Trial 76 finished with value: 0.0033224644779140562 and parameters: {'reservoir_size': 143, 'spectral_radius': 1.3496849541449536, 'ar_lags': 10, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.3562706120808777, 'aci_step_size': 0.043105953418301035, 'oob_split_ratio': 0.6547556252366054}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:49,033] Trial 77 finished with value: 0.0033681409171204585 and parameters: {'reservoir_size': 146, 'spectral_radius': 1.3012311546014186, 'ar_lags': 11, 'foundation_window': 23, 'regressor_type': 'Lasso', 'reg_alpha': 0.10007453492433584, 'aci_step_size': 0.0303688563834433, 'oob_split_ratio': 0.653255867935703}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:49,230] Trial 78 finished with value: 0.0033830678824700497 and parameters: {'reservoir_size': 141, 'spectral_radius': 1.3552683662091898, 'ar_lags': 12, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.380644928995946, 'aci_step_size': 0.040910447021086885, 'oob_split_ratio': 0.6301785893261835}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:49,347] Trial 79 finished with value: 0.0033230329023870124 and parameters: {'reservoir_size': 118, 'spectral_radius': 1.3181778141981941, 'ar_lags': 9, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 3.3535699522081868, 'aci_step_size': 0.01911289697517246, 'oob_split_ratio': 0.6633786672446004}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:49,520] Trial 80 finished with value: 0.003398776611130267 and parameters: {'reservoir_size': 167, 'spectral_radius': 1.3567315228021253, 'ar_lags': 10, 'foundation_window': 20, 'regressor_type': 'Lasso', 'reg_alpha': 0.5806752202484253, 'aci_step_size': 0.044222323747728484, 'oob_split_ratio': 0.6203769132701673}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:49,670] Trial 81 finished with value: 0.0033230329023870124 and parameters: {'reservoir_size': 134, 'spectral_radius': 1.3914984901748644, 'ar_lags': 9, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 11.152564815298788, 'aci_step_size': 0.03639195491382979, 'oob_split_ratio': 0.6605256719103255}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:49,790] Trial 82 finished with value: 0.003315439471540175 and parameters: {'reservoir_size': 89, 'spectral_radius': 1.2354934457406217, 'ar_lags': 10, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 3.6064900718059736, 'aci_step_size': 0.050424321909750616, 'oob_split_ratio': 0.6422640846074611}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:49,893] Trial 83 finished with value: 0.0033467736519155883 and parameters: {'reservoir_size': 67, 'spectral_radius': 1.2414138283997556, 'ar_lags': 11, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 4.536721347293145, 'aci_step_size': 0.04984025179991204, 'oob_split_ratio': 0.6377946729295623}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:50,077] Trial 84 finished with value: 0.003347005540941543 and parameters: {'reservoir_size': 92, 'spectral_radius': 1.421361786111558, 'ar_lags': 10, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.8603899956508345, 'aci_step_size': 0.060031185261488186, 'oob_split_ratio': 0.647749521512302}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:50,180] Trial 85 finished with value: 0.003326433117479675 and parameters: {'reservoir_size': 35, 'spectral_radius': 1.2931041395540026, 'ar_lags': 10, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 32.87784870931516, 'aci_step_size': 0.04366675585744492, 'oob_split_ratio': 0.6563200250922469}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:50,286] Trial 86 finished with value: 0.0035626997142787498 and parameters: {'reservoir_size': 72, 'spectral_radius': 1.3339549121270544, 'ar_lags': 8, 'foundation_window': 23, 'regressor_type': 'Ridge', 'reg_alpha': 13.13151228193557, 'aci_step_size': 0.04926611922947849, 'oob_split_ratio': 0.6415278671390151}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:50,438] Trial 87 finished with value: 0.0033663928461178266 and parameters: {'reservoir_size': 166, 'spectral_radius': 1.4627039466105967, 'ar_lags': 10, 'foundation_window': 20, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.18788691646867653, 'aci_step_size': 0.06854302663384088, 'oob_split_ratio': 0.6313989731142503}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:50,648] Trial 88 finished with value: 0.0034238267183077493 and parameters: {'reservoir_size': 100, 'spectral_radius': 1.369823346746115, 'ar_lags': 8, 'foundation_window': 24, 'regressor_type': 'Lasso', 'reg_alpha': 18.974721856786925, 'aci_step_size': 0.08523114225648216, 'oob_split_ratio': 0.8305428835563168}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:50,815] Trial 89 finished with value: 0.003326947633367567 and parameters: {'reservoir_size': 180, 'spectral_radius': 1.4309482890268557, 'ar_lags': 9, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 0.12241974798452387, 'aci_step_size': 0.030506142588080945, 'oob_split_ratio': 0.68197973138135}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:50,996] Trial 90 finished with value: 0.003431978724128586 and parameters: {'reservoir_size': 110, 'spectral_radius': 1.3987319379735805, 'ar_lags': 2, 'foundation_window': 19, 'regressor_type': 'Lasso', 'reg_alpha': 0.23320578816136045, 'aci_step_size': 0.0546305326500915, 'oob_split_ratio': 0.647737568941215}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:51,128] Trial 91 finished with value: 0.003312163586580921 and parameters: {'reservoir_size': 128, 'spectral_radius': 1.3230588006360682, 'ar_lags': 9, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 3.526549123303601, 'aci_step_size': 0.02030335241829917, 'oob_split_ratio': 0.6671236778794704}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:51,240] Trial 92 finished with value: 0.003318379833954471 and parameters: {'reservoir_size': 82, 'spectral_radius': 1.321975755154216, 'ar_lags': 10, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 7.280413655570368, 'aci_step_size': 0.017556133816355974, 'oob_split_ratio': 0.6534100492243747}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:51,323] Trial 93 finished with value: 0.0033020397145624397 and parameters: {'reservoir_size': 80, 'spectral_radius': 1.320558703649801, 'ar_lags': 9, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.5814933429989986, 'aci_step_size': 0.014160296479217691, 'oob_split_ratio': 0.6650467681586995}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:51,427] Trial 94 finished with value: 0.003338247467302354 and parameters: {'reservoir_size': 67, 'spectral_radius': 1.259561354359791, 'ar_lags': 8, 'foundation_window': 20, 'regressor_type': 'ElasticNet', 'reg_alpha': 3.764689556162703, 'aci_step_size': 0.010150982289363768, 'oob_split_ratio': 0.6637599581780094}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:51,655] Trial 95 finished with value: 0.003312163586580921 and parameters: {'reservoir_size': 98, 'spectral_radius': 1.2330397370415458, 'ar_lags': 9, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.909805035309332, 'aci_step_size': 0.029437940356254196, 'oob_split_ratio': 0.6732779504096605}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:51,833] Trial 96 finished with value: 0.0033963737545321363 and parameters: {'reservoir_size': 96, 'spectral_radius': 1.219948729268491, 'ar_lags': 9, 'foundation_window': 20, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.2965542446948506, 'aci_step_size': 0.0208013071823141, 'oob_split_ratio': 0.6915666566610533}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:52,064] Trial 97 finished with value: 0.0034656554522754447 and parameters: {'reservoir_size': 105, 'spectral_radius': 1.2785295846717752, 'ar_lags': 9, 'foundation_window': 18, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.5263915682730214, 'aci_step_size': 0.014803688849361047, 'oob_split_ratio': 0.6707077713262051}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:52,170] Trial 98 finished with value: 0.0033202872339067302 and parameters: {'reservoir_size': 85, 'spectral_radius': 1.187361222993269, 'ar_lags': 8, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 3.1787136442035333, 'aci_step_size': 0.028105513912661036, 'oob_split_ratio': 0.6249155029983461}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:52,313] Trial 99 finished with value: 0.00334426524977211 and parameters: {'reservoir_size': 77, 'spectral_radius': 1.1515383168568987, 'ar_lags': 9, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 5.349527566422281, 'aci_step_size': 0.022742973643023627, 'oob_split_ratio': 0.6754496800192894}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:52,472] Trial 100 finished with value: 0.003313978748057059 and parameters: {'reservoir_size': 92, 'spectral_radius': 1.2416626314408294, 'ar_lags': 8, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 4.1781466629644655, 'aci_step_size': 0.036845167646301254, 'oob_split_ratio': 0.6847928849830422}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:52,584] Trial 101 finished with value: 0.003313978748057059 and parameters: {'reservoir_size': 91, 'spectral_radius': 1.2368670923422422, 'ar_lags': 8, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 4.436304400680212, 'aci_step_size': 0.03879178517322229, 'oob_split_ratio': 0.6866510945137809}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:52,808] Trial 102 finished with value: 0.003344830629511981 and parameters: {'reservoir_size': 95, 'spectral_radius': 1.2364020281861916, 'ar_lags': 8, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 4.187623536074548, 'aci_step_size': 0.036973049851817, 'oob_split_ratio': 0.7055175907956999}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:52,969] Trial 103 finished with value: 0.0033389186702038054 and parameters: {'reservoir_size': 102, 'spectral_radius': 1.2850683657491735, 'ar_lags': 8, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.1517053777506816, 'aci_step_size': 0.031134125566314202, 'oob_split_ratio': 0.686118646463917}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:53,100] Trial 104 finished with value: 0.00335275554202929 and parameters: {'reservoir_size': 93, 'spectral_radius': 1.2001483969251674, 'ar_lags': 9, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 6.095994665911768, 'aci_step_size': 0.024130300605597864, 'oob_split_ratio': 0.6987529738540273}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:53,214] Trial 105 finished with value: 0.003346151946558436 and parameters: {'reservoir_size': 89, 'spectral_radius': 1.2558679556964092, 'ar_lags': 8, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.970353587491783, 'aci_step_size': 0.03916545339157865, 'oob_split_ratio': 0.6978916705120997}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:53,332] Trial 106 finished with value: 0.003379977747609853 and parameters: {'reservoir_size': 82, 'spectral_radius': 0.7551196765445414, 'ar_lags': 9, 'foundation_window': 24, 'regressor_type': 'ElasticNet', 'reg_alpha': 4.5589131457341034, 'aci_step_size': 0.013574618743281999, 'oob_split_ratio': 0.680836499745166}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:53,437] Trial 107 finished with value: 0.004102453176518536 and parameters: {'reservoir_size': 71, 'spectral_radius': 1.3081696580832878, 'ar_lags': 8, 'foundation_window': 13, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.776281872861351, 'aci_step_size': 0.09434983530259161, 'oob_split_ratio': 0.7119111673482855}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:53,563] Trial 108 finished with value: 0.0033448426201220702 and parameters: {'reservoir_size': 84, 'spectral_radius': 1.2266631392060685, 'ar_lags': 9, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.2169766780670568, 'aci_step_size': 0.027968767880528406, 'oob_split_ratio': 0.6901299971904877}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:53,671] Trial 109 finished with value: 0.003286449880763291 and parameters: {'reservoir_size': 89, 'spectral_radius': 1.1707505796691204, 'ar_lags': 8, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 3.6978660379453663, 'aci_step_size': 0.017601429782251952, 'oob_split_ratio': 0.6425064960721175}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:53,785] Trial 110 finished with value: 0.0034690715322951353 and parameters: {'reservoir_size': 109, 'spectral_radius': 1.1678346810502316, 'ar_lags': 8, 'foundation_window': 20, 'regressor_type': 'Ridge', 'reg_alpha': 7.30657813160429, 'aci_step_size': 0.017137797890317857, 'oob_split_ratio': 0.7271974574666438}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:53,895] Trial 111 finished with value: 0.003332821747031275 and parameters: {'reservoir_size': 88, 'spectral_radius': 1.1415573795412821, 'ar_lags': 7, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 3.384133199139452, 'aci_step_size': 0.0212052436945208, 'oob_split_ratio': 0.637908081707598}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:54,020] Trial 112 finished with value: 0.003332376446803462 and parameters: {'reservoir_size': 129, 'spectral_radius': 1.2726101755036183, 'ar_lags': 8, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 3.6983188695518545, 'aci_step_size': 0.03411457755038623, 'oob_split_ratio': 0.6453982382024124}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:54,135] Trial 113 finished with value: 0.0033076474811282934 and parameters: {'reservoir_size': 81, 'spectral_radius': 1.198455107654083, 'ar_lags': 8, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.059780873656182, 'aci_step_size': 0.04656893307402344, 'oob_split_ratio': 0.6587433783392551}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:54,239] Trial 114 finished with value: 0.003293824753684199 and parameters: {'reservoir_size': 57, 'spectral_radius': 1.3351486974717426, 'ar_lags': 8, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.5626446196668669, 'aci_step_size': 0.02588617143878395, 'oob_split_ratio': 0.6587700948385546}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:54,344] Trial 115 finished with value: 0.003389956066582087 and parameters: {'reservoir_size': 60, 'spectral_radius': 1.3419549479496855, 'ar_lags': 8, 'foundation_window': 19, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.9397036818486448, 'aci_step_size': 0.02465928526277853, 'oob_split_ratio': 0.6506178539052448}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:54,453] Trial 116 finished with value: 0.0033370449474967117 and parameters: {'reservoir_size': 45, 'spectral_radius': 1.3138209867011392, 'ar_lags': 7, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.4609251304198612, 'aci_step_size': 0.013538222528570218, 'oob_split_ratio': 0.664767701263991}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:54,556] Trial 117 finished with value: 0.003344709891783156 and parameters: {'reservoir_size': 78, 'spectral_radius': 1.1057130520558929, 'ar_lags': 9, 'foundation_window': 20, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.6779168756780345, 'aci_step_size': 0.033021050734106654, 'oob_split_ratio': 0.6571646486796796}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:54,660] Trial 118 finished with value: 0.0033459768910552956 and parameters: {'reservoir_size': 61, 'spectral_radius': 1.3815171146799274, 'ar_lags': 7, 'foundation_window': 21, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.682384733089261, 'aci_step_size': 0.08069308252992073, 'oob_split_ratio': 0.6718561407143943}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:54,764] Trial 119 finished with value: 0.003305238720882441 and parameters: {'reservoir_size': 74, 'spectral_radius': 0.8207531058699522, 'ar_lags': 4, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.2223754307085777, 'aci_step_size': 0.016957106137262985, 'oob_split_ratio': 0.6571592986195384}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:54,851] Trial 120 finished with value: 0.003329326897980643 and parameters: {'reservoir_size': 73, 'spectral_radius': 1.3677052434019492, 'ar_lags': 4, 'foundation_window': 23, 'regressor_type': 'ElasticNet', 'reg_alpha': 2.195258787368798, 'aci_step_size': 0.01764132992138361, 'oob_split_ratio': 0.6595075771938563}. Best is trial 75 with value: 0.0032851438699171114.
# [I 2026-07-03 20:19:54,955] Trial 121 finished with value: 0.003305716165698681 and parameters: {'reservoir_size': 45, 'spectral_radius': 0.6574721338558627, 'ar_lags': 4, 'foundation_window': 22, 'regressor_type': 'ElasticNet', 'reg_alpha': 1.9334774459047444, 'aci_step_size': 0.026992071096552307, 'oob_split_ratio': 0.6519301508564226}. Best is trial 75 with value: 0.0032851438699171114.
# ...
# [I 2026-07-03 20:20:24,626] Trial 143 finished with value: 1.437548345483477 and parameters: {'target_miscoverage': 0.023350740749252016, 'aci_step_size': 0.06973460180886441, 'interval_scale': 0.6113215350794029}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:24,698] Trial 144 finished with value: 1.45023993588836 and parameters: {'target_miscoverage': 0.019345701896845407, 'aci_step_size': 0.06275235853876379, 'interval_scale': 0.6265671480989824}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:24,771] Trial 145 finished with value: 1.5917720343649755 and parameters: {'target_miscoverage': 0.03414616395407344, 'aci_step_size': 0.07724076461651985, 'interval_scale': 0.6880547445745377}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:24,842] Trial 146 finished with value: 3.8647093545475806 and parameters: {'target_miscoverage': 0.014753909680777966, 'aci_step_size': 0.04557954016374686, 'interval_scale': 0.5370653880534287}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:24,914] Trial 147 finished with value: 1.8961510024869086 and parameters: {'target_miscoverage': 0.02913134295477842, 'aci_step_size': 0.03786008633085986, 'interval_scale': 0.58784240104256}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:24,987] Trial 148 finished with value: 1.5276359394086403 and parameters: {'target_miscoverage': 0.058155612521333847, 'aci_step_size': 0.05778332707673322, 'interval_scale': 0.6597279682745055}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:25,060] Trial 149 finished with value: 3.7782562011723737 and parameters: {'target_miscoverage': 0.021216956888163385, 'aci_step_size': 0.09431718894571853, 'interval_scale': 0.5622206512333668}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:25,133] Trial 150 finished with value: 1.4358751745189469 and parameters: {'target_miscoverage': 0.07395437836625313, 'aci_step_size': 0.08524082163548467, 'interval_scale': 0.6066411224877465}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:25,209] Trial 151 finished with value: 1.4366574006344728 and parameters: {'target_miscoverage': 0.07518680657396395, 'aci_step_size': 0.08593774085939762, 'interval_scale': 0.6086680050686663}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:25,283] Trial 152 finished with value: 1.4847046222673073 and parameters: {'target_miscoverage': 0.07174719577773386, 'aci_step_size': 0.08610807758398509, 'interval_scale': 0.6411875622115489}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:25,356] Trial 153 finished with value: 1.9034254277911797 and parameters: {'target_miscoverage': 0.06687166730980766, 'aci_step_size': 0.07992835535358107, 'interval_scale': 0.5829054187426859}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:25,435] Trial 154 finished with value: 3.894467963686042 and parameters: {'target_miscoverage': 0.0929067146822997, 'aci_step_size': 0.07190375440293395, 'interval_scale': 0.5283724967446713}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:25,515] Trial 155 finished with value: 1.6299023011913198 and parameters: {'target_miscoverage': 0.0739608767079915, 'aci_step_size': 0.09933132376164476, 'interval_scale': 0.7038929275695995}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:25,594] Trial 156 finished with value: 1.4611174450293913 and parameters: {'target_miscoverage': 0.07755836717867813, 'aci_step_size': 0.08721157243273028, 'interval_scale': 0.63100115580733}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:25,668] Trial 157 finished with value: 3.7664402925974025 and parameters: {'target_miscoverage': 0.06834866203349554, 'aci_step_size': 0.1085561086206126, 'interval_scale': 0.5652326906129932}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:25,742] Trial 158 finished with value: 1.5448325007822945 and parameters: {'target_miscoverage': 0.08031674942567966, 'aci_step_size': 0.0765114427357025, 'interval_scale': 0.6671545102951973}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:25,817] Trial 159 finished with value: 1.7778467170775114 and parameters: {'target_miscoverage': 0.07539278586295653, 'aci_step_size': 0.06671805484010697, 'interval_scale': 0.7677845043466811}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:25,890] Trial 160 finished with value: 1.87890227360763 and parameters: {'target_miscoverage': 0.014850472810606384, 'aci_step_size': 0.09538821337342397, 'interval_scale': 0.5990854149840152}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:25,967] Trial 161 finished with value: 1.4376828082929667 and parameters: {'target_miscoverage': 0.09018979787650112, 'aci_step_size': 0.05136883200142319, 'interval_scale': 0.6118272754441956}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:26,043] Trial 162 finished with value: 1.435353511285857 and parameters: {'target_miscoverage': 0.018330048371354084, 'aci_step_size': 0.06353233345939806, 'interval_scale': 0.6055337573623975}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:26,125] Trial 163 finished with value: 3.8321597853578235 and parameters: {'target_miscoverage': 0.025132543897845784, 'aci_step_size': 0.08084873827381123, 'interval_scale': 0.546696448741601}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:26,203] Trial 164 finished with value: 1.4858157438523778 and parameters: {'target_miscoverage': 0.06373015081581478, 'aci_step_size': 0.033133625497044863, 'interval_scale': 0.6416674134424022}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:26,275] Trial 165 finished with value: 1.8990502567537342 and parameters: {'target_miscoverage': 0.08444438773230478, 'aci_step_size': 0.06083710961524754, 'interval_scale': 0.5857396241560306}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:26,353] Trial 166 finished with value: 1.6362300637881892 and parameters: {'target_miscoverage': 0.017770248057221365, 'aci_step_size': 0.06897732640602089, 'interval_scale': 0.706925907468394}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:26,425] Trial 167 finished with value: 3.992343416332538 and parameters: {'target_miscoverage': 0.013671112301192738, 'aci_step_size': 0.08931689081937856, 'interval_scale': 0.5004050983882409}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:26,500] Trial 168 finished with value: 1.5448306684450601 and parameters: {'target_miscoverage': 0.03709446310712383, 'aci_step_size': 0.07552524774863918, 'interval_scale': 0.6671537189783145}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:26,573] Trial 169 finished with value: 3.7963438154169644 and parameters: {'target_miscoverage': 0.030861017501706837, 'aci_step_size': 0.04078687422030778, 'interval_scale': 0.5568661135053496}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:26,648] Trial 170 finished with value: 1.4375789175341003 and parameters: {'target_miscoverage': 0.05686930765532677, 'aci_step_size': 0.03612991235868182, 'interval_scale': 0.6110558140599462}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:26,720] Trial 171 finished with value: 1.4369654675956671 and parameters: {'target_miscoverage': 0.022419654017711912, 'aci_step_size': 0.05463528337662622, 'interval_scale': 0.6097250565363663}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:26,792] Trial 172 finished with value: 1.4871511153576809 and parameters: {'target_miscoverage': 0.01007723833550638, 'aci_step_size': 0.04735115285521953, 'interval_scale': 0.6423503200846975}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:26,864] Trial 173 finished with value: 3.7125653832071244 and parameters: {'target_miscoverage': 0.01905153720827672, 'aci_step_size': 0.06419440885128364, 'interval_scale': 0.5809899267678368}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:26,938] Trial 174 finished with value: 3.8501887217471165 and parameters: {'target_miscoverage': 0.02581729415547955, 'aci_step_size': 0.04366700111513936, 'interval_scale': 0.5413323169034253}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,009] Trial 175 finished with value: 1.878171174026928 and parameters: {'target_miscoverage': 0.01721072680854412, 'aci_step_size': 0.057987214452496716, 'interval_scale': 0.5994722604943997}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,081] Trial 176 finished with value: 1.4408748058756964 and parameters: {'target_miscoverage': 0.07043042563180615, 'aci_step_size': 0.050499329302801765, 'interval_scale': 0.6195960283734584}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,155] Trial 177 finished with value: 1.5220924936942632 and parameters: {'target_miscoverage': 0.15090802414009422, 'aci_step_size': 0.06964316233655918, 'interval_scale': 0.6608210939653237}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,228] Trial 178 finished with value: 1.6747733667779767 and parameters: {'target_miscoverage': 0.021658647887024485, 'aci_step_size': 0.062364622282506485, 'interval_scale': 0.7236097231391834}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,302] Trial 179 finished with value: 3.897904252799443 and parameters: {'target_miscoverage': 0.05087766515695795, 'aci_step_size': 0.07362163390579535, 'interval_scale': 0.5273831615343153}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,379] Trial 180 finished with value: 3.739240487427751 and parameters: {'target_miscoverage': 0.013552741301836287, 'aci_step_size': 0.03856551190121197, 'interval_scale': 0.5731675407774632}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,454] Trial 181 finished with value: 1.4498469422362477 and parameters: {'target_miscoverage': 0.027256109599847162, 'aci_step_size': 0.0835159263209007, 'interval_scale': 0.626628125505971}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,531] Trial 182 finished with value: 1.8846882523073583 and parameters: {'target_miscoverage': 0.02929284541097054, 'aci_step_size': 0.07250642977573102, 'interval_scale': 0.5954814883305928}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,609] Trial 183 finished with value: 1.5741817926425448 and parameters: {'target_miscoverage': 0.01687980973047729, 'aci_step_size': 0.08195811318003741, 'interval_scale': 0.6801554100600313}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,687] Trial 184 finished with value: 3.799445989852791 and parameters: {'target_miscoverage': 0.022748907928671357, 'aci_step_size': 0.06526609007535468, 'interval_scale': 0.5560161464173862}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,765] Trial 185 finished with value: 1.4730994616696755 and parameters: {'target_miscoverage': 0.14103907668419385, 'aci_step_size': 0.0788677592722281, 'interval_scale': 0.6370471258398356}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,838] Trial 186 finished with value: 1.8786867939904288 and parameters: {'target_miscoverage': 0.019415533879666134, 'aci_step_size': 0.05445349063288236, 'interval_scale': 0.5991504335915036}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,911] Trial 187 finished with value: 1.5744731366628222 and parameters: {'target_miscoverage': 0.04142040446347806, 'aci_step_size': 0.09400831227750982, 'interval_scale': 0.679955175678475}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:27,984] Trial 188 finished with value: 3.785837800090269 and parameters: {'target_miscoverage': 0.03195963950804624, 'aci_step_size': 0.04632092397629372, 'interval_scale': 0.559935229181961}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:28,056] Trial 189 finished with value: 1.4583712419050054 and parameters: {'target_miscoverage': 0.013277946046304757, 'aci_step_size': 0.05822043887474216, 'interval_scale': 0.6299839307658568}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:28,128] Trial 190 finished with value: 3.909444448535786 and parameters: {'target_miscoverage': 0.026258022224189208, 'aci_step_size': 0.005002211794506965, 'interval_scale': 0.5242248444201157}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:28,202] Trial 191 finished with value: 1.4347413563395268 and parameters: {'target_miscoverage': 0.022865826401297286, 'aci_step_size': 0.05353178832602931, 'interval_scale': 0.6039593749431198}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:28,278] Trial 192 finished with value: 1.8832663059139516 and parameters: {'target_miscoverage': 0.020791743991367663, 'aci_step_size': 0.042562568880382706, 'interval_scale': 0.5961471658871602}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:28,352] Trial 193 finished with value: 3.7393863168945467 and parameters: {'target_miscoverage': 0.01627311439487632, 'aci_step_size': 0.04973571973014654, 'interval_scale': 0.5731824987833626}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:28,425] Trial 194 finished with value: 12.880309843895716 and parameters: {'target_miscoverage': 0.02464915728232323, 'aci_step_size': 0.06621320134679934, 'interval_scale': 5.565664495165921}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:28,501] Trial 195 finished with value: 1.494760107207105 and parameters: {'target_miscoverage': 0.011108262828744232, 'aci_step_size': 0.060810055185581025, 'interval_scale': 0.6456812785958506}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:28,574] Trial 196 finished with value: 1.4382384118790517 and parameters: {'target_miscoverage': 0.0354130993905927, 'aci_step_size': 0.07570003667437439, 'interval_scale': 0.6133344222139172}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:28,650] Trial 197 finished with value: 1.5756315572837707 and parameters: {'target_miscoverage': 0.02850068918619593, 'aci_step_size': 0.08769993747941272, 'interval_scale': 0.68104531989582}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:28,724] Trial 198 finished with value: 3.7889743694642233 and parameters: {'target_miscoverage': 0.01693328647203934, 'aci_step_size': 0.05526286548512767, 'interval_scale': 0.5589261882265568}. Best is trial 72 with value: 1.4334957500828434.
# [I 2026-07-03 20:20:28,797] Trial 199 finished with value: 1.9045858578041501 and parameters: {'target_miscoverage': 0.021697737111448477, 'aci_step_size': 0.0704451743752046, 'interval_scale': 0.5824622011041316}. Best is trial 72 with value: 1.4334957500828434.
# S3-Forecaster best point parameters:
# {'reservoir_size': 43, 'spectral_radius': 0.6431845944160947, 'ar_lags': 2, 'foundation_window': 22, 'regressor_type': 'Ridge', 'reg_alpha': 3.5706149382358325, 'aci_step_size': 0.17751689212303806, 'oob_split_ratio': 0.6756898426028435}
# S3-Forecaster best UQ parameters:
# {'target_miscoverage': 0.01382679968278653, 'aci_step_size': 0.04007672806448736, 'interval_scale': 0.6005909469147512}
# S3-Forecaster test metrics on modelling scale:
#         mae       mse      rmse        r2  mape_percent      mape  \
# 0  0.032958  0.001479  0.038454 -1.843427      0.444923  0.004449
#
#    smape_percent     smape       ecp  coverage_error        iw  mean_width  \
# 0       0.443578  0.004436  0.916667        0.016667  0.125998    0.125998
#
#         mis  interval_score      msis    scale  elapsed_seconds  \
# 0  0.140852        0.140852  1.919736  0.07337         0.069189
#
#    trainable_params
# 0               554

# %% [markdown]
# ## 7. S3-FastSketch optimization and final test

# %%
fastsketch_result = run_fastsketch_experiment(
    train_series,
    test_series,
    point_trials=FASTSKETCH_POINT_TRIALS,
    uq_trials=FASTSKETCH_UQ_TRIALS,
    val_size=VAL_SIZE,
    seed=SEED,
)

print("S3-FastSketch best point parameters:")
print(fastsketch_result["best_point_params"])
print("S3-FastSketch best UQ parameters:")
print(fastsketch_result["best_uq_params"])
print("S3-FastSketch test metrics on modelling scale:")
display(pd.DataFrame([fastsketch_result["metrics"]]))
# Out:
# [I 2026-07-03 20:20:29,070] A new study created in memory with name: no-name-04f9e5c0-b8e6-4c5e-a3c9-05dc6dd6e697
# [I 2026-07-03 20:20:29,280] Trial 0 finished with value: 0.004067860740128723 and parameters: {'foundation_window': 6, 'ar_lags': 6, 'ema_spans': (2, 4), 'conv_scales': (2, 4, 8), 'use_calendar': False, 'ridge_alpha': 0.008111941985431923, 'shrinkage_max': 0.754362402096943, 'oob_split_ratio': 0.6260605607398845}. Best is trial 0 with value: 0.004067860740128723.
# [I 2026-07-03 20:20:29,483] Trial 1 finished with value: 0.0045448437568177125 and parameters: {'foundation_window': 7, 'ar_lags': 3, 'ema_spans': (2, 4, 8), 'conv_scales': (2, 3, 4), 'use_calendar': True, 'ridge_alpha': 0.007122305833333868, 'shrinkage_max': 0.42889188070951867, 'oob_split_ratio': 0.7872213843133333}. Best is trial 0 with value: 0.004067860740128723.
# [I 2026-07-03 20:20:29,646] Trial 2 finished with value: 0.004137254490327067 and parameters: {'foundation_window': 12, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': True, 'ridge_alpha': 0.5414413211338525, 'shrinkage_max': 0.7583497526951993, 'oob_split_ratio': 0.7923961569411397}. Best is trial 0 with value: 0.004067860740128723.
# [I 2026-07-03 20:20:29,839] Trial 3 finished with value: 0.0037359703935133247 and parameters: {'foundation_window': 10, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (2, 4, 8), 'use_calendar': False, 'ridge_alpha': 0.5169879442298543, 'shrinkage_max': 0.6375416186805973, 'oob_split_ratio': 0.75054924518851}. Best is trial 3 with value: 0.0037359703935133247.
# [I 2026-07-03 20:20:30,047] Trial 4 finished with value: 0.0034171905142489256 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3, 4), 'use_calendar': False, 'ridge_alpha': 0.04513257622008944, 'shrinkage_max': 0.42478546328656497, 'oob_split_ratio': 0.6277455804289156}. Best is trial 4 with value: 0.0034171905142489256.
# [I 2026-07-03 20:20:30,216] Trial 5 finished with value: 0.003731095463452226 and parameters: {'foundation_window': 5, 'ar_lags': 5, 'ema_spans': (2, 4, 8), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.003463037026119184, 'shrinkage_max': 0.3364302606385192, 'oob_split_ratio': 0.7091026028159452}. Best is trial 4 with value: 0.0034171905142489256.
# [I 2026-07-03 20:20:30,417] Trial 6 finished with value: 0.0038943740319828594 and parameters: {'foundation_window': 5, 'ar_lags': 4, 'ema_spans': (2, 4), 'conv_scales': (3, 6, 12), 'use_calendar': True, 'ridge_alpha': 10.431827200054899, 'shrinkage_max': 0.7630676619365986, 'oob_split_ratio': 0.7731397496224945}. Best is trial 4 with value: 0.0034171905142489256.
# [I 2026-07-03 20:20:30,614] Trial 7 finished with value: 0.004578635223126989 and parameters: {'foundation_window': 7, 'ar_lags': 5, 'ema_spans': (2, 4), 'conv_scales': (2, 3, 4), 'use_calendar': False, 'ridge_alpha': 0.0487613652796118, 'shrinkage_max': 2.8430016857594276, 'oob_split_ratio': 0.6308007330051888}. Best is trial 4 with value: 0.0034171905142489256.
# [I 2026-07-03 20:20:30,835] Trial 8 finished with value: 0.004425257022260889 and parameters: {'foundation_window': 7, 'ar_lags': 5, 'ema_spans': (2, 4, 8), 'conv_scales': (3, 6, 12), 'use_calendar': True, 'ridge_alpha': 34.77998816092338, 'shrinkage_max': 0.9087951993341742, 'oob_split_ratio': 0.5862237180228058}. Best is trial 4 with value: 0.0034171905142489256.
# [I 2026-07-03 20:20:31,010] Trial 9 finished with value: 0.00468740911821408 and parameters: {'foundation_window': 7, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.008562341633595545, 'shrinkage_max': 0.36213163927560077, 'oob_split_ratio': 0.6977232357970605}. Best is trial 4 with value: 0.0034171905142489256.
# [I 2026-07-03 20:20:31,191] Trial 10 finished with value: 0.0033732699217740645 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 1.7825772506071267, 'shrinkage_max': 1.754986535579859, 'oob_split_ratio': 0.5544647693441357}. Best is trial 10 with value: 0.0033732699217740645.
# [I 2026-07-03 20:20:31,379] Trial 11 finished with value: 0.0033492199723545416 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 1.0308784754681746, 'shrinkage_max': 1.5752149065741565, 'oob_split_ratio': 0.5532295897104252}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:31,557] Trial 12 finished with value: 0.0033737252022915123 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 2.8033866806350285, 'shrinkage_max': 1.7578679089642608, 'oob_split_ratio': 0.5563066619651622}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:31,737] Trial 13 finished with value: 0.0036006565753555955 and parameters: {'foundation_window': 3, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 1.4198625602792694, 'shrinkage_max': 1.5645825534887527, 'oob_split_ratio': 0.5506174600428168}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:31,941] Trial 14 finished with value: 0.0036905997711692584 and parameters: {'foundation_window': 4, 'ar_lags': 2, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 0.2001529075929869, 'shrinkage_max': 1.8454911996429355, 'oob_split_ratio': 0.5887933359773073}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:32,149] Trial 15 finished with value: 0.003620836132336729 and parameters: {'foundation_window': 3, 'ar_lags': 2, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 6.928312696620425, 'shrinkage_max': 2.3401083025624456, 'oob_split_ratio': 0.586824717083858}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:32,367] Trial 16 finished with value: 0.0033774988000275243 and parameters: {'foundation_window': 2, 'ar_lags': 2, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 76.97192144784924, 'shrinkage_max': 1.3481442622305488, 'oob_split_ratio': 0.5738066462523634}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:32,549] Trial 17 finished with value: 0.003642363107049016 and parameters: {'foundation_window': 4, 'ar_lags': 1, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 0.08787108196266004, 'shrinkage_max': 2.266672670521139, 'oob_split_ratio': 0.6113367928938461}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:32,731] Trial 18 finished with value: 0.003948141074595911 and parameters: {'foundation_window': 3, 'ar_lags': 3, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 1.855872255177356, 'shrinkage_max': 1.1652664478819619, 'oob_split_ratio': 0.6649494510833106}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:32,909] Trial 19 finished with value: 0.0037232907363239187 and parameters: {'foundation_window': 4, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 12.665129557244128, 'shrinkage_max': 2.0454328405911895, 'oob_split_ratio': 0.5596888045575695}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:33,123] Trial 20 finished with value: 0.0034228559601126997 and parameters: {'foundation_window': 2, 'ar_lags': 2, 'ema_spans': (3, 6, 12), 'conv_scales': (3, 6, 12), 'use_calendar': False, 'ridge_alpha': 0.31333706566811925, 'shrinkage_max': 2.6468427993240207, 'oob_split_ratio': 0.606132357707585}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:33,299] Trial 21 finished with value: 0.0033784304406453054 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 2.547061758816308, 'shrinkage_max': 1.6727195543386832, 'oob_split_ratio': 0.5587856323865606}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:33,478] Trial 22 finished with value: 0.003639615728217159 and parameters: {'foundation_window': 3, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 4.2864388557578055, 'shrinkage_max': 1.3565432060982872, 'oob_split_ratio': 0.5500622917875136}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:33,659] Trial 23 finished with value: 0.0033750926330068064 and parameters: {'foundation_window': 2, 'ar_lags': 2, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 1.0381194903326139, 'shrinkage_max': 1.9071922161516648, 'oob_split_ratio': 0.5755128145413994}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:33,833] Trial 24 finished with value: 0.0036676228174050292 and parameters: {'foundation_window': 4, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 15.225549359332238, 'shrinkage_max': 1.5465757826741429, 'oob_split_ratio': 0.6035456508777763}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:34,065] Trial 25 finished with value: 0.0034155356429712617 and parameters: {'foundation_window': 3, 'ar_lags': 3, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 4, 8), 'use_calendar': False, 'ridge_alpha': 3.4096141385017353, 'shrinkage_max': 1.2013731634906264, 'oob_split_ratio': 0.6534965521006755}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:34,256] Trial 26 finished with value: 0.004375856662105639 and parameters: {'foundation_window': 5, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.8636685206092858, 'shrinkage_max': 2.193790553952402, 'oob_split_ratio': 0.5654700183350418}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:34,468] Trial 27 finished with value: 0.0033720777849419754 and parameters: {'foundation_window': 2, 'ar_lags': 2, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 0.10280170609344179, 'shrinkage_max': 2.4732822612001817, 'oob_split_ratio': 0.5788698451504689}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:34,670] Trial 28 finished with value: 0.004245928492090696 and parameters: {'foundation_window': 9, 'ar_lags': 2, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 0.15628399081655517, 'shrinkage_max': 2.711177582569223, 'oob_split_ratio': 0.5955890043102293}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:34,875] Trial 29 finished with value: 0.0041465589471406964 and parameters: {'foundation_window': 3, 'ar_lags': 3, 'ema_spans': (2, 4), 'conv_scales': (2, 4, 8), 'use_calendar': False, 'ridge_alpha': 0.0010547775522317456, 'shrinkage_max': 2.4341214500337474, 'oob_split_ratio': 0.613473895005487}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:35,085] Trial 30 finished with value: 0.00412341402977458 and parameters: {'foundation_window': 6, 'ar_lags': 2, 'ema_spans': (3, 6), 'conv_scales': (2, 3, 4), 'use_calendar': False, 'ridge_alpha': 0.025084866493465693, 'shrinkage_max': 2.510243274947423, 'oob_split_ratio': 0.6495750110668936}. Best is trial 11 with value: 0.0033492199723545416.
# [I 2026-07-03 20:20:35,277] Trial 31 finished with value: 0.0033416456661995806 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 0.5138507597645586, 'shrinkage_max': 1.7436722873170991, 'oob_split_ratio': 0.5741805469378722}. Best is trial 31 with value: 0.0033416456661995806.
# [I 2026-07-03 20:20:35,464] Trial 32 finished with value: 0.0033400625665761952 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 0.3644435982822868, 'shrinkage_max': 2.0649501428663966, 'oob_split_ratio': 0.5773025415032474}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:35,670] Trial 33 finished with value: 0.0036313821083102716 and parameters: {'foundation_window': 3, 'ar_lags': 2, 'ema_spans': (2, 4, 8), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 0.3114957526874385, 'shrinkage_max': 2.0498933441108265, 'oob_split_ratio': 0.577761725710893}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:35,850] Trial 34 finished with value: 0.0035867371437627218 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (3, 6), 'use_calendar': True, 'ridge_alpha': 0.5377103864437376, 'shrinkage_max': 2.9789214339842816, 'oob_split_ratio': 0.5713820282624491}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:36,076] Trial 35 finished with value: 0.0037886020573542935 and parameters: {'foundation_window': 12, 'ar_lags': 3, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 4, 8), 'use_calendar': False, 'ridge_alpha': 0.10912072098886591, 'shrinkage_max': 1.9982929929069642, 'oob_split_ratio': 0.6261286074403593}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:36,252] Trial 36 finished with value: 0.0037769523148082703 and parameters: {'foundation_window': 4, 'ar_lags': 2, 'ema_spans': (3, 6), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 0.03606197949731475, 'shrinkage_max': 2.1829669904040934, 'oob_split_ratio': 0.5956424289763558}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:36,459] Trial 37 finished with value: 0.004196797167003397 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (2, 4), 'conv_scales': (2, 3, 4), 'use_calendar': True, 'ridge_alpha': 0.2882026611652969, 'shrinkage_max': 1.5086014589682457, 'oob_split_ratio': 0.5801272686543223}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:36,677] Trial 38 finished with value: 0.004173370251807091 and parameters: {'foundation_window': 3, 'ar_lags': 2, 'ema_spans': (2, 4, 8), 'conv_scales': (3, 6, 12), 'use_calendar': False, 'ridge_alpha': 0.013501893393788201, 'shrinkage_max': 1.0232699284073203, 'oob_split_ratio': 0.6175763171330324}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:36,854] Trial 39 finished with value: 0.004015011613543683 and parameters: {'foundation_window': 10, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.06876929587130981, 'shrinkage_max': 2.570574504685961, 'oob_split_ratio': 0.6366763175678264}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:37,038] Trial 40 finished with value: 0.004387663800648493 and parameters: {'foundation_window': 5, 'ar_lags': 3, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 3), 'use_calendar': True, 'ridge_alpha': 0.7281733239698964, 'shrinkage_max': 2.1140932943787774, 'oob_split_ratio': 0.5959767222216206}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:37,226] Trial 41 finished with value: 0.0033569343116777515 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 0.48201155430898535, 'shrinkage_max': 1.7168712357494613, 'oob_split_ratio': 0.566035734353016}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:37,406] Trial 42 finished with value: 0.0033627513894993895 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 0.4140297422319845, 'shrinkage_max': 1.7060734678005165, 'oob_split_ratio': 0.5665695739205073}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:37,581] Trial 43 finished with value: 0.0033770154593330743 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 0.4087716674477471, 'shrinkage_max': 1.417620323738354, 'oob_split_ratio': 0.5708770841805826}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:37,761] Trial 44 finished with value: 0.0035169113616837842 and parameters: {'foundation_window': 3, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 0.20912186766503155, 'shrinkage_max': 1.675490070205885, 'oob_split_ratio': 0.566372949953247}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:37,970] Trial 45 finished with value: 0.0035819799783035114 and parameters: {'foundation_window': 4, 'ar_lags': 1, 'ema_spans': (2, 4), 'conv_scales': (3, 6, 12), 'use_calendar': False, 'ridge_alpha': 0.6128449451593445, 'shrinkage_max': 1.851106500756445, 'oob_split_ratio': 0.7475587036776231}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:38,184] Trial 46 finished with value: 0.00355948617869118 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6, 12), 'conv_scales': (2, 3, 4), 'use_calendar': False, 'ridge_alpha': 1.1364765525419291, 'shrinkage_max': 1.934436772642154, 'oob_split_ratio': 0.584770420231477}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:38,362] Trial 47 finished with value: 0.003641847849037667 and parameters: {'foundation_window': 3, 'ar_lags': 1, 'ema_spans': (2, 4, 8), 'conv_scales': (2, 3), 'use_calendar': False, 'ridge_alpha': 5.048421516997548, 'shrinkage_max': 1.701974465958017, 'oob_split_ratio': 0.561592587987955}. Best is trial 32 with value: 0.0033400625665761952.
# [I 2026-07-03 20:20:38,533] Trial 48 finished with value: 0.0032456411366516198 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.14289453252389034, 'shrinkage_max': 1.5980067557630138, 'oob_split_ratio': 0.5971980434711334}. Best is trial 48 with value: 0.0032456411366516198.
# [I 2026-07-03 20:20:38,709] Trial 49 finished with value: 0.003758114413511045 and parameters: {'foundation_window': 3, 'ar_lags': 1, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.05024709332553255, 'shrinkage_max': 1.2929759024000471, 'oob_split_ratio': 0.5896359426116147}. Best is trial 48 with value: 0.0032456411366516198.
# [I 2026-07-03 20:20:38,883] Trial 50 finished with value: 0.0035429679585606386 and parameters: {'foundation_window': 4, 'ar_lags': 1, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.14560987519856822, 'shrinkage_max': 1.4939112586768004, 'oob_split_ratio': 0.6020644802111685}. Best is trial 48 with value: 0.0032456411366516198.
# [I 2026-07-03 20:20:39,056] Trial 51 finished with value: 0.003312059288574539 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.42845556725494766, 'shrinkage_max': 1.8059016593638448, 'oob_split_ratio': 0.5665286649424331}. Best is trial 48 with value: 0.0032456411366516198.
# [I 2026-07-03 20:20:39,232] Trial 52 finished with value: 0.0033698812020529563 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 1.5827545357637793, 'shrinkage_max': 1.827658594540513, 'oob_split_ratio': 0.5518914284363401}. Best is trial 48 with value: 0.0032456411366516198.
# [I 2026-07-03 20:20:39,404] Trial 53 finished with value: 0.003222509427662043 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.23290910176685048, 'shrinkage_max': 0.5609227804465544, 'oob_split_ratio': 0.5863605657165037}. Best is trial 53 with value: 0.003222509427662043.
# [I 2026-07-03 20:20:39,577] Trial 54 finished with value: 0.0037895856920203224 and parameters: {'foundation_window': 3, 'ar_lags': 2, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.21209290275154916, 'shrinkage_max': 0.6658555674402662, 'oob_split_ratio': 0.6165675848617066}. Best is trial 53 with value: 0.003222509427662043.
# [I 2026-07-03 20:20:39,752] Trial 55 finished with value: 0.00320363527334675 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.1391163905880955, 'shrinkage_max': 0.5020426992431416, 'oob_split_ratio': 0.5884937155044146}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:39,924] Trial 56 finished with value: 0.0036271547638497843 and parameters: {'foundation_window': 2, 'ar_lags': 1, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.05604999629860806, 'shrinkage_max': 0.466877967665511, 'oob_split_ratio': 0.6362583399084515}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:40,108] Trial 57 finished with value: 0.004023960355678245 and parameters: {'foundation_window': 3, 'ar_lags': 2, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': True, 'ridge_alpha': 0.023431565639910702, 'shrinkage_max': 0.26042452446398523, 'oob_split_ratio': 0.5883650479063282}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:40,283] Trial 58 finished with value: 0.0032583183271867196 and parameters: {'foundation_window': 2, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.14398673455413677, 'shrinkage_max': 0.5119918237248816, 'oob_split_ratio': 0.6072219388323398}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:40,454] Trial 59 finished with value: 0.003881243116786563 and parameters: {'foundation_window': 3, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.14244003418140622, 'shrinkage_max': 0.737904844187869, 'oob_split_ratio': 0.6215928453441532}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:40,627] Trial 60 finished with value: 0.0032550332132166393 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.07925958018232306, 'shrinkage_max': 0.510222096581246, 'oob_split_ratio': 0.6065699042427994}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:40,800] Trial 61 finished with value: 0.0032517641843075144 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.07526337735030182, 'shrinkage_max': 0.5064538473368447, 'oob_split_ratio': 0.6094174277601603}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:40,984] Trial 62 finished with value: 0.0032407430434531065 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.030863429529719013, 'shrinkage_max': 0.47439006596454647, 'oob_split_ratio': 0.6079213177655223}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:41,174] Trial 63 finished with value: 0.003889788883649429 and parameters: {'foundation_window': 3, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.03381248388534225, 'shrinkage_max': 0.5201936832193335, 'oob_split_ratio': 0.6082512556003484}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:41,347] Trial 64 finished with value: 0.00327054415909751 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.009944325678713334, 'shrinkage_max': 0.5630741400174553, 'oob_split_ratio': 0.6312251468528708}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:41,518] Trial 65 finished with value: 0.003295472160395271 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.004888283885222019, 'shrinkage_max': 0.9026107938346962, 'oob_split_ratio': 0.6444426778781496}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:41,693] Trial 66 finished with value: 0.0034024614905633827 and parameters: {'foundation_window': 3, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.08468365477857587, 'shrinkage_max': 0.325668467434267, 'oob_split_ratio': 0.6732848245786185}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:41,867] Trial 67 finished with value: 0.003220136408384143 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.018387033475356713, 'shrinkage_max': 0.5957844241259884, 'oob_split_ratio': 0.6040591375992531}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:42,053] Trial 68 finished with value: 0.00437606093062343 and parameters: {'foundation_window': 11, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.018812511625447958, 'shrinkage_max': 0.625368527794201, 'oob_split_ratio': 0.59995153310267}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:42,248] Trial 69 finished with value: 0.0037794109734225964 and parameters: {'foundation_window': 4, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': True, 'ridge_alpha': 0.016050897873367904, 'shrinkage_max': 0.38973793245746463, 'oob_split_ratio': 0.621900894744049}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:42,445] Trial 70 finished with value: 0.004380386177709048 and parameters: {'foundation_window': 8, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.03603006698627171, 'shrinkage_max': 0.8973631906843731, 'oob_split_ratio': 0.6121584911095532}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:42,623] Trial 71 finished with value: 0.003241555812724966 and parameters: {'foundation_window': 2, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.07331354309723298, 'shrinkage_max': 0.8187334263344346, 'oob_split_ratio': 0.6047823338742384}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:42,801] Trial 72 finished with value: 0.0032648028834548273 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.07062771830420361, 'shrinkage_max': 0.8191057226069292, 'oob_split_ratio': 0.5943496458088721}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:42,977] Trial 73 finished with value: 0.003241634124686662 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.10645983897293211, 'shrinkage_max': 1.0239220905319337, 'oob_split_ratio': 0.6035373359152222}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:43,156] Trial 74 finished with value: 0.003922870994753016 and parameters: {'foundation_window': 3, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.10876063346816008, 'shrinkage_max': 1.0368177422997484, 'oob_split_ratio': 0.5841596574264601}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:43,337] Trial 75 finished with value: 0.003220976430116813 and parameters: {'foundation_window': 2, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.026641711802689833, 'shrinkage_max': 0.6995856898706612, 'oob_split_ratio': 0.5907602258231066}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:43,527] Trial 76 finished with value: 0.0036151983362307234 and parameters: {'foundation_window': 3, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.0102124311118249, 'shrinkage_max': 0.6927840359761839, 'oob_split_ratio': 0.5926554194372156}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:43,738] Trial 77 finished with value: 0.0033419311618700823 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (2, 4, 8), 'use_calendar': False, 'ridge_alpha': 0.005779140328208635, 'shrinkage_max': 0.7721218733255701, 'oob_split_ratio': 0.5987188557212944}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:43,921] Trial 78 finished with value: 0.00348747147839205 and parameters: {'foundation_window': 2, 'ar_lags': 4, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.044036938296603136, 'shrinkage_max': 0.604944903434654, 'oob_split_ratio': 0.6205725670971537}. Best is trial 55 with value: 0.00320363527334675.
# [I 2026-07-03 20:20:44,097] Trial 79 finished with value: 0.0031828335567146877 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.024735931490437468, 'shrinkage_max': 0.8168642888380869, 'oob_split_ratio': 0.5818640379859217}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:44,274] Trial 80 finished with value: 0.003854974410645574 and parameters: {'foundation_window': 3, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.028124420108165203, 'shrinkage_max': 1.0552975884179019, 'oob_split_ratio': 0.5842239517887997}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:44,449] Trial 81 finished with value: 0.0033504510110070854 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.002670406614877028, 'shrinkage_max': 0.8486452510817237, 'oob_split_ratio': 0.600873613008678}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:44,626] Trial 82 finished with value: 0.003202130458712617 and parameters: {'foundation_window': 2, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.019488889376411814, 'shrinkage_max': 0.7283061104149899, 'oob_split_ratio': 0.5812452168743579}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:44,809] Trial 83 finished with value: 0.0032426752530901218 and parameters: {'foundation_window': 2, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.013340095143794696, 'shrinkage_max': 0.9748911568271191, 'oob_split_ratio': 0.5807990666212334}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:44,995] Trial 84 finished with value: 0.0036666831254002063 and parameters: {'foundation_window': 3, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.01952595188073402, 'shrinkage_max': 0.725698919901693, 'oob_split_ratio': 0.5909764623670702}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:45,219] Trial 85 finished with value: 0.003952985569140041 and parameters: {'foundation_window': 2, 'ar_lags': 3, 'ema_spans': (2, 4), 'conv_scales': (3, 6, 12), 'use_calendar': False, 'ridge_alpha': 0.007728456870883796, 'shrinkage_max': 1.117636389453343, 'oob_split_ratio': 0.5734892256790889}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:45,434] Trial 86 finished with value: 0.0034985566676208582 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (2, 3, 4), 'use_calendar': True, 'ridge_alpha': 0.050375306300706114, 'shrinkage_max': 0.7901147656140213, 'oob_split_ratio': 0.6280516355304003}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:45,610] Trial 87 finished with value: 0.0037236458211989585 and parameters: {'foundation_window': 3, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.030529104025134975, 'shrinkage_max': 0.44305742211808447, 'oob_split_ratio': 0.5884289694541046}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:45,794] Trial 88 finished with value: 0.003370750697891435 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (2, 4, 8), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.012325641895113676, 'shrinkage_max': 0.5920757807347586, 'oob_split_ratio': 0.7805428835563168}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:46,007] Trial 89 finished with value: 0.004059051157050999 and parameters: {'foundation_window': 3, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (2, 4, 8), 'use_calendar': False, 'ridge_alpha': 0.02181150533438221, 'shrinkage_max': 0.9709277546479624, 'oob_split_ratio': 0.7604590041212986}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:46,189] Trial 90 finished with value: 0.0032680074181643346 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.042658758247673026, 'shrinkage_max': 0.661622285664735, 'oob_split_ratio': 0.582962235920735}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:46,370] Trial 91 finished with value: 0.003242345381798427 and parameters: {'foundation_window': 2, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.01151150079719429, 'shrinkage_max': 0.9626012160897429, 'oob_split_ratio': 0.5799183253768024}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:46,544] Trial 92 finished with value: 0.0031979380368540983 and parameters: {'foundation_window': 2, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.0029325764962912938, 'shrinkage_max': 0.8562702047716005, 'oob_split_ratio': 0.5586800714346254}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:46,733] Trial 93 finished with value: 0.00329388743055662 and parameters: {'foundation_window': 2, 'ar_lags': 3, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.24747628791670237, 'shrinkage_max': 0.8844471033396866, 'oob_split_ratio': 0.5596946450342115}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:46,908] Trial 94 finished with value: 0.0036287772659178235 and parameters: {'foundation_window': 2, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.0010705800133507678, 'shrinkage_max': 0.32442211559070655, 'oob_split_ratio': 0.6131893987981373}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:47,090] Trial 95 finished with value: 0.0038909818329558687 and parameters: {'foundation_window': 3, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.0021793742213427583, 'shrinkage_max': 1.202278375335291, 'oob_split_ratio': 0.5743863151961616}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:47,279] Trial 96 finished with value: 0.0032081863834823566 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.005911388010370877, 'shrinkage_max': 0.4075687978896077, 'oob_split_ratio': 0.6035347583791}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:47,498] Trial 97 finished with value: 0.0033586275803835362 and parameters: {'foundation_window': 2, 'ar_lags': 3, 'ema_spans': (3, 6), 'conv_scales': (3, 6, 12), 'use_calendar': False, 'ridge_alpha': 0.005901034694138207, 'shrinkage_max': 0.25002124486759714, 'oob_split_ratio': 0.7166547618554111}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:47,673] Trial 98 finished with value: 0.003797341915894019 and parameters: {'foundation_window': 3, 'ar_lags': 5, 'ema_spans': (2, 4), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.001432261395417854, 'shrinkage_max': 0.4178491811648444, 'oob_split_ratio': 0.5925753559396923}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:47,894] Trial 99 finished with value: 0.003607408530349285 and parameters: {'foundation_window': 2, 'ar_lags': 4, 'ema_spans': (3, 6), 'conv_scales': (2, 3, 4), 'use_calendar': True, 'ridge_alpha': 0.003890555102416049, 'shrinkage_max': 0.6911551121524264, 'oob_split_ratio': 0.5547935309736006}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:48,099] Trial 100 finished with value: 0.003552049530646953 and parameters: {'foundation_window': 3, 'ar_lags': 6, 'ema_spans': (2, 4, 8), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.015887442878637005, 'shrinkage_max': 0.589219339883424, 'oob_split_ratio': 0.5694228258505769}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:48,293] Trial 101 finished with value: 0.003249026854664595 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.05999307926885326, 'shrinkage_max': 0.8129317094270214, 'oob_split_ratio': 0.6022023739478742}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:48,472] Trial 102 finished with value: 0.0031928144678764632 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.003335454425623645, 'shrinkage_max': 0.5438539948962298, 'oob_split_ratio': 0.6010898754740294}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:48,647] Trial 103 finished with value: 0.003196025798474659 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.003139195584572231, 'shrinkage_max': 0.5553924295559413, 'oob_split_ratio': 0.6143519136931213}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:48,829] Trial 104 finished with value: 0.003429153644633222 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.0024805123978125544, 'shrinkage_max': 0.5322363421357639, 'oob_split_ratio': 0.6162529706995766}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:49,010] Trial 105 finished with value: 0.0032329878836004525 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.003535502808295234, 'shrinkage_max': 0.4451437053375768, 'oob_split_ratio': 0.586372315039607}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:49,187] Trial 106 finished with value: 0.003894902548944683 and parameters: {'foundation_window': 3, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.0017375938423790387, 'shrinkage_max': 0.3518316963193881, 'oob_split_ratio': 0.5856169386031453}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:49,372] Trial 107 finished with value: 0.00318817351351075 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.0034081515117178186, 'shrinkage_max': 0.7181826293952217, 'oob_split_ratio': 0.5608765181843494}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:49,550] Trial 108 finished with value: 0.0031924016470219925 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.0029556403159837477, 'shrinkage_max': 0.7356658794911843, 'oob_split_ratio': 0.5617615682480128}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:49,727] Trial 109 finished with value: 0.0036486542046851376 and parameters: {'foundation_window': 3, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.004482534828415871, 'shrinkage_max': 0.7067647111972182, 'oob_split_ratio': 0.5635952603188155}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:49,950] Trial 110 finished with value: 0.0033190177983910742 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (2, 3, 5, 8), 'conv_scales': (2, 4, 8), 'use_calendar': False, 'ridge_alpha': 0.002992039884456622, 'shrinkage_max': 0.6395917011308814, 'oob_split_ratio': 0.557026670055705}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:50,144] Trial 111 finished with value: 0.003241507427818912 and parameters: {'foundation_window': 2, 'ar_lags': 5, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.0016668860089084868, 'shrinkage_max': 0.7604190809300553, 'oob_split_ratio': 0.5700178851203911}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:50,337] Trial 112 finished with value: 0.0031881155934972497 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.0077025973733661724, 'shrinkage_max': 0.5539348966276102, 'oob_split_ratio': 0.5617999842898559}. Best is trial 79 with value: 0.0031828335567146877.
# [I 2026-07-03 20:20:50,514] Trial 113 finished with value: 0.0031658398834531524 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.005174340682469713, 'shrinkage_max': 0.6259079620846917, 'oob_split_ratio': 0.5621668534007931}. Best is trial 113 with value: 0.0031658398834531524.
# [I 2026-07-03 20:20:50,698] Trial 114 finished with value: 0.0031710542032845628 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.006579862432373676, 'shrinkage_max': 0.6355128732953934, 'oob_split_ratio': 0.5613043244501116}. Best is trial 113 with value: 0.0031658398834531524.
# [I 2026-07-03 20:20:50,874] Trial 115 finished with value: 0.0031871731289363926 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.006766664983729704, 'shrinkage_max': 0.39059482438721593, 'oob_split_ratio': 0.5616456474670484}. Best is trial 113 with value: 0.0031658398834531524.
# [I 2026-07-03 20:20:51,056] Trial 116 finished with value: 0.0031731385248530714 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.007386287802752821, 'shrinkage_max': 0.6407260714161062, 'oob_split_ratio': 0.5521759761880076}. Best is trial 113 with value: 0.0031658398834531524.
# [I 2026-07-03 20:20:51,246] Trial 117 finished with value: 0.003548959429647997 and parameters: {'foundation_window': 3, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.007439234783827253, 'shrinkage_max': 0.631243796773113, 'oob_split_ratio': 0.5516210501256804}. Best is trial 113 with value: 0.0031658398834531524.
# [I 2026-07-03 20:20:51,433] Trial 118 finished with value: 0.003160617898609398 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.008744199224544882, 'shrinkage_max': 0.7637106145103838, 'oob_split_ratio': 0.5604371404419334}. Best is trial 118 with value: 0.003160617898609398.
# [I 2026-07-03 20:20:51,616] Trial 119 finished with value: 0.0031901236080474193 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.00453354914811853, 'shrinkage_max': 0.8594558864022109, 'oob_split_ratio': 0.5609395354593378}. Best is trial 118 with value: 0.003160617898609398.
# [I 2026-07-03 20:20:51,829] Trial 120 finished with value: 0.004723855406145735 and parameters: {'foundation_window': 3, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6, 12), 'use_calendar': True, 'ridge_alpha': 0.008784129785674083, 'shrinkage_max': 0.7626420518249146, 'oob_split_ratio': 0.5625875376781132}. Best is trial 118 with value: 0.003160617898609398.
# [I 2026-07-03 20:20:52,012] Trial 121 finished with value: 0.003187309343611108 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.004797844068739694, 'shrinkage_max': 0.8730748422181477, 'oob_split_ratio': 0.5587409999479356}. Best is trial 118 with value: 0.003160617898609398.
# [I 2026-07-03 20:20:52,191] Trial 122 finished with value: 0.003167128317390704 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.004268377977400849, 'shrinkage_max': 0.9347485568103315, 'oob_split_ratio': 0.5511436250075435}. Best is trial 118 with value: 0.003160617898609398.
# [I 2026-07-03 20:20:52,409] Trial 123 finished with value: 0.0031675993614766473 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.005146365444288907, 'shrinkage_max': 0.9335183416777009, 'oob_split_ratio': 0.5553507405830281}. Best is trial 118 with value: 0.003160617898609398.
# [I 2026-07-03 20:20:52,593] Trial 124 finished with value: 0.003172583050513694 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.004410367250759247, 'shrinkage_max': 0.9454910572843434, 'oob_split_ratio': 0.5560310105287447}. Best is trial 118 with value: 0.003160617898609398.
# [I 2026-07-03 20:20:52,778] Trial 125 finished with value: 0.0031705345205501547 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.004987291549837204, 'shrinkage_max': 0.9376829538238095, 'oob_split_ratio': 0.5508651508714029}. Best is trial 118 with value: 0.003160617898609398.
# [I 2026-07-03 20:20:52,957] Trial 126 finished with value: 0.003997847358503747 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (2, 4), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.006713412845334121, 'shrinkage_max': 0.9171865138827404, 'oob_split_ratio': 0.5508654565945522}. Best is trial 118 with value: 0.003160617898609398.
# [I 2026-07-03 20:20:53,168] Trial 127 finished with value: 0.0033551559770941485 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (2, 3, 4), 'use_calendar': False, 'ridge_alpha': 0.004382382708272271, 'shrinkage_max': 1.083748909363984, 'oob_split_ratio': 0.5554024024946026}. Best is trial 118 with value: 0.003160617898609398.
# [I 2026-07-03 20:20:53,359] Trial 128 finished with value: 0.0032046541661698985 and parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (2, 4, 8), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.00866517504614568, 'shrinkage_max': 0.9489028986796433, 'oob_split_ratio': 0.5680940702949512}. Best is trial 118 with value: 0.003160617898609398.
# [I 2026-07-03 20:20:53,544] Trial 129 finished with value: 0.0035542875581498017 and parameters: {'foundation_window': 3, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.005571850841132431, 'shrinkage_max': 1.2303813005536641, 'oob_split_ratio': 0.5500965016078422}. Best is trial 118 with value: 0.003160617898609398.
# ...
# [I 2026-07-03 20:21:54,014] Trial 156 finished with value: 1.4260725535569672 and parameters: {'aci_target': 0.04712072410809427, 'aci_step_size': 0.04213349056463551, 'interval_scale': 1.1565364774513904, 'interval_power': 0.012080148213234457, 'min_width_factor': 0.6829137966212373}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:54,194] Trial 157 finished with value: 1.4470934546463168 and parameters: {'aci_target': 0.047612564073301944, 'aci_step_size': 0.039810056737681274, 'interval_scale': 1.139965320962599, 'interval_power': 0.04029683631493077, 'min_width_factor': 0.7021816265636064}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:54,371] Trial 158 finished with value: 1.4196195307607857 and parameters: {'aci_target': 0.048222124574996056, 'aci_step_size': 0.04196385052734969, 'interval_scale': 1.1423731167825737, 'interval_power': 0.0019666829140710593, 'min_width_factor': 0.6651737230582786}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:54,549] Trial 159 finished with value: 1.481696671059341 and parameters: {'aci_target': 0.04620338696218162, 'aci_step_size': 0.04236816937960914, 'interval_scale': 1.280976738863198, 'interval_power': 0.00388345727331923, 'min_width_factor': 0.7331595298093109}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:54,724] Trial 160 finished with value: 1.586025466574178 and parameters: {'aci_target': 0.04171832935583418, 'aci_step_size': 0.03444191124151258, 'interval_scale': 1.3206737461287301, 'interval_power': 0.025007435647349807, 'min_width_factor': 0.6724797337714176}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:54,899] Trial 161 finished with value: 1.883724805822068 and parameters: {'aci_target': 0.04972470844653069, 'aci_step_size': 0.047898591373198345, 'interval_scale': 1.119015746749866, 'interval_power': 0.002471958759977421, 'min_width_factor': 0.6374378477900663}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:55,085] Trial 162 finished with value: 1.4567674129071009 and parameters: {'aci_target': 0.059313729462055584, 'aci_step_size': 0.041652557152580164, 'interval_scale': 1.1724858396069309, 'interval_power': 0.04771255030310278, 'min_width_factor': 0.6080452442542162}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:55,275] Trial 163 finished with value: 1.4243909450969618 and parameters: {'aci_target': 0.05104873152158866, 'aci_step_size': 0.05750743275625511, 'interval_scale': 1.1385974387023803, 'interval_power': 0.0008739750384995151, 'min_width_factor': 0.6794879660668087}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:55,469] Trial 164 finished with value: 1.4261315109387036 and parameters: {'aci_target': 0.050110882978072376, 'aci_step_size': 0.05150333217368086, 'interval_scale': 1.1289314113396076, 'interval_power': 0.004504546374745412, 'min_width_factor': 0.6847096635920347}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:55,645] Trial 165 finished with value: 1.573473821469572 and parameters: {'aci_target': 0.05016774785144095, 'aci_step_size': 0.05981514711634123, 'interval_scale': 1.1502325623998126, 'interval_power': 0.000441199181414614, 'min_width_factor': 0.7867369107347867}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:55,818] Trial 166 finished with value: 1.77630814862882 and parameters: {'aci_target': 0.04476239041927488, 'aci_step_size': 0.04953216534347749, 'interval_scale': 1.4472836194666787, 'interval_power': 0.03988504451101437, 'min_width_factor': 0.6831967343004807}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:55,996] Trial 167 finished with value: 1.4857113335439276 and parameters: {'aci_target': 0.05638119434167353, 'aci_step_size': 0.05525643998634987, 'interval_scale': 1.2429998147172436, 'interval_power': 0.02384656217070766, 'min_width_factor': 0.737563161275585}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:56,192] Trial 168 finished with value: 1.8752505319930146 and parameters: {'aci_target': 0.04137998550441841, 'aci_step_size': 0.03597270178161179, 'interval_scale': 1.1189270891521053, 'interval_power': 0.0006409394923408123, 'min_width_factor': 0.6517657447669273}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:56,377] Trial 169 finished with value: 1.649166156661564 and parameters: {'aci_target': 0.051610691784596104, 'aci_step_size': 0.04505787909487919, 'interval_scale': 1.1896641638903147, 'interval_power': 0.05018604648390612, 'min_width_factor': 0.824583078330782}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:56,550] Trial 170 finished with value: 1.5430349969711112 and parameters: {'aci_target': 0.048370554849511575, 'aci_step_size': 0.053820904041684034, 'interval_scale': 1.288456394360669, 'interval_power': 0.026264360806794868, 'min_width_factor': 0.6820415413627846}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:56,722] Trial 171 finished with value: 3.7390780147190683 and parameters: {'aci_target': 0.06234985569295185, 'aci_step_size': 0.07143649692252943, 'interval_scale': 1.1023175046021856, 'interval_power': 0.0002502877400596924, 'min_width_factor': 0.5620657785639954}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:56,899] Trial 172 finished with value: 1.5158072289474185 and parameters: {'aci_target': 0.04560412922865884, 'aci_step_size': 0.030753022480796685, 'interval_scale': 1.1960520656478382, 'interval_power': 0.05683783611870028, 'min_width_factor': 0.6206865901336309}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:57,092] Trial 173 finished with value: 1.5566881962591 and parameters: {'aci_target': 0.05699794851082946, 'aci_step_size': 0.05894802669410071, 'interval_scale': 1.1474510216322065, 'interval_power': 0.10495013184422376, 'min_width_factor': 0.5505624919747031}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:57,276] Trial 174 finished with value: 1.5509281882005737 and parameters: {'aci_target': 0.0394988358422822, 'aci_step_size': 0.03181607703835589, 'interval_scale': 1.2508984345339926, 'interval_power': 0.043511736884479166, 'min_width_factor': 0.5994922610973344}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:57,452] Trial 175 finished with value: 1.4353242324601554 and parameters: {'aci_target': 0.052294045128184995, 'aci_step_size': 0.02414974024461663, 'interval_scale': 1.0827789621035495, 'interval_power': 0.026489712473036255, 'min_width_factor': 0.7122878281563905}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:57,628] Trial 176 finished with value: 1.4363663569480674 and parameters: {'aci_target': 0.053750870962742454, 'aci_step_size': 0.028565922638836585, 'interval_scale': 1.099884093717068, 'interval_power': 0.025336175112786644, 'min_width_factor': 0.7154142016201254}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:57,802] Trial 177 finished with value: 1.4302718459144361 and parameters: {'aci_target': 0.052419060800263394, 'aci_step_size': 0.19899940498542387, 'interval_scale': 1.1628675487757107, 'interval_power': 0.02385816746069381, 'min_width_factor': 0.6971306685192354}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:57,983] Trial 178 finished with value: 1.5348583038925356 and parameters: {'aci_target': 0.052454635777619156, 'aci_step_size': 0.03672112585051179, 'interval_scale': 1.0366224102125932, 'interval_power': 0.0023494767615339033, 'min_width_factor': 0.7674291519462643}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:58,161] Trial 179 finished with value: 1.7028361817142066 and parameters: {'aci_target': 0.04977081029289686, 'aci_step_size': 0.03260617354948118, 'interval_scale': 1.331857044221267, 'interval_power': 0.06256905510182052, 'min_width_factor': 0.7170947287800535}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:58,342] Trial 180 finished with value: 1.4505460283517986 and parameters: {'aci_target': 0.05610716354603639, 'aci_step_size': 0.027902246358960908, 'interval_scale': 1.2082885810869568, 'interval_power': 0.025173654140973164, 'min_width_factor': 0.6964772400765712}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:58,520] Trial 181 finished with value: 1.863530590673394 and parameters: {'aci_target': 0.06560309255488918, 'aci_step_size': 0.15797106871412867, 'interval_scale': 1.1496638757296131, 'interval_power': 0.02593386235849645, 'min_width_factor': 0.6605557007566443}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:58,695] Trial 182 finished with value: 1.451225594550057 and parameters: {'aci_target': 0.0531661859717242, 'aci_step_size': 0.028851601760838976, 'interval_scale': 1.1018936525666576, 'interval_power': 0.05800942133691124, 'min_width_factor': 0.6374303692213648}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:58,870] Trial 183 finished with value: 1.6207755896304836 and parameters: {'aci_target': 0.0610711000077673, 'aci_step_size': 0.14899571387323848, 'interval_scale': 1.1599989828282478, 'interval_power': 0.022667321820813668, 'min_width_factor': 0.8103877948152466}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:59,048] Trial 184 finished with value: 1.528392046859289 and parameters: {'aci_target': 0.04188795970078122, 'aci_step_size': 0.04022054704179851, 'interval_scale': 1.0498251220671992, 'interval_power': 0.07542037601948005, 'min_width_factor': 0.764196023429647}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:59,227] Trial 185 finished with value: 1.4286893703645434 and parameters: {'aci_target': 0.048246213967049284, 'aci_step_size': 0.09573651520246308, 'interval_scale': 1.094408630966333, 'interval_power': 0.04631319817563654, 'min_width_factor': 0.678835617872744}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:59,407] Trial 186 finished with value: 1.5148863450691594 and parameters: {'aci_target': 0.047928569524654345, 'aci_step_size': 0.07905618686797578, 'interval_scale': 1.1080242469755581, 'interval_power': 0.10289564412380728, 'min_width_factor': 0.7070164781825878}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:59,586] Trial 187 finished with value: 1.4826449325432176 and parameters: {'aci_target': 0.05745873641366494, 'aci_step_size': 0.09497954774031846, 'interval_scale': 1.230345574905707, 'interval_power': 0.05068700749509327, 'min_width_factor': 0.6917897167424899}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:59,763] Trial 188 finished with value: 1.4884696713186893 and parameters: {'aci_target': 0.05069936959346082, 'aci_step_size': 0.11528589552643657, 'interval_scale': 1.0372105757414005, 'interval_power': 0.005615574050373822, 'min_width_factor': 0.744234835659344}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:21:59,938] Trial 189 finished with value: 1.466118880735532 and parameters: {'aci_target': 0.043514610970354604, 'aci_step_size': 0.04418081090987703, 'interval_scale': 1.076301832065435, 'interval_power': 0.07321001929023624, 'min_width_factor': 0.6640481477925271}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:22:00,118] Trial 190 finished with value: 1.4282631213825026 and parameters: {'aci_target': 0.046062268823990164, 'aci_step_size': 0.05123575184033892, 'interval_scale': 1.200592678762792, 'interval_power': 0.0011311180119670666, 'min_width_factor': 0.6223702201814598}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:22:00,309] Trial 191 finished with value: 1.4259664915526244 and parameters: {'aci_target': 0.04811678610721297, 'aci_step_size': 0.051008434981570254, 'interval_scale': 1.1930519595025282, 'interval_power': 4.6270149766624614e-05, 'min_width_factor': 0.6288053877596731}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:22:00,490] Trial 192 finished with value: 1.4511331925251283 and parameters: {'aci_target': 0.04756116962927137, 'aci_step_size': 0.05204752186726195, 'interval_scale': 1.2605609842960461, 'interval_power': 0.0023222555114290055, 'min_width_factor': 0.6216046595057189}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:22:00,664] Trial 193 finished with value: 1.4508227330290726 and parameters: {'aci_target': 0.04566867380771326, 'aci_step_size': 0.04788943337915585, 'interval_scale': 1.1945007599118294, 'interval_power': 0.03293837318453943, 'min_width_factor': 0.6497975003722835}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:22:00,836] Trial 194 finished with value: 1.7070958493748103 and parameters: {'aci_target': 0.03758210268101672, 'aci_step_size': 0.06819978901759972, 'interval_scale': 1.3794595948225656, 'interval_power': 0.04563637388807606, 'min_width_factor': 0.5959244715982812}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:22:01,014] Trial 195 finished with value: 1.4367656033348148 and parameters: {'aci_target': 0.052206146605910664, 'aci_step_size': 0.05041335406465458, 'interval_scale': 1.1208431286708553, 'interval_power': 0.02121265195554203, 'min_width_factor': 0.7166119407803715}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:22:01,191] Trial 196 finished with value: 1.4379501855401526 and parameters: {'aci_target': 0.04246455487603917, 'aci_step_size': 0.13552579323190317, 'interval_scale': 1.1963530864998388, 'interval_power': 0.02166471760744377, 'min_width_factor': 0.6795329003279704}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:22:01,367] Trial 197 finished with value: 1.4709874822685618 and parameters: {'aci_target': 0.048061329096290524, 'aci_step_size': 0.06202710373974238, 'interval_scale': 1.2828866648987398, 'interval_power': 0.0012185832797919874, 'min_width_factor': 0.6326408967932884}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:22:01,542] Trial 198 finished with value: 1.441405069299368 and parameters: {'aci_target': 0.03447905249514192, 'aci_step_size': 0.04524345835101083, 'interval_scale': 1.077454026769936, 'interval_power': 0.053185559920699496, 'min_width_factor': 0.5909181913457536}. Best is trial 154 with value: 1.4191092877826412.
# [I 2026-07-03 20:22:01,715] Trial 199 finished with value: 1.4193596258078327 and parameters: {'aci_target': 0.051164109063010325, 'aci_step_size': 0.18799695997653096, 'interval_scale': 1.1644096599130072, 'interval_power': 0.037902674614007426, 'min_width_factor': 0.6643940081994232}. Best is trial 154 with value: 1.4191092877826412.
# S3-FastSketch best point parameters:
# {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.0066068453158860665, 'shrinkage_max': 1.2937706004332123, 'oob_split_ratio': 0.5656144376904828}
# S3-FastSketch best UQ parameters:
# {'aci_target': 0.048312154019363514, 'aci_step_size': 0.032138245854063455, 'interval_scale': 1.150828140857102, 'interval_power': 0.0006090773299027524, 'min_width_factor': 0.623842720251909}
# S3-FastSketch test metrics on modelling scale:
#         mae      mse      rmse       r2  mape_percent     mape  smape_percent  \
# 0  0.016403  0.00044  0.020985  0.15323      0.220962  0.00221       0.221295
#
#       smape  ecp  coverage_error        iw  mean_width       mis  \
# 0  0.002213  1.0             0.1  0.091543    0.091543  0.091543
#
#    interval_score      msis    scale  elapsed_seconds  trainable_params
# 0        0.091543  1.247685  0.07337         0.169759                24

# %% [markdown]
# ## 8. Baselines with fixed parameters and a common ACI wrapper
#
# Each baseline is fitted twice:
#
# 1. on a chronological training core to obtain calibration residuals;
# 2. on the complete training series to produce the final test forecast.
#
# The interval for test step `t` is formed before observing `y_t`. After scoring that step, the ACI state is updated for the next one. Thus, the procedure is sequential and does not use future test observations.

# %%
def finite_sample_conformal_quantile(scores, alpha):
    scores = np.asarray(scores, dtype=float).reshape(-1)
    scores = scores[np.isfinite(scores)]
    if len(scores) == 0:
        raise ValueError("No finite calibration scores were produced.")
    level = min(1.0, math.ceil((len(scores) + 1) * (1.0 - alpha)) / len(scores))
    try:
        return float(np.quantile(scores, level, method="higher"))
    except TypeError:
        return float(np.quantile(scores, level, interpolation="higher"))


def adaptive_conformal_path(y_true, y_pred, calibration_scores, alpha=0.10, step_size=0.05):
    y_true = np.asarray(y_true, dtype=float).reshape(-1)
    y_pred = np.asarray(y_pred, dtype=float).reshape(-1)
    buffer = list(np.asarray(calibration_scores, dtype=float).reshape(-1))
    alpha_t = float(alpha)
    lower, upper, alpha_path = [], [], []

    for observed, predicted in zip(y_true, y_pred):
        q = finite_sample_conformal_quantile(buffer, alpha_t)
        lo = float(predicted - q)
        up = float(predicted + q)
        lower.append(lo)
        upper.append(up)
        alpha_path.append(alpha_t)

        miss = float(observed < lo or observed > up)
        alpha_t = float(np.clip(alpha_t + step_size * (alpha - miss), 0.01, 0.50))
        buffer.append(abs(float(observed - predicted)))

    return np.asarray(lower), np.asarray(upper), np.asarray(alpha_path)


def evaluate_fixed_baseline_with_aci(
    model_name,
    params,
    train,
    test,
    *,
    calibration_ratio=0.20,
    alpha=0.10,
    aci_step_size=0.05,
    seasonal_period=12,
):
    train = ensure_series(train, name="train")
    test = ensure_series(test, name="test")

    split = int(np.floor((1.0 - calibration_ratio) * len(train)))
    split = max(split, seasonal_period + 5)
    split = min(split, len(train) - 2)
    train_core = train.iloc[:split]
    calibration = train.iloc[split:]

    _, calibration_forecast = fit_predict_baseline(
        model_name,
        train_core,
        len(calibration),
        params,
    )
    calibration_output = parse_forecast_output(calibration_forecast)
    if len(calibration_output.pred) != len(calibration):
        raise ValueError(
            f"{model_name} returned {len(calibration_output.pred)} calibration values; "
            f"expected {len(calibration)}."
        )
    calibration_scores = np.abs(calibration.to_numpy() - calibration_output.pred)

    start = time.perf_counter()
    model, test_forecast = fit_predict_baseline(model_name, train, len(test), params)
    elapsed = time.perf_counter() - start
    test_output = parse_forecast_output(test_forecast)

    if test_output.has_interval:
        lower, upper = test_output.lower, test_output.upper
        interval_source = "native"
        alpha_path = np.full(len(test), alpha)
    else:
        lower, upper, alpha_path = adaptive_conformal_path(
            test,
            test_output.pred,
            calibration_scores,
            alpha=alpha,
            step_size=aci_step_size,
        )
        interval_source = "external_aci"

    forecast = pd.DataFrame(
        {
            "pred": test_output.pred,
            "lower": lower,
            "upper": upper,
            "aci_alpha": alpha_path,
        },
        index=test.index,
    )

    metrics = evaluate_forecast(
        test,
        forecast["pred"],
        y_train=train,
        lower=forecast["lower"],
        upper=forecast["upper"],
        alpha=alpha,
        seasonal_period=seasonal_period,
        elapsed_seconds=elapsed,
        trainable_params=count_trainable_parameters(model),
    )

    return {
        "model": model,
        "forecast": forecast,
        "metrics": metrics,
        "interval_source": interval_source,
        "calibration_size": len(calibration),
    }

# %%
baseline_results = {}
baseline_failures = []

for baseline_name in BASELINE_ORDER:
    display_name = BASELINE_DISPLAY_NAMES.get(baseline_name, baseline_name)
    print(f"\nEvaluating {display_name} with fixed original parameters...")
    try:
        result = evaluate_fixed_baseline_with_aci(
            baseline_name,
            BASELINE_PARAMS[baseline_name],
            train_series,
            test_series,
            calibration_ratio=BASELINE_CALIBRATION_RATIO,
            alpha=ALPHA,
            aci_step_size=BASELINE_ACI_STEP_SIZE,
            seasonal_period=SEASONAL_PERIOD,
        )
        baseline_results[display_name] = result
        print(result["metrics"])
    except Exception as exc:
        baseline_failures.append(
            {
                "model": display_name,
                "exception_type": type(exc).__name__,
                "error": str(exc),
            }
        )
        print(f"FAILED: {type(exc).__name__}: {exc}")

if baseline_failures:
    print("\nBaseline failures were retained for audit:")
    display(pd.DataFrame(baseline_failures))
# Out:
# Evaluating CNN with fixed original parameters...
# {'mae': 0.02466300520102238, 'mse': 0.0010168314853626688, 'rmse': 0.03188779524148179, 'r2': -0.9552639286339615, 'mape_percent': 0.332253319191237, 'mape': 0.00332253319191237, 'smape_percent': 0.33156525391694114, 'smape': 0.0033156525391694115, 'ecp': 1.0, 'coverage_error': 0.09999999999999998, 'iw': 0.4207819227555598, 'mean_width': 0.4207819227555598, 'mis': 0.4207819227555598, 'interval_score': 0.4207819227555598, 'msis': 5.735036844928813, 'scale': 0.07337039571552793, 'elapsed_seconds': 6.071899524999935, 'trainable_params': 65372}
#
# Evaluating LSTM with fixed original parameters...
# {'mae': 0.055742185592361805, 'mse': 0.00427588127544421, 'rmse': 0.06539022308758558, 'r2': -7.222086492547527, 'mape_percent': 0.7513049419786954, 'mape': 0.007513049419786953, 'smape_percent': 0.7548833212398122, 'smape': 0.007548833212398121, 'ecp': 0.8333333333333334, 'coverage_error': 0.06666666666666665, 'iw': 0.20795788325010708, 'mean_width': 0.20795788325010708, 'mis': 0.2554008689224883, 'interval_score': 0.2554008689224883, 'msis': 3.4809798479584306, 'scale': 0.07337039571552793, 'elapsed_seconds': 5.170074251999949, 'trainable_params': 10124}
#
# Evaluating Gaussian Process with fixed original parameters...
# {'mae': 0.01616244254257615, 'mse': 0.00034419867171486194, 'rmse': 0.018552592048413665, 'r2': 0.3381408259130012, 'mape_percent': 0.21787079445489987, 'mape': 0.0021787079445489987, 'smape_percent': 0.2180423307672847, 'smape': 0.0021804233076728467, 'ecp': 1.0, 'coverage_error': 0.09999999999999998, 'iw': 0.27634770064256653, 'mean_width': 0.27634770064256653, 'mis': 0.27634770064256653, 'interval_score': 0.27634770064256653, 'msis': 3.7664741745979295, 'scale': 0.07337039571552793, 'elapsed_seconds': 0.6545724149999614, 'trainable_params': 1032}
#
# Evaluating Kernel Ridge with fixed original parameters...
# {'mae': 0.019060979970234444, 'mse': 0.00047193193092606175, 'rmse': 0.021723994359372813, 'r2': 0.09252270942299845, 'mape_percent': 0.2568566793244323, 'mape': 0.0025685667932443226, 'smape_percent': 0.25689868736998817, 'smape': 0.0025689868736998816, 'ecp': 1.0, 'coverage_error': 0.09999999999999998, 'iw': 0.20060385298324324, 'mean_width': 0.20060385298324324, 'mis': 0.20060385298324324, 'interval_score': 0.20060385298324324, 'msis': 2.734125269829885, 'scale': 0.07337039571552793, 'elapsed_seconds': 0.004947927999978674, 'trainable_params': 792}
#
# Evaluating AR with fixed original parameters...
# {'mae': 0.029030964536404264, 'mse': 0.001045494585253959, 'rmse': 0.0323341086973796, 'r2': -1.0103801657952083, 'mape_percent': 0.39082036327797626, 'mape': 0.0039082036327797625, 'smape_percent': 0.391738832233937, 'smape': 0.00391738832233937, 'ecp': 0.9166666666666666, 'coverage_error': 0.016666666666666607, 'iw': 0.16581346670362893, 'mean_width': 0.16581346670362893, 'mis': 0.16616683667252255, 'interval_score': 0.16616683667252255, 'msis': 2.2647668048130125, 'scale': 0.07337039571552793, 'elapsed_seconds': 0.008909351000056631, 'trainable_params': 2}
#
# Evaluating ARIMA with fixed original parameters...
# {'mae': 0.02030140955975246, 'mse': 0.0006297810926219263, 'rmse': 0.02509543967779657, 'r2': -0.21100523642827862, 'mape_percent': 0.27403055852554004, 'mape': 0.0027403055852554003, 'smape_percent': 0.27352083958636275, 'smape': 0.0027352083958636277, 'ecp': 1.0, 'coverage_error': 0.09999999999999998, 'iw': 0.16735638601408778, 'mean_width': 0.16735638601408778, 'mis': 0.16735638601408778, 'interval_score': 0.16735638601408778, 'msis': 2.2809797382443295, 'scale': 0.07337039571552793, 'elapsed_seconds': 0.4036225940000122, 'trainable_params': 7}
#
# Evaluating ARKAN with fixed original parameters...
# {'mae': 0.06083259432073529, 'mse': 0.00433488377527012, 'rmse': 0.06583983425913313, 'r2': -7.335542322023233, 'mape_percent': 0.8188787105472186, 'mape': 0.008188787105472186, 'smape_percent': 0.8228210301277427, 'smape': 0.008228210301277426, 'ecp': 1.0, 'coverage_error': 0.09999999999999998, 'iw': 0.39964414956506555, 'mean_width': 0.39964414956506555, 'mis': 0.39964414956506555, 'interval_score': 0.39964414956506555, 'msis': 5.446940086224529, 'scale': 0.07337039571552793, 'elapsed_seconds': 2.9844774519999646, 'trainable_params': 199975}
#
# Evaluating EasyTSF (NLinear) with fixed original parameters...
# {'mae': 0.018905535756151465, 'mse': 0.0005375936859253395, 'rmse': 0.023186066633332603, 'r2': -0.0337381930854419, 'mape_percent': 0.2550321709466649, 'mape': 0.0025503217094666494, 'smape_percent': 0.254591109134279, 'smape': 0.00254591109134279, 'ecp': 1.0, 'coverage_error': 0.09999999999999998, 'iw': 0.1371746873098972, 'mean_width': 0.1371746873098972, 'mis': 0.1371746873098972, 'interval_score': 0.1371746873098972, 'msis': 1.869619019662257, 'scale': 0.07337039571552793, 'elapsed_seconds': 1.5571540790000427, 'trainable_params': 5}
#
# Evaluating ETS with fixed original parameters...
# {'mae': 0.018160957997326383, 'mse': 0.0005054068695666433, 'rmse': 0.022481255960614017, 'r2': 0.02815379384617611, 'mape_percent': 0.24457237119449032, 'mape': 0.002445723711944903, 'smape_percent': 0.24499446714179945, 'smape': 0.0024499446714179945, 'ecp': 1.0, 'coverage_error': 0.09999999999999998, 'iw': 0.19594663556646053, 'mean_width': 0.19594663556646053, 'mis': 0.19594663556646053, 'interval_score': 0.19594663556646053, 'msis': 2.6706498398371163, 'scale': 0.07337039571552793, 'elapsed_seconds': 0.1256486010000799, 'trainable_params': 18}
#
# Evaluating Chronos with fixed original parameters...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/191M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# {'mae': 0.017089720018208743, 'mse': 0.0004217278482584415, 'rmse': 0.02053601344610101, 'r2': 0.18906007409276393, 'mape_percent': 0.2302884396928714, 'mape': 0.002302884396928714, 'smape_percent': 0.23045388581807297, 'smape': 0.0023045388581807297, 'ecp': 1.0, 'coverage_error': 0.09999999999999998, 'iw': 0.15236980297418853, 'mean_width': 0.15236980297418853, 'mis': 0.15236980297418853, 'interval_score': 0.15236980297418853, 'msis': 2.076720474085454, 'scale': 0.07337039571552793, 'elapsed_seconds': 1.0527316029999838, 'trainable_params': 0}

# %% [markdown]
# ## 9. Consolidated results on modelling and original scales

# %%
def forecast_to_frame(forecast, index):
    out = parse_forecast_output(forecast)
    frame = pd.DataFrame({"pred": out.pred}, index=index)
    if out.lower is not None and out.upper is not None:
        frame["lower"] = out.lower
        frame["upper"] = out.upper
    return frame


def inverse_forecast_frame(frame, transformation):
    result = frame.copy()
    for column in ("pred", "lower", "upper"):
        if column in result:
            result[column] = inverse_transform(result[column].to_numpy(), transformation)
    if "lower" in result and "upper" in result:
        lower = np.minimum(result["lower"].to_numpy(), result["upper"].to_numpy())
        upper = np.maximum(result["lower"].to_numpy(), result["upper"].to_numpy())
        result["lower"] = lower
        result["upper"] = upper
    return result


all_results = {
    "S3-Forecaster": s3_result,
    "S3-FastSketch": fastsketch_result,
    **baseline_results,
}

model_scale_rows = []
original_scale_rows = []
original_forecasts = {}

for model_name, result in all_results.items():
    model_metrics = result["metrics"]
    model_scale_rows.append(paper_metric_row(model_name, model_metrics))

    model_frame = forecast_to_frame(result["forecast"], test_series.index)
    original_frame = inverse_forecast_frame(model_frame, transformation)
    original_forecasts[model_name] = original_frame

    original_metrics = evaluate_forecast(
        raw_test,
        original_frame["pred"],
        y_train=raw_train,
        lower=original_frame.get("lower"),
        upper=original_frame.get("upper"),
        alpha=ALPHA,
        seasonal_period=SEASONAL_PERIOD,
        elapsed_seconds=model_metrics.get("elapsed_seconds"),
        trainable_params=model_metrics.get("trainable_params"),
    )
    original_scale_rows.append(paper_metric_row(model_name, original_metrics))

model_scale_results = pd.DataFrame(model_scale_rows).sort_values("MAPE (%)").reset_index(drop=True)
original_scale_results = pd.DataFrame(original_scale_rows).sort_values("MAPE (%)").reset_index(drop=True)

print("Results on modelling scale:")
display(model_scale_results)
print("Results on original CIF Monthly scale:")
display(original_scale_results)
# Out:
# Results on modelling scale:
#                 Model       MAE       MSE      RMSE       R^2  MAPE (%)  \
# 0    Gaussian Process  0.016162  0.000344  0.018553  0.338141  0.217871
# 1       S3-FastSketch  0.016403  0.000440  0.020985  0.153230  0.220962
# 2             Chronos  0.017090  0.000422  0.020536  0.189060  0.230288
# 3                 ETS  0.018161  0.000505  0.022481  0.028154  0.244572
# 4   EasyTSF (NLinear)  0.018906  0.000538  0.023186 -0.033738  0.255032
# 5        Kernel Ridge  0.019061  0.000472  0.021724  0.092523  0.256857
# 6               ARIMA  0.020301  0.000630  0.025095 -0.211005  0.274031
# 7                 CNN  0.024663  0.001017  0.031888 -0.955264  0.332253
# 8                  AR  0.029031  0.001045  0.032334 -1.010380  0.390820
# 9       S3-Forecaster  0.032958  0.001479  0.038454 -1.843427  0.444923
# 10               LSTM  0.055742  0.004276  0.065390 -7.222086  0.751305
# 11              ARKAN  0.060833  0.004335  0.065840 -7.335542  0.818879
#
#     sMAPE (%)  Time (s)  trainable_params       ECP        IW       MIS  \
# 0    0.218042  0.654572              1032  1.000000  0.276348  0.276348
# 1    0.221295  0.169759                24  1.000000  0.091543  0.091543
# 2    0.230454  1.052732                 0  1.000000  0.152370  0.152370
# 3    0.244994  0.125649                18  1.000000  0.195947  0.195947
# 4    0.254591  1.557154                 5  1.000000  0.137175  0.137175
# 5    0.256899  0.004948               792  1.000000  0.200604  0.200604
# 6    0.273521  0.403623                 7  1.000000  0.167356  0.167356
# 7    0.331565  6.071900             65372  1.000000  0.420782  0.420782
# 8    0.391739  0.008909                 2  0.916667  0.165813  0.166167
# 9    0.443578  0.069189               554  0.916667  0.125998  0.140852
# 10   0.754883  5.170074             10124  0.833333  0.207958  0.255401
# 11   0.822821  2.984477            199975  1.000000  0.399644  0.399644
#
#         MSIS
# 0   3.766474
# 1   1.247685
# 2   2.076720
# 3   2.670650
# 4   1.869619
# 5   2.734125
# 6   2.280980
# 7   5.735037
# 8   2.264767
# 9   1.919736
# 10  3.480980
# 11  5.446940
# Results on original CIF Monthly scale:
#                 Model        MAE           MSE        RMSE       R^2  \
# 0    Gaussian Process  26.783077    940.458304   30.666893  0.344270
# 1       S3-FastSketch  27.179115   1206.411498   34.733435  0.158835
# 2             Chronos  28.407545   1165.072929   34.133165  0.187658
# 3                 ETS  30.102156   1392.312603   37.313705  0.029216
# 4        Kernel Ridge  31.809849   1317.094325   36.291794  0.081662
# 5   EasyTSF (NLinear)  31.750458   1525.078554   39.052254 -0.063354
# 6               ARIMA  33.971101   1751.979204   41.856651 -0.221559
# 7                 CNN  41.961900   3029.006276   55.036409 -1.111961
# 8                  AR  48.019245   2883.316845   53.696525 -1.010379
# 9       S3-Forecaster  55.573098   4166.019760   64.544711 -1.904738
# 10               LSTM  89.829969  11005.453426  104.906880 -6.673502
# 11              ARKAN  98.871541  11506.226043  107.267078 -7.022663
#
#     MAPE (%)  sMAPE (%)  Time (s)  trainable_params       ECP          IW  \
# 0   1.606913   1.616175  0.654572              1032  1.000000  457.739956
# 1   1.622221   1.640217  0.169759                24  1.000000  151.127176
# 2   1.699955   1.708871  1.052732                 0  1.000000  251.756424
# 3   1.793090   1.815960  0.125649                18  1.000000  322.024504
# 4   1.903888   1.905988  0.004948               792  1.000000  333.885185
# 5   1.915148   1.890401  1.557154                 5  1.000000  230.509105
# 6   2.058512   2.029949  0.403623                 7  1.000000  282.557221
# 7   2.505465   2.465837  6.071900             65372  1.000000  719.892463
# 8   2.853150   2.902737  0.008909                 2  0.916667  268.981212
# 9   3.370965   3.295132  0.069189               554  0.916667  217.294695
# 10  5.384390   5.571136  5.170074             10124  0.833333  333.941305
# 11  5.871985   6.080470  2.984477            199975  1.000000  631.669834
#
#            MIS      MSIS
# 0   457.739956  5.120784
# 1   151.127176  1.690675
# 2   251.756424  2.816425
# 3   322.024504  3.602521
# 4   333.885185  3.735208
# 5   230.509105  2.578729
# 6   282.557221  3.160997
# 7   719.892463  8.053511
# 8   269.595535  3.015993
# 9   240.946220  2.695490
# 10  413.357153  4.624269
# 11  631.669834  7.066555

# %% [markdown]
# # 10.IMPORTS AND FINAL FIXED PARAMETERS

# %%
# ============================================================
# CELL 1 — IMPORTS AND FINAL FIXED PARAMETERS
# Run after the core S3, FastSketch and baseline experiments.
# ============================================================

import copy
import gc
import math
import subprocess
import sys
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display

from s3paper.ablation_study import (
    run_fastsketch_ablation,
    run_s3_ablation_study,
)
from s3paper.baselines import fit_predict_baseline
from s3paper.data_efficiency import make_params_feasible
from s3paper.metrics import evaluate_forecast
from s3paper.multi_prior_robustness import (
    ChronosPrior,
    ETSPrior,
    ProphetPrior,
    RollingPrior,
    run_multi_prior_robustness,
)
from s3paper.s3_fastsketch_experiment import evaluate_fastsketch
from s3paper.s3_forecaster_experiment import evaluate_s3_forecaster
from s3paper.shock_analysis import analyze_forecast_shocks
from s3paper.utils import (
    count_trainable_parameters,
    ensure_series,
    parse_forecast_output,
    set_global_seed,
)

SEED = 42
set_global_seed(SEED)

OUTPUT_DIR = Path(
    globals().get(
        "OUTPUT_DIR",
        "/kaggle/working/cif_s3_results",
    )
)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

required_objects = [
    "train_series",
    "test_series",
    "s3_result",
    "fastsketch_result",
    "BASELINE_PARAMS",
]

missing_objects = [
    name for name in required_objects
    if name not in globals()
]

if missing_objects:
    raise NameError(
        f"Run the core experiment cells first. Missing: {missing_objects}"
    )

# ------------------------------------------------------------
# Add the original batch size and gradient clipping parameters.
# ------------------------------------------------------------
if "BASELINE_PARAMS_ORIGINAL" in globals():
    BASELINE_PARAMS = copy.deepcopy(BASELINE_PARAMS)

    BASELINE_PARAMS["ARKAN"].update(
        {
            "batch_size": int(
                BASELINE_PARAMS_ORIGINAL["ARKAN"]["batch_size"]
            ),
            "clip_grad": float(
                BASELINE_PARAMS_ORIGINAL["ARKAN"]["clip_grad"]
            ),
        }
    )

    BASELINE_PARAMS["NLinear"].update(
        {
            "batch_size": int(
                BASELINE_PARAMS_ORIGINAL["EasyTSF"]["batch_size"]
            ),
            "clip_grad": float(
                BASELINE_PARAMS_ORIGINAL["EasyTSF"]["clip_grad"]
            ),
        }
    )

    OMITTED_TRAINING_OPTIONS = {}

BASELINE_ORDER = list(
    globals().get(
        "BASELINE_ORDER",
        [
            "CNN",
            "LSTM",
            "GaussianProcess",
            "KernelRidgeRegressor",
            "AR",
            "ARIMA",
            "ARKAN",
            "NLinear",
            "ETS",
        ],
    )
)

BASELINE_DISPLAY_NAMES = {
    "CNN": "CNN",
    "LSTM": "LSTM",
    "GaussianProcess": "Gaussian Process",
    "KernelRidgeRegressor": "Kernel Ridge",
    "AR": "AR",
    "ARIMA": "ARIMA",
    "ARKAN": "ARKAN",
    "NLinear": "EasyTSF (NLinear)",
    "ETS": "ETS",
    **globals().get("BASELINE_DISPLAY_NAMES", {}),
}

S3_POINT_PARAMS = copy.deepcopy(
    s3_result["best_point_params"]
)
S3_UQ_PARAMS = copy.deepcopy(
    s3_result["best_uq_params"]
)

FASTSKETCH_POINT_PARAMS = copy.deepcopy(
    fastsketch_result["best_point_params"]
)
FASTSKETCH_UQ_PARAMS = copy.deepcopy(
    fastsketch_result["best_uq_params"]
)

S3_ABLATION_PARAMS = copy.deepcopy(S3_POINT_PARAMS)

if "aci_step_size" in S3_UQ_PARAMS:
    S3_ABLATION_PARAMS["aci_step_size"] = (
        S3_UQ_PARAMS["aci_step_size"]
    )

SEASONAL_PERIOD = int(
    globals().get("SEASONAL_PERIOD", 12)
)
ALPHA = float(
    globals().get("ALPHA", 0.10)
)
BASELINE_CALIBRATION_RATIO = float(
    globals().get("BASELINE_CALIBRATION_RATIO", 0.20)
)
BASELINE_ACI_STEP_SIZE = float(
    globals().get("BASELINE_ACI_STEP_SIZE", 0.05)
)

print("Device: CPU")
print("S3 parameters:", S3_POINT_PARAMS)
print("S3 UQ parameters:", S3_UQ_PARAMS)
print("FastSketch parameters:", FASTSKETCH_POINT_PARAMS)
print("FastSketch UQ parameters:", FASTSKETCH_UQ_PARAMS)
print("Baselines:", BASELINE_ORDER)
# Out:
# Device: CPU
# S3 parameters: {'reservoir_size': 43, 'spectral_radius': 0.6431845944160947, 'ar_lags': 2, 'foundation_window': 22, 'regressor_type': 'Ridge', 'reg_alpha': 3.5706149382358325, 'aci_step_size': 0.17751689212303806, 'oob_split_ratio': 0.6756898426028435}
# S3 UQ parameters: {'target_miscoverage': 0.01382679968278653, 'aci_step_size': 0.04007672806448736, 'interval_scale': 0.6005909469147512}
# FastSketch parameters: {'foundation_window': 2, 'ar_lags': 6, 'ema_spans': (3, 6), 'conv_scales': (3, 6), 'use_calendar': False, 'ridge_alpha': 0.0066068453158860665, 'shrinkage_max': 1.2937706004332123, 'oob_split_ratio': 0.5656144376904828}
# FastSketch UQ parameters: {'aci_target': 0.048312154019363514, 'aci_step_size': 0.032138245854063455, 'interval_scale': 1.150828140857102, 'interval_power': 0.0006090773299027524, 'min_width_factor': 0.623842720251909}
# Baselines: ['CNN', 'LSTM', 'GaussianProcess', 'KernelRidgeRegressor', 'AR', 'ARIMA', 'ARKAN', 'NLinear', 'ETS', 'Chronos']

# %% [markdown]
# # 11.ABLATION STUDY

# %%
# ============================================================
# CELL 2 — ABLATION STUDY
# ============================================================

s3_ablation = run_s3_ablation_study(
    train_series=train_series,
    test_series=test_series,
    best_params=S3_ABLATION_PARAMS,
    alpha=ALPHA,
    seasonal_period=SEASONAL_PERIOD,
)

fastsketch_ablation = run_fastsketch_ablation(
    train_series=train_series,
    test_series=test_series,
    point_params=FASTSKETCH_POINT_PARAMS,
    uq_params=FASTSKETCH_UQ_PARAMS,
    series_id=(
        SERIES_ID
        if "SERIES_ID" in globals()
        else "CIF Monthly-series"
    ),
    seasonal_period=SEASONAL_PERIOD,
    alpha=ALPHA,
    verbose=True,
)

s3_ablation_table = (
    s3_ablation["results"].copy()
)
s3_ablation_table.insert(
    0,
    "model",
    "S3-Forecaster",
)

fastsketch_ablation_table = (
    fastsketch_ablation["results"].copy()
)
fastsketch_ablation_table.insert(
    0,
    "model",
    "S3-FastSketch",
)

print("S3-Forecaster ablation")
display(s3_ablation_table)

print("S3-FastSketch ablation")
display(fastsketch_ablation_table)

s3_ablation_table.to_csv(
    OUTPUT_DIR / "cif_s3_ablation.csv",
    index=False,
)

fastsketch_ablation_table.to_csv(
    OUTPUT_DIR / "cif_fastsketch_ablation.csv",
    index=False,
)


def plot_ablation_metric(
    table,
    metric,
    *,
    label_column="variant",
    figsize=(12, 5),
):
    valid = table[
        (table["status"] == "ok")
        & table[metric].notna()
        & np.isfinite(table[metric])
    ].copy()

    fig, ax = plt.subplots(figsize=figsize)

    ax.bar(
        valid[label_column].astype(str),
        valid[metric].astype(float),
    )

    ax.set_xlabel(
        "Ablation variant",
        fontsize=14,
    )
    ax.set_ylabel(
        metric.replace("_", " ").upper(),
        fontsize=14,
    )

    ax.tick_params(
        axis="x",
        rotation=40,
        labelsize=11,
    )
    ax.tick_params(
        axis="y",
        labelsize=12,
    )

    fig.tight_layout()
    plt.show()

    return fig, ax


plot_ablation_metric(
    s3_ablation_table,
    "mape_percent",
)

plot_ablation_metric(
    s3_ablation_table,
    "msis",
)

plot_ablation_metric(
    fastsketch_ablation_table,
    "mape_percent",
)

plot_ablation_metric(
    fastsketch_ablation_table,
    "msis",
)
# Out:
# [OK] Full: MAPE=0.221%, MSIS=1.2477
# [OK] Foundation only: MAPE=0.516%, MSIS=1.8744
# [OK] Without foundation: MAPE=0.483%, MSIS=5.4868
# [OK] Without AR lags: MAPE=0.222%, MSIS=1.2477
# [OK] Without EMA residual: MAPE=0.288%, MSIS=1.2477
# [OK] Without volatility: MAPE=0.242%, MSIS=1.2477
# [OK] Without momentum: MAPE=0.235%, MSIS=1.2477
# [OK] Without causal convolutions: MAPE=0.223%, MSIS=1.2477
# [OK] Without seasonal residual: MAPE=0.206%, MSIS=1.2477
# [OK] Without calendar: MAPE=0.221%, MSIS=1.2477
# [OK] Without multiscale sketch: MAPE=0.214%, MSIS=1.2477
# [OK] Without signed shrinkage: MAPE=0.355%, MSIS=2.2526
# [OK] Static conformal (without ACI): MAPE=0.221%, MSIS=1.2477
# S3-Forecaster ablation
#            model                        variant                mode  \
# 0  S3-Forecaster                      base only           base_only
# 1  S3-Forecaster        base + residual adapter       base_residual
# 2  S3-Forecaster         base + residual + gate  base_residual_gate
# 3  S3-Forecaster               full model + ACI            full_aci
# 4  S3-Forecaster  full model + static conformal         full_static
#
#    gate_value  alpha_final status error       mae       mse      rmse  ...  \
# 0    1.000000         0.10     ok  None  0.027259  0.000964  0.031041  ...
# 1    1.000000         0.10     ok  None  0.041018  0.002112  0.045953  ...
# 2    0.870429         0.10     ok  None  0.032958  0.001479  0.038454  ...
# 3    0.870429         0.01     ok  None  0.032958  0.001479  0.038454  ...
# 4    0.870429         0.10     ok  None  0.032958  0.001479  0.038454  ...
#
#     ecp  coverage_error        iw  mean_width       mis  interval_score  \
# 0   NaN             NaN       NaN         NaN       NaN             NaN
# 1   NaN             NaN       NaN         NaN       NaN             NaN
# 2   NaN             NaN       NaN         NaN       NaN             NaN
# 3  1.00            0.10  0.208496    0.208496  0.208496        0.208496
# 4  0.75            0.15  0.102049    0.102049  0.151491        0.151491
#
#        msis    scale  elapsed_seconds  trainable_params
# 0       NaN      NaN         0.008942                 0
# 1       NaN      NaN         0.035184               552
# 2       NaN      NaN         0.052477               552
# 3  2.841687  0.07337         0.064112               552
# 4  2.064739  0.07337         0.067467               552
#
# [5 rows x 25 columns]
# S3-FastSketch ablation
#             model series_id                         variant  n_features  \
# 0   S3-FastSketch        T1                            Full          22
# 1   S3-FastSketch        T1                 Foundation only           0
# 2   S3-FastSketch        T1              Without foundation          22
# 3   S3-FastSketch        T1                 Without AR lags          16
# 4   S3-FastSketch        T1            Without EMA residual          20
# 5   S3-FastSketch        T1              Without volatility          20
# 6   S3-FastSketch        T1                Without momentum          20
# 7   S3-FastSketch        T1     Without causal convolutions          14
# 8   S3-FastSketch        T1       Without seasonal residual          20
# 9   S3-FastSketch        T1                Without calendar          22
# 10  S3-FastSketch        T1       Without multiscale sketch           8
# 11  S3-FastSketch        T1        Without signed shrinkage          22
# 12  S3-FastSketch        T1  Static conformal (without ACI)          22
#
#                      gamma  final_alpha_t status error       mae       mse  \
# 0   (0.25875412008664234,)       0.036395     ok  None  0.016403  0.000440
# 1                   (0.0,)       0.035310     ok  None  0.038300  0.001774
# 2    (1.0350164803465698,)       0.052353     ok  None  0.035775  0.001682
# 3   (0.22640985507581202,)       0.036395     ok  None  0.016464  0.000450
# 4    (0.5175082401732847,)       0.036395     ok  None  0.021379  0.000651
# 5   (0.25875412008664234,)       0.036395     ok  None  0.017986  0.000486
# 6   (0.22640985507581202,)       0.036395     ok  None  0.017440  0.000489
# 7   (0.22640985507581202,)       0.036395     ok  None  0.016563  0.000391
# 8   (0.25875412008664234,)       0.036395     ok  None  0.015281  0.000417
# 9   (0.25875412008664234,)       0.036395     ok  None  0.016403  0.000440
# 10   (0.9056394203032485,)       0.036395     ok  None  0.015857  0.000435
# 11                  (1.0,)       0.034843     ok  None  0.026299  0.001096
# 12  (0.25875412008664234,)       0.048312     ok  None  0.016403  0.000440
#
#     ...  interval_score      msis    scale  elapsed_seconds  trainable_params  \
# 0   ...        0.091543  1.247685  0.07337         0.206165                24
# 1   ...        0.137528  1.874429  0.07337         0.175789                 0
# 2   ...        0.402566  5.486763  0.07337         0.138913                24
# 3   ...        0.091543  1.247685  0.07337         0.172424                18
# 4   ...        0.091543  1.247685  0.07337         0.184346                22
# 5   ...        0.091543  1.247685  0.07337         0.209458                22
# 6   ...        0.091543  1.247685  0.07337         0.188150                22
# 7   ...        0.091543  1.247685  0.07337         0.182870                16
# 8   ...        0.091543  1.247685  0.07337         0.166616                22
# 9   ...        0.091543  1.247685  0.07337         0.173478                24
# 10  ...        0.091543  1.247685  0.07337         0.170575                10
# 11  ...        0.165273  2.252581  0.07337         0.179610                24
# 12  ...        0.091543  1.247685  0.07337         0.185290                24
#
#     delta_mape_percent  delta_rmse  delta_coverage_error  delta_mean_width  \
# 0             0.000000    0.000000                  0.00          0.000000
# 1             0.294576    0.021132                  0.05          0.006981
# 2             0.261771    0.020024                  0.00          0.311023
# 3             0.000810    0.000232                  0.00          0.000000
# 4             0.066907    0.004527                  0.00          0.000000
# 5             0.021269    0.001055                  0.00          0.000000
# 6             0.013908    0.001132                  0.00          0.000000
# 7             0.002275   -0.001199                  0.00          0.000000
# 8            -0.015124   -0.000554                  0.00          0.000000
# 9             0.000000    0.000000                  0.00          0.000000
# 10           -0.007397   -0.000129                  0.00          0.000000
# 11            0.133688    0.012123                  0.00          0.073730
# 12            0.000000    0.000000                  0.00          0.000000
#
#     delta_msis
# 0     0.000000
# 1     0.626743
# 2     4.239078
# 3     0.000000
# 4     0.000000
# 5     0.000000
# 6     0.000000
# 7     0.000000
# 8     0.000000
# 9     0.000000
# 10    0.000000
# 11    1.004896
# 12    0.000000
#
# [13 rows x 31 columns]
# (<Figure size 1200x500 with 1 Axes>,
#  <Axes: xlabel='Ablation variant', ylabel='MSIS'>)

# %% [markdown]
# # 12.SHOCK / NON-SHOCK ANALYSIS

# %%
# ============================================================
# CELL 3 — SHOCK / NON-SHOCK ANALYSIS
# Uses all forecasts produced by the core experiment.
# ============================================================

results_for_shock = {
    "S3-Forecaster": s3_result,
    "S3-FastSketch": fastsketch_result,
    **globals().get("baseline_results", {}),
}

shock_objects = {}
shock_summary_parts = []
shock_failures = []

for model_name, result in results_for_shock.items():
    print(f"Analyzing shocks for {model_name}...")

    try:
        analysis = analyze_forecast_shocks(
            train_series=train_series,
            test_series=test_series,
            forecast=result["forecast"],
            model_name=model_name,
            alpha=ALPHA,
            seasonal_period=SEASONAL_PERIOD,
            threshold_method="iqr",
            iqr_k=1.5,
        )

        shock_objects[model_name] = analysis
        shock_summary_parts.append(
            analysis["summary"]
        )

        safe_name = (
            model_name.lower()
            .replace(" ", "_")
            .replace("(", "")
            .replace(")", "")
            .replace("-", "_")
        )

        analysis["details"].to_csv(
            OUTPUT_DIR
            / f"cif_shock_details_{safe_name}.csv"
        )

    except Exception as exc:
        shock_failures.append(
            {
                "model": model_name,
                "exception_type": type(exc).__name__,
                "error": str(exc),
            }
        )

shock_summary = (
    pd.concat(
        shock_summary_parts,
        ignore_index=True,
    )
    if shock_summary_parts
    else pd.DataFrame()
)

if not shock_summary.empty:
    shock_summary = (
        shock_summary
        .sort_values(["model", "subset"])
        .reset_index(drop=True)
    )

print("Shock/non-shock results")
display(shock_summary)

if shock_failures:
    print("Shock-analysis failures")
    display(pd.DataFrame(shock_failures))

shock_summary.to_csv(
    OUTPUT_DIR / "cif_shock_nonshock_summary.csv",
    index=False,
)

pd.DataFrame(shock_failures).to_csv(
    OUTPUT_DIR / "cif_shock_nonshock_failures.csv",
    index=False,
)


def plot_shock_metric(
    summary,
    metric,
    *,
    figsize=(14, 6),
):
    valid = summary[
        (summary["status"] == "ok")
        & summary[metric].notna()
        & np.isfinite(summary[metric])
    ]

    pivot = valid.pivot_table(
        index="model",
        columns="subset",
        values=metric,
        aggfunc="first",
    )

    preferred_columns = [
        subset
        for subset in (
            "overall",
            "shock",
            "non_shock",
        )
        if subset in pivot.columns
    ]

    pivot = pivot[preferred_columns]

    fig, ax = plt.subplots(figsize=figsize)

    pivot.plot(
        kind="bar",
        ax=ax,
    )

    ax.set_xlabel(
        "Model",
        fontsize=14,
    )
    ax.set_ylabel(
        metric.replace("_", " ").upper(),
        fontsize=14,
    )

    ax.tick_params(
        axis="x",
        rotation=40,
        labelsize=11,
    )
    ax.tick_params(
        axis="y",
        labelsize=12,
    )

    ax.legend(
        title="Subset",
        fontsize=11,
    )

    fig.tight_layout()
    plt.show()

    return pivot, fig, ax


shock_mape_pivot, _, _ = plot_shock_metric(
    shock_summary,
    "mape_percent",
)

shock_rmse_pivot, _, _ = plot_shock_metric(
    shock_summary,
    "rmse",
)

shock_msis_pivot, _, _ = plot_shock_metric(
    shock_summary,
    "msis",
)

shock_mape_pivot.to_csv(
    OUTPUT_DIR / "cif_shock_mape_pivot.csv"
)

shock_rmse_pivot.to_csv(
    OUTPUT_DIR / "cif_shock_rmse_pivot.csv"
)

shock_msis_pivot.to_csv(
    OUTPUT_DIR / "cif_shock_msis_pivot.csv"
)
# Out:
# Analyzing shocks for S3-Forecaster...
# Analyzing shocks for S3-FastSketch...
# Analyzing shocks for CNN...
# Analyzing shocks for LSTM...
# Analyzing shocks for Gaussian Process...
# Analyzing shocks for Kernel Ridge...
# Analyzing shocks for AR...
# Analyzing shocks for ARIMA...
# Analyzing shocks for ARKAN...
# Analyzing shocks for EasyTSF (NLinear)...
# Analyzing shocks for ETS...
# Analyzing shocks for Chronos...
# Shock/non-shock results
#        subset  n_points  fraction status       mae       mse      rmse  \
# 0   non_shock        12       1.0     ok  0.029031  0.001045  0.032334
# 1     overall        12       1.0     ok  0.029031  0.001045  0.032334
# 2       shock         0       0.0  empty       NaN       NaN       NaN
# 3   non_shock        12       1.0     ok  0.020301  0.000630  0.025095
# 4     overall        12       1.0     ok  0.020301  0.000630  0.025095
# 5       shock         0       0.0  empty       NaN       NaN       NaN
# 6   non_shock        12       1.0     ok  0.060833  0.004335  0.065840
# 7     overall        12       1.0     ok  0.060833  0.004335  0.065840
# 8       shock         0       0.0  empty       NaN       NaN       NaN
# 9   non_shock        12       1.0     ok  0.024663  0.001017  0.031888
# 10    overall        12       1.0     ok  0.024663  0.001017  0.031888
# 11      shock         0       0.0  empty       NaN       NaN       NaN
# 12  non_shock        12       1.0     ok  0.017090  0.000422  0.020536
# 13    overall        12       1.0     ok  0.017090  0.000422  0.020536
# 14      shock         0       0.0  empty       NaN       NaN       NaN
# 15  non_shock        12       1.0     ok  0.018161  0.000505  0.022481
# 16    overall        12       1.0     ok  0.018161  0.000505  0.022481
# 17      shock         0       0.0  empty       NaN       NaN       NaN
# 18  non_shock        12       1.0     ok  0.018906  0.000538  0.023186
# 19    overall        12       1.0     ok  0.018906  0.000538  0.023186
# 20      shock         0       0.0  empty       NaN       NaN       NaN
# 21  non_shock        12       1.0     ok  0.016162  0.000344  0.018553
# 22    overall        12       1.0     ok  0.016162  0.000344  0.018553
# 23      shock         0       0.0  empty       NaN       NaN       NaN
# 24  non_shock        12       1.0     ok  0.019061  0.000472  0.021724
# 25    overall        12       1.0     ok  0.019061  0.000472  0.021724
# 26      shock         0       0.0  empty       NaN       NaN       NaN
# 27  non_shock        12       1.0     ok  0.055742  0.004276  0.065390
# 28    overall        12       1.0     ok  0.055742  0.004276  0.065390
# 29      shock         0       0.0  empty       NaN       NaN       NaN
# 30  non_shock        12       1.0     ok  0.016403  0.000440  0.020985
# 31    overall        12       1.0     ok  0.016403  0.000440  0.020985
# 32      shock         0       0.0  empty       NaN       NaN       NaN
# 33  non_shock        12       1.0     ok  0.032958  0.001479  0.038454
# 34    overall        12       1.0     ok  0.032958  0.001479  0.038454
# 35      shock         0       0.0  empty       NaN       NaN       NaN
#
#           r2  mape_percent      mape  ...  mean_width       mis  \
# 0  -1.010380      0.390820  0.003908  ...    0.165813  0.166167
# 1  -1.010380      0.390820  0.003908  ...    0.165813  0.166167
# 2        NaN           NaN       NaN  ...         NaN       NaN
# 3  -0.211005      0.274031  0.002740  ...    0.167356  0.167356
# 4  -0.211005      0.274031  0.002740  ...    0.167356  0.167356
# 5        NaN           NaN       NaN  ...         NaN       NaN
# 6  -7.335542      0.818879  0.008189  ...    0.399644  0.399644
# 7  -7.335542      0.818879  0.008189  ...    0.399644  0.399644
# 8        NaN           NaN       NaN  ...         NaN       NaN
# 9  -0.955264      0.332253  0.003323  ...    0.420782  0.420782
# 10 -0.955264      0.332253  0.003323  ...    0.420782  0.420782
# 11       NaN           NaN       NaN  ...         NaN       NaN
# 12  0.189060      0.230288  0.002303  ...    0.152370  0.152370
# 13  0.189060      0.230288  0.002303  ...    0.152370  0.152370
# 14       NaN           NaN       NaN  ...         NaN       NaN
# 15  0.028154      0.244572  0.002446  ...    0.195947  0.195947
# 16  0.028154      0.244572  0.002446  ...    0.195947  0.195947
# 17       NaN           NaN       NaN  ...         NaN       NaN
# 18 -0.033738      0.255032  0.002550  ...    0.137175  0.137175
# 19 -0.033738      0.255032  0.002550  ...    0.137175  0.137175
# 20       NaN           NaN       NaN  ...         NaN       NaN
# 21  0.338141      0.217871  0.002179  ...    0.276348  0.276348
# 22  0.338141      0.217871  0.002179  ...    0.276348  0.276348
# 23       NaN           NaN       NaN  ...         NaN       NaN
# 24  0.092523      0.256857  0.002569  ...    0.200604  0.200604
# 25  0.092523      0.256857  0.002569  ...    0.200604  0.200604
# 26       NaN           NaN       NaN  ...         NaN       NaN
# 27 -7.222086      0.751305  0.007513  ...    0.207958  0.255401
# 28 -7.222086      0.751305  0.007513  ...    0.207958  0.255401
# 29       NaN           NaN       NaN  ...         NaN       NaN
# 30  0.153230      0.220962  0.002210  ...    0.091543  0.091543
# 31  0.153230      0.220962  0.002210  ...    0.091543  0.091543
# 32       NaN           NaN       NaN  ...         NaN       NaN
# 33 -1.843427      0.444923  0.004449  ...    0.125998  0.140852
# 34 -1.843427      0.444923  0.004449  ...    0.125998  0.140852
# 35       NaN           NaN       NaN  ...         NaN       NaN
#
#     interval_score      msis    scale  elapsed_seconds  trainable_params  \
# 0         0.166167  2.264767  0.07337              NaN               NaN
# 1         0.166167  2.264767  0.07337              NaN               NaN
# 2              NaN       NaN      NaN              NaN               NaN
# 3         0.167356  2.280980  0.07337              NaN               NaN
# 4         0.167356  2.280980  0.07337              NaN               NaN
# 5              NaN       NaN      NaN              NaN               NaN
# 6         0.399644  5.446940  0.07337              NaN               NaN
# 7         0.399644  5.446940  0.07337              NaN               NaN
# 8              NaN       NaN      NaN              NaN               NaN
# 9         0.420782  5.735037  0.07337              NaN               NaN
# 10        0.420782  5.735037  0.07337              NaN               NaN
# 11             NaN       NaN      NaN              NaN               NaN
# 12        0.152370  2.076720  0.07337              NaN               NaN
# 13        0.152370  2.076720  0.07337              NaN               NaN
# 14             NaN       NaN      NaN              NaN               NaN
# 15        0.195947  2.670650  0.07337              NaN               NaN
# 16        0.195947  2.670650  0.07337              NaN               NaN
# 17             NaN       NaN      NaN              NaN               NaN
# 18        0.137175  1.869619  0.07337              NaN               NaN
# 19        0.137175  1.869619  0.07337              NaN               NaN
# 20             NaN       NaN      NaN              NaN               NaN
# 21        0.276348  3.766474  0.07337              NaN               NaN
# 22        0.276348  3.766474  0.07337              NaN               NaN
# 23             NaN       NaN      NaN              NaN               NaN
# 24        0.200604  2.734125  0.07337              NaN               NaN
# 25        0.200604  2.734125  0.07337              NaN               NaN
# 26             NaN       NaN      NaN              NaN               NaN
# 27        0.255401  3.480980  0.07337              NaN               NaN
# 28        0.255401  3.480980  0.07337              NaN               NaN
# 29             NaN       NaN      NaN              NaN               NaN
# 30        0.091543  1.247685  0.07337              NaN               NaN
# 31        0.091543  1.247685  0.07337              NaN               NaN
# 32             NaN       NaN      NaN              NaN               NaN
# 33        0.140852  1.919736  0.07337              NaN               NaN
# 34        0.140852  1.919736  0.07337              NaN               NaN
# 35             NaN       NaN      NaN              NaN               NaN
#
#                 model  threshold  threshold_method
# 0                  AR   0.162414               iqr
# 1                  AR   0.162414               iqr
# 2                  AR   0.162414               iqr
# 3               ARIMA   0.162414               iqr
# 4               ARIMA   0.162414               iqr
# 5               ARIMA   0.162414               iqr
# 6               ARKAN   0.162414               iqr
# 7               ARKAN   0.162414               iqr
# 8               ARKAN   0.162414               iqr
# 9                 CNN   0.162414               iqr
# 10                CNN   0.162414               iqr
# 11                CNN   0.162414               iqr
# 12            Chronos   0.162414               iqr
# 13            Chronos   0.162414               iqr
# 14            Chronos   0.162414               iqr
# 15                ETS   0.162414               iqr
# 16                ETS   0.162414               iqr
# 17                ETS   0.162414               iqr
# 18  EasyTSF (NLinear)   0.162414               iqr
# 19  EasyTSF (NLinear)   0.162414               iqr
# 20  EasyTSF (NLinear)   0.162414               iqr
# 21   Gaussian Process   0.162414               iqr
# 22   Gaussian Process   0.162414               iqr
# 23   Gaussian Process   0.162414               iqr
# 24       Kernel Ridge   0.162414               iqr
# 25       Kernel Ridge   0.162414               iqr
# 26       Kernel Ridge   0.162414               iqr
# 27               LSTM   0.162414               iqr
# 28               LSTM   0.162414               iqr
# 29               LSTM   0.162414               iqr
# 30      S3-FastSketch   0.162414               iqr
# 31      S3-FastSketch   0.162414               iqr
# 32      S3-FastSketch   0.162414               iqr
# 33      S3-Forecaster   0.162414               iqr
# 34      S3-Forecaster   0.162414               iqr
# 35      S3-Forecaster   0.162414               iqr
#
# [36 rows x 25 columns]

# %% [markdown]
# # 13.DATA-EFFICIENCY ANALYSIS

# %%
# ============================================================
# CELL 4 — COMMON ACI FOR DATA-EFFICIENCY BASELINES
# ============================================================

def finite_sample_conformal_quantile(
    scores,
    alpha,
):
    scores = np.asarray(
        scores,
        dtype=float,
    ).reshape(-1)

    scores = scores[
        np.isfinite(scores)
    ]

    if len(scores) == 0:
        raise ValueError(
            "No finite calibration scores were produced."
        )

    level = min(
        1.0,
        math.ceil(
            (len(scores) + 1)
            * (1.0 - alpha)
        )
        / len(scores),
    )

    try:
        return float(
            np.quantile(
                scores,
                level,
                method="higher",
            )
        )
    except TypeError:
        return float(
            np.quantile(
                scores,
                level,
                interpolation="higher",
            )
        )


def adaptive_conformal_path(
    y_true,
    y_pred,
    calibration_scores,
    *,
    alpha=0.10,
    step_size=0.05,
):
    y_true = np.asarray(
        y_true,
        dtype=float,
    ).reshape(-1)

    y_pred = np.asarray(
        y_pred,
        dtype=float,
    ).reshape(-1)

    buffer = list(
        np.asarray(
            calibration_scores,
            dtype=float,
        ).reshape(-1)
    )

    alpha_t = float(alpha)

    lower = []
    upper = []
    alpha_path = []

    for observed, predicted in zip(
        y_true,
        y_pred,
    ):
        q = finite_sample_conformal_quantile(
            buffer,
            alpha_t,
        )

        lo = float(predicted - q)
        up = float(predicted + q)

        lower.append(lo)
        upper.append(up)
        alpha_path.append(alpha_t)

        miss = float(
            observed < lo
            or observed > up
        )

        alpha_t = float(
            np.clip(
                alpha_t
                + step_size
                * (alpha - miss),
                0.01,
                0.50,
            )
        )

        buffer.append(
            abs(
                float(
                    observed - predicted
                )
            )
        )

    return (
        np.asarray(lower),
        np.asarray(upper),
        np.asarray(alpha_path),
    )


def evaluate_fixed_baseline_with_aci_cpu(
    model_name,
    params,
    train,
    test,
    *,
    calibration_ratio=0.20,
    alpha=0.10,
    aci_step_size=0.05,
    seasonal_period=12,
):
    train = ensure_series(
        train,
        name="train",
    )
    test = ensure_series(
        test,
        name="test",
    )

    split = int(
        np.floor(
            (1.0 - calibration_ratio)
            * len(train)
        )
    )

    split = max(
        split,
        seasonal_period + 5,
    )
    split = min(
        split,
        len(train) - 2,
    )

    train_core = train.iloc[:split]
    calibration = train.iloc[split:]

    if len(calibration) < 2:
        raise ValueError(
            "At least two chronological "
            "calibration points are required."
        )

    _, calibration_forecast = (
        fit_predict_baseline(
            model_name,
            train_core,
            len(calibration),
            params,
        )
    )

    calibration_output = (
        parse_forecast_output(
            calibration_forecast
        )
    )

    if (
        len(calibration_output.pred)
        != len(calibration)
    ):
        raise ValueError(
            f"{model_name} returned "
            f"{len(calibration_output.pred)} "
            "calibration values; expected "
            f"{len(calibration)}."
        )

    calibration_scores = np.abs(
        calibration.to_numpy(dtype=float)
        - calibration_output.pred
    )

    start = time.perf_counter()

    model, test_forecast = (
        fit_predict_baseline(
            model_name,
            train,
            len(test),
            params,
        )
    )

    elapsed = (
        time.perf_counter() - start
    )

    test_output = (
        parse_forecast_output(
            test_forecast
        )
    )

    if test_output.has_interval:
        lower = test_output.lower
        upper = test_output.upper

        alpha_path = np.full(
            len(test),
            alpha,
            dtype=float,
        )

        interval_source = "native"

    else:
        (
            lower,
            upper,
            alpha_path,
        ) = adaptive_conformal_path(
            test.to_numpy(dtype=float),
            test_output.pred,
            calibration_scores,
            alpha=alpha,
            step_size=aci_step_size,
        )

        interval_source = "external_aci"

    forecast = pd.DataFrame(
        {
            "pred": test_output.pred,
            "lower": lower,
            "upper": upper,
            "aci_alpha": alpha_path,
        },
        index=test.index,
    )

    metrics = evaluate_forecast(
        test,
        forecast["pred"],
        y_train=train,
        lower=forecast["lower"],
        upper=forecast["upper"],
        alpha=alpha,
        seasonal_period=seasonal_period,
        elapsed_seconds=elapsed,
        trainable_params=(
            count_trainable_parameters(
                model
            )
        ),
    )

    return {
        "model": model,
        "forecast": forecast,
        "metrics": metrics,
        "interval_source": interval_source,
        "calibration_size": len(calibration),
    }

# ============================================================
# CELL 5 — FEASIBLE PARAMETERS FOR RESTRICTED HISTORIES
# No hyperparameter optimization is performed.
# ============================================================

def make_baseline_params_feasible_for_aci(
    model_name,
    params,
    *,
    n_history,
    test_horizon,
    calibration_ratio=0.20,
    seasonal_period=12,
):
    p = copy.deepcopy(params)

    split = int(
        np.floor(
            (1.0 - calibration_ratio)
            * n_history
        )
    )

    split = max(
        split,
        seasonal_period + 5,
    )
    split = min(
        split,
        n_history - 2,
    )

    calibration_horizon = (
        n_history - split
    )

    direct_models = {
        "CNN",
        "LSTM",
        "GaussianProcess",
        "KernelRidge",
        "KernelRidgeRegressor",
    }

    if (
        model_name in direct_models
        and "input_window" in p
    ):
        # At least eight direct windows are
        # required by the repository class.
        max_for_calibration = (
            split
            - calibration_horizon
            - 7
        )

        max_for_test = (
            n_history
            - test_horizon
            - 7
        )

        max_window = max(
            1,
            min(
                max_for_calibration,
                max_for_test,
            ),
        )

        p["input_window"] = int(
            np.clip(
                p["input_window"],
                1,
                max_window,
            )
        )

        if "kernel_size" in p:
            p["kernel_size"] = int(
                np.clip(
                    p["kernel_size"],
                    1,
                    max(
                        1,
                        p["input_window"],
                    ),
                )
            )

    if (
        model_name == "NLinear"
        and "window_size" in p
    ):
        max_window = max(
            1,
            min(
                split - 10,
                n_history - 10,
            ),
        )

        p["window_size"] = int(
            np.clip(
                p["window_size"],
                1,
                max_window,
            )
        )

    if (
        model_name == "ARKAN"
        and "window_size" in p
    ):
        max_window = max(
            1,
            min(
                split - 12,
                n_history - 12,
            ),
        )

        p["window_size"] = int(
            np.clip(
                p["window_size"],
                1,
                max_window,
            )
        )

    if model_name == "AR":
        p["lags"] = int(
            min(
                max(
                    1,
                    int(
                        p.get("lags", 1)
                    ),
                ),
                max(
                    1,
                    split // 3,
                ),
            )
        )

        if (
            p.get("seasonal", False)
            and split
            <= p["lags"]
            + seasonal_period
            + 2
        ):
            p["seasonal"] = False

        p["period"] = int(
            p.get(
                "period",
                seasonal_period,
            )
        )

    if model_name == "ARIMA":
        max_order = max(
            1,
            split // 4,
        )

        p["p"] = int(
            np.clip(
                int(p.get("p", 1)),
                0,
                max_order,
            )
        )

        p["q"] = int(
            np.clip(
                int(p.get("q", 0)),
                0,
                max_order,
            )
        )

        p["d"] = int(
            np.clip(
                int(p.get("d", 0)),
                0,
                2,
            )
        )

        if (
            p["p"] == 0
            and p["q"] == 0
            and p["d"] == 0
        ):
            p["p"] = 1

    if (
        model_name == "ETS"
        and p.get("seasonal_periods")
    ):
        required = (
            2
            * int(
                p["seasonal_periods"]
            )
            + 2
        )

        if split < required:
            p["seasonal"] = None
            p["seasonal_periods"] = None

    if model_name == "Chronos":
        return p

    return p


def make_s3_params_feasible(
    params,
    *,
    n_history,
    test_horizon,
):
    p = make_params_feasible(
        "S3-Forecaster",
        params,
        n_history,
        seasonal_period=SEASONAL_PERIOD,
    )

    minimum_required = (
        2 * test_horizon + 5
    )

    if n_history < minimum_required:
        raise ValueError(
            "The restricted history is too short "
            "for direct multi-horizon S3 training. "
            f"N={n_history}, minimum={minimum_required}."
        )

    maximum_ar_lags = max(
        1,
        n_history
        - 2 * test_horizon
        - 4,
    )

    p["ar_lags"] = int(
        min(
            p["ar_lags"],
            maximum_ar_lags,
        )
    )

    lower_split = (
        test_horizon
        + p["ar_lags"]
        + 2
    ) / n_history

    upper_split = (
        n_history
        - test_horizon
        - 1
    ) / n_history

    if lower_split >= upper_split:
        raise ValueError(
            "No feasible S3 train/calibration split "
            f"exists for N={n_history}."
        )

    p["oob_split_ratio"] = float(
        np.clip(
            p["oob_split_ratio"],
            lower_split,
            upper_split,
        )
    )

    return p


def clear_cpu_model_state():
    if tf is not None:
        try:
            tf.keras.backend.clear_session()
        except Exception:
            pass

    gc.collect()

# %%
# ============================================================
# CELL 6 — DATA-EFFICIENCY ANALYSIS FOR ALL MODELS ON CPU
# ============================================================

def run_complete_data_efficiency_cpu(
    train,
    test,
    *,
    history_sizes=(
        48,
        60,
        84,
        120,
        160,
    ),
):
    train = ensure_series(
        train,
        name="train",
    )

    test = ensure_series(
        test,
        name="test",
    )

    model_specs = [
        (
            "S3-Forecaster",
            "S3-Forecaster",
            S3_POINT_PARAMS,
        ),
        (
            "S3-FastSketch",
            "S3-FastSketch",
            FASTSKETCH_POINT_PARAMS,
        ),
    ]

    for internal_name in BASELINE_ORDER:
        model_specs.append(
            (
                BASELINE_DISPLAY_NAMES.get(
                    internal_name,
                    internal_name,
                ),
                internal_name,
                BASELINE_PARAMS[
                    internal_name
                ],
            )
        )

    rows = []
    forecasts = {}
    models = {}

    for (
        display_name,
        internal_name,
        fixed_params,
    ) in model_specs:

        forecasts[display_name] = {}
        models[display_name] = {}

        for history_size in history_sizes:
            if history_size > len(train):
                continue

            train_subset = (
                train
                .iloc[-int(history_size):]
                .copy()
            )

            start = time.perf_counter()

            try:
                if internal_name == "S3-Forecaster":
                    effective_params = (
                        make_s3_params_feasible(
                            fixed_params,
                            n_history=len(
                                train_subset
                            ),
                            test_horizon=len(test),
                        )
                    )

                elif internal_name == "S3-FastSketch":
                    effective_params = (
                        make_params_feasible(
                            internal_name,
                            fixed_params,
                            len(train_subset),
                            seasonal_period=(
                                SEASONAL_PERIOD
                            ),
                        )
                    )

                else:
                    effective_params = (
                        make_baseline_params_feasible_for_aci(
                            internal_name,
                            fixed_params,
                            n_history=len(
                                train_subset
                            ),
                            test_horizon=len(test),
                            calibration_ratio=(
                                BASELINE_CALIBRATION_RATIO
                            ),
                            seasonal_period=(
                                SEASONAL_PERIOD
                            ),
                        )
                    )

                print(
                    f"{display_name}: "
                    f"N={history_size}, CPU"
                )

                if internal_name == "S3-Forecaster":
                    output = evaluate_s3_forecaster(
                        train_subset,
                        test,
                        effective_params,
                        uq_params=S3_UQ_PARAMS,
                        seasonal_period=(
                            SEASONAL_PERIOD
                        ),
                        alpha=ALPHA,
                    )

                elif internal_name == "S3-FastSketch":
                    output = evaluate_fastsketch(
                        train_subset,
                        test,
                        effective_params,
                        uq_params=(
                            FASTSKETCH_UQ_PARAMS
                        ),
                        seasonal_period=(
                            SEASONAL_PERIOD
                        ),
                        alpha=ALPHA,
                    )

                else:
                    output = (
                        evaluate_fixed_baseline_with_aci_cpu(
                            internal_name,
                            effective_params,
                            train_subset,
                            test,
                            calibration_ratio=(
                                BASELINE_CALIBRATION_RATIO
                            ),
                            alpha=ALPHA,
                            aci_step_size=(
                                BASELINE_ACI_STEP_SIZE
                            ),
                            seasonal_period=(
                                SEASONAL_PERIOD
                            ),
                        )
                    )

                rows.append(
                    {
                        "model_name": display_name,
                        "internal_name": internal_name,
                        "history_size": int(
                            history_size
                        ),
                        "device": "cpu",
                        "status": "ok",
                        "error": None,
                        "effective_params": (
                            effective_params
                        ),
                        **output["metrics"],
                    }
                )

                forecasts[
                    display_name
                ][history_size] = (
                    output["forecast"]
                )

                models[
                    display_name
                ][history_size] = (
                    output["model"]
                )

            except Exception as exc:
                rows.append(
                    {
                        "model_name": display_name,
                        "internal_name": internal_name,
                        "history_size": int(
                            history_size
                        ),
                        "device": "cpu",
                        "status": "failed",
                        "error": (
                            f"{type(exc).__name__}: "
                            f"{exc}"
                        ),
                        "effective_params": (
                            locals().get(
                                "effective_params",
                                fixed_params,
                            )
                        ),
                        "elapsed_seconds": (
                            time.perf_counter()
                            - start
                        ),
                    }
                )

                forecasts[
                    display_name
                ][history_size] = None

                models[
                    display_name
                ][history_size] = None

            finally:
                clear_cpu_model_state()

    summary = (
        pd.DataFrame(rows)
        .sort_values(
            [
                "model_name",
                "history_size",
            ]
        )
        .reset_index(drop=True)
    )

    return {
        "summary": summary,
        "forecasts": forecasts,
        "models": models,
    }


minimum_s3_history = max(
    18,
    2 * len(test_series) + 5,
)

preferred_history_sizes = [
    36,
    48,
    60,
    84,
    120,
    160,
]

candidate_history_sizes = [
    size
    for size in preferred_history_sizes
    if minimum_s3_history <= size <= len(train_series)
]

fractional_history_sizes = [
    int(round(len(train_series) * fraction))
    for fraction in (0.60, 0.75, 0.90, 1.00)
]

candidate_history_sizes.extend(
    size
    for size in fractional_history_sizes
    if minimum_s3_history <= size <= len(train_series)
)

candidate_history_sizes.append(len(train_series))

DATA_EFFICIENCY_HISTORY_SIZES = tuple(
    sorted(
        {
            int(size)
            for size in candidate_history_sizes
            if minimum_s3_history <= int(size) <= len(train_series)
        }
    )
)

if not DATA_EFFICIENCY_HISTORY_SIZES:
    raise ValueError(
        "The selected training series is too short for the "
        "data-efficiency experiment with the current test horizon."
    )

print(
    "Data-efficiency history sizes:",
    DATA_EFFICIENCY_HISTORY_SIZES,
)

data_efficiency = (
    run_complete_data_efficiency_cpu(
        train_series,
        test_series,
        history_sizes=(
            DATA_EFFICIENCY_HISTORY_SIZES
        ),
    )
)

data_efficiency_summary = (
    data_efficiency["summary"]
)

print("Data-efficiency results")
display(data_efficiency_summary)

data_efficiency_summary.to_csv(
    OUTPUT_DIR
    / "cif_data_efficiency_all_models_cpu.csv",
    index=False,
)
# Out:
# Data-efficiency history sizes: (36, 48, 60, 65, 81, 84, 97, 108)
# S3-Forecaster: N=36, CPU
# S3-Forecaster: N=48, CPU
# S3-Forecaster: N=60, CPU
# S3-Forecaster: N=65, CPU
# S3-Forecaster: N=81, CPU
# S3-Forecaster: N=84, CPU
# S3-Forecaster: N=97, CPU
# S3-Forecaster: N=108, CPU
# S3-FastSketch: N=36, CPU
# S3-FastSketch: N=48, CPU
# S3-FastSketch: N=60, CPU
# S3-FastSketch: N=65, CPU
# S3-FastSketch: N=81, CPU
# S3-FastSketch: N=84, CPU
# S3-FastSketch: N=97, CPU
# S3-FastSketch: N=108, CPU
# CNN: N=36, CPU
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7baeef365a80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7baee539c7c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# CNN: N=48, CPU
# CNN: N=60, CPU
# CNN: N=65, CPU
# CNN: N=81, CPU
# CNN: N=84, CPU
# CNN: N=97, CPU
# CNN: N=108, CPU
# LSTM: N=36, CPU
# LSTM: N=48, CPU
# LSTM: N=60, CPU
# LSTM: N=65, CPU
# LSTM: N=81, CPU
# LSTM: N=84, CPU
# LSTM: N=97, CPU
# LSTM: N=108, CPU
# Gaussian Process: N=36, CPU
# Gaussian Process: N=48, CPU
# Gaussian Process: N=60, CPU
# Gaussian Process: N=65, CPU
# Gaussian Process: N=81, CPU
# Gaussian Process: N=84, CPU
# Gaussian Process: N=97, CPU
# Gaussian Process: N=108, CPU
# Kernel Ridge: N=36, CPU
# Kernel Ridge: N=48, CPU
# Kernel Ridge: N=60, CPU
# Kernel Ridge: N=65, CPU
# Kernel Ridge: N=81, CPU
# Kernel Ridge: N=84, CPU
# Kernel Ridge: N=97, CPU
# Kernel Ridge: N=108, CPU
# AR: N=36, CPU
# AR: N=48, CPU
# AR: N=60, CPU
# AR: N=65, CPU
# AR: N=81, CPU
# AR: N=84, CPU
# AR: N=97, CPU
# AR: N=108, CPU
# ARIMA: N=36, CPU
# ARIMA: N=48, CPU
# ARIMA: N=60, CPU
# ARIMA: N=65, CPU
# ARIMA: N=81, CPU
# ARIMA: N=84, CPU
# ARIMA: N=97, CPU
# ARIMA: N=108, CPU
# ARKAN: N=36, CPU
# ARKAN: N=48, CPU
# ARKAN: N=60, CPU
# ARKAN: N=65, CPU
# ARKAN: N=81, CPU
# ARKAN: N=84, CPU
# ARKAN: N=97, CPU
# ARKAN: N=108, CPU
# EasyTSF (NLinear): N=36, CPU
# EasyTSF (NLinear): N=48, CPU
# EasyTSF (NLinear): N=60, CPU
# EasyTSF (NLinear): N=65, CPU
# EasyTSF (NLinear): N=81, CPU
# EasyTSF (NLinear): N=84, CPU
# EasyTSF (NLinear): N=97, CPU
# EasyTSF (NLinear): N=108, CPU
# ETS: N=36, CPU
# ETS: N=48, CPU
# ETS: N=60, CPU
# ETS: N=65, CPU
# ETS: N=81, CPU
# ETS: N=84, CPU
# ETS: N=97, CPU
# ETS: N=108, CPU
# Chronos: N=36, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=48, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=60, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=65, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=81, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=84, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=97, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Chronos: N=108, CPU
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Data-efficiency results
#        model_name  internal_name  history_size device status error  \
# 0              AR             AR            36    cpu     ok  None
# 1              AR             AR            48    cpu     ok  None
# 2              AR             AR            60    cpu     ok  None
# 3              AR             AR            65    cpu     ok  None
# 4              AR             AR            81    cpu     ok  None
# ..            ...            ...           ...    ...    ...   ...
# 91  S3-Forecaster  S3-Forecaster            65    cpu     ok  None
# 92  S3-Forecaster  S3-Forecaster            81    cpu     ok  None
# 93  S3-Forecaster  S3-Forecaster            84    cpu     ok  None
# 94  S3-Forecaster  S3-Forecaster            97    cpu     ok  None
# 95  S3-Forecaster  S3-Forecaster           108    cpu     ok  None
#
#                                      effective_params       mae       mse  \
# 0   {'lags': 1, 'trend': 't', 'seasonal': False, '...  0.042133  0.002132
# 1   {'lags': 1, 'trend': 't', 'seasonal': False, '...  0.026934  0.000921
# 2   {'lags': 1, 'trend': 't', 'seasonal': False, '...  0.046048  0.002556
# 3   {'lags': 1, 'trend': 't', 'seasonal': False, '...  0.022304  0.000681
# 4   {'lags': 1, 'trend': 't', 'seasonal': False, '...  0.030600  0.001147
# ..                                                ...       ...       ...
# 91  {'reservoir_size': 43, 'spectral_radius': 0.64...  0.019072  0.000646
# 92  {'reservoir_size': 43, 'spectral_radius': 0.64...  0.020936  0.000669
# 93  {'reservoir_size': 43, 'spectral_radius': 0.64...  0.023906  0.000808
# 94  {'reservoir_size': 43, 'spectral_radius': 0.64...  0.030765  0.001410
# 95  {'reservoir_size': 43, 'spectral_radius': 0.64...  0.032958  0.001479
#
#         rmse  ...       ecp  coverage_error        iw  mean_width       mis  \
# 0   0.046174  ...  1.000000        0.100000  0.310647    0.310647  0.310647
# 1   0.030354  ...  1.000000        0.100000  0.128744    0.128744  0.128744
# 2   0.050554  ...  0.916667        0.016667  0.145056    0.145056  0.177099
# 3   0.026104  ...  0.916667        0.016667  0.111026    0.111026  0.111585
# 4   0.033871  ...  1.000000        0.100000  0.514914    0.514914  0.514914
# ..       ...  ...       ...             ...       ...         ...       ...
# 91  0.025417  ...  1.000000        0.100000  0.119297    0.119297  0.119297
# 92  0.025875  ...  1.000000        0.100000  0.129437    0.129437  0.129437
# 93  0.028433  ...  1.000000        0.100000  0.133245    0.133245  0.133245
# 94  0.037544  ...  0.916667        0.016667  0.135138    0.135138  0.148705
# 95  0.038454  ...  0.916667        0.016667  0.125998    0.125998  0.140852
#
#     interval_score      msis     scale  elapsed_seconds  trainable_params
# 0         0.310647  4.556209  0.068181         0.008825                 2
# 1         0.128744  2.032209  0.063352         0.006772                 2
# 2         0.177099  2.758727  0.064196         0.008353                 2
# 3         0.111585  1.696548  0.065772         0.007208                 2
# 4         0.514914  7.658677  0.067233         0.007932                 2
# ..             ...       ...       ...              ...               ...
# 91        0.119297  1.813790  0.065772         0.047668               554
# 92        0.129437  1.925205  0.067233         0.047426               554
# 93        0.133245  1.990294  0.066947         0.046143               554
# 94        0.148705  2.106662  0.070588         0.063039               554
# 95        0.140852  1.919736  0.073370         0.058570               554
#
# [96 rows x 25 columns]

# %%
# ============================================================
# CELL 7 — DATA-EFFICIENCY TABLES AND FIGURES
# ============================================================

def make_data_efficiency_pivot(
    summary,
    metric,
):
    valid = summary[
        (summary["status"] == "ok")
        & summary[metric].notna()
        & np.isfinite(summary[metric])
    ]

    return valid.pivot_table(
        index="model_name",
        columns="history_size",
        values=metric,
        aggfunc="first",
    )


def plot_data_efficiency(
    summary,
    metric,
    *,
    figsize=(13, 7),
):
    valid = summary[
        (summary["status"] == "ok")
        & summary[metric].notna()
        & np.isfinite(summary[metric])
    ].copy()

    fig, ax = plt.subplots(
        figsize=figsize
    )

    for model_name in (
        valid["model_name"]
        .drop_duplicates()
    ):
        subset = (
            valid[
                valid["model_name"]
                == model_name
            ]
            .sort_values(
                "history_size"
            )
        )

        ax.plot(
            subset["history_size"],
            subset[metric],
            marker="o",
            label=model_name,
        )

    ax.set_xlabel(
        "Available history (N)",
        fontsize=14,
    )

    ax.set_ylabel(
        metric.replace("_", " ").upper(),
        fontsize=14,
    )

    ax.tick_params(
        axis="both",
        labelsize=12,
    )

    ax.grid(alpha=0.3)

    ax.legend(
        bbox_to_anchor=(1.02, 1),
        loc="upper left",
        fontsize=11,
    )

    fig.tight_layout()
    plt.show()

    return fig, ax


data_efficiency_mape = (
    make_data_efficiency_pivot(
        data_efficiency_summary,
        "mape_percent",
    )
)

data_efficiency_rmse = (
    make_data_efficiency_pivot(
        data_efficiency_summary,
        "rmse",
    )
)

data_efficiency_msis = (
    make_data_efficiency_pivot(
        data_efficiency_summary,
        "msis",
    )
)

print("MAPE pivot")
display(data_efficiency_mape)

print("RMSE pivot")
display(data_efficiency_rmse)

print("MSIS pivot")
display(data_efficiency_msis)

data_efficiency_mape.to_csv(
    OUTPUT_DIR
    / "cif_data_efficiency_mape_pivot.csv"
)

data_efficiency_rmse.to_csv(
    OUTPUT_DIR
    / "cif_data_efficiency_rmse_pivot.csv"
)

data_efficiency_msis.to_csv(
    OUTPUT_DIR
    / "cif_data_efficiency_msis_pivot.csv"
)

plot_data_efficiency(
    data_efficiency_summary,
    "mape_percent",
)

plot_data_efficiency(
    data_efficiency_summary,
    "rmse",
)

plot_data_efficiency(
    data_efficiency_summary,
    "msis",
)
# Out:
# MAPE pivot
# history_size            36        48        60        65        81        84   \
# model_name
# AR                 0.567109  0.362601  0.619789  0.300321  0.411928  0.383330
# ARIMA              0.301288  0.526675  0.286379  0.318163  0.262863  0.264977
# ARKAN              0.725761  0.888369  1.170743  1.469971  0.256268  0.270520
# CNN                0.710253  1.273730  1.785458  0.856317  1.003955  0.881038
# Chronos            0.832290  0.545303  0.353268  0.296501  0.251629  0.247440
# ETS                0.371534  0.430189  0.416974  0.278685  0.314996  0.270691
# EasyTSF (NLinear)  0.747890  0.798230  0.657990  0.220939  0.230926  0.209716
# Gaussian Process   1.159330  1.030557  0.912895  0.331867  0.213072  0.227103
# Kernel Ridge       0.972739  1.595880  0.775855  0.721130  0.618440  0.563807
# LSTM               1.438934  0.508849  0.404761  0.383592  0.495356  0.575644
# S3-FastSketch      0.358849  0.265997  0.604191  0.211145  0.282169  0.283052
# S3-Forecaster      0.383280  0.322433  0.269918  0.257487  0.282668  0.322668
#
# history_size            97        108
# model_name
# AR                 0.458774  0.390820
# ARIMA              0.272967  0.274031
# ARKAN              1.098631  0.746737
# CNN                0.538379  0.457346
# Chronos            0.232103  0.230288
# ETS                0.247695  0.244572
# EasyTSF (NLinear)  0.205497  0.255032
# Gaussian Process   0.242799  0.217871
# Kernel Ridge       0.330528  0.256857
# LSTM               0.912953  0.944488
# S3-FastSketch      0.263395  0.220962
# S3-Forecaster      0.415420  0.444923
# RMSE pivot
# history_size            36        48        60        65        81        84   \
# model_name
# AR                 0.046174  0.030354  0.050554  0.026104  0.033871  0.031799
# ARIMA              0.029077  0.044081  0.025621  0.029408  0.023663  0.023705
# ARKAN              0.058293  0.069834  0.092131  0.115681  0.022663  0.025300
# CNN                0.061956  0.106741  0.148401  0.081695  0.086007  0.080302
# Chronos            0.068545  0.044558  0.030758  0.026784  0.022828  0.022446
# ETS                0.029166  0.037396  0.036241  0.025738  0.027523  0.023490
# EasyTSF (NLinear)  0.062515  0.066464  0.055491  0.019240  0.020723  0.018215
# Gaussian Process   0.088800  0.084253  0.089359  0.031096  0.018580  0.019932
# Kernel Ridge       0.090663  0.138463  0.069621  0.065250  0.052138  0.048938
# LSTM               0.109547  0.051402  0.036461  0.034125  0.045632  0.049385
# S3-FastSketch      0.030604  0.025370  0.049342  0.020814  0.025027  0.025423
# S3-Forecaster      0.035185  0.029744  0.027063  0.025417  0.025875  0.028433
#
# history_size            97        108
# model_name
# AR                 0.037418  0.032334
# ARIMA              0.024764  0.025095
# ARKAN              0.086374  0.060519
# CNN                0.045915  0.041571
# Chronos            0.020943  0.020536
# ETS                0.022820  0.022481
# EasyTSF (NLinear)  0.017050  0.023186
# Gaussian Process   0.020170  0.018553
# Kernel Ridge       0.028431  0.021724
# LSTM               0.074130  0.075863
# S3-FastSketch      0.023891  0.020985
# S3-Forecaster      0.037544  0.038454
# MSIS pivot
# history_size            36        48        60        65        81        84   \
# model_name
# AR                 4.556209  2.032209  2.758727  1.696548  7.658677  7.299826
# ARIMA              2.898124  2.372297  1.668386  1.848417  1.547038  1.562477
# ARKAN              3.041387  3.511602  4.713101  6.192100  5.069668  5.049260
# CNN                4.559539  5.504341  9.361149  5.485970  4.773219  5.679046
# Chronos            3.489935  3.001044  2.520606  2.960833  4.244870  3.750081
# ETS                1.782916  2.841172  2.796138  2.502815  2.863201  2.807673
# EasyTSF (NLinear)  3.147591  3.686530  3.036451  2.095478  3.527610  2.757028
# Gaussian Process   3.441873  4.586550  5.106113  4.583173  5.387802  3.225108
# Kernel Ridge       5.651854  7.908746  4.723645  5.385086  3.649055  3.777754
# LSTM               4.483907  3.791435  3.241931  3.516910  2.479553  3.079741
# S3-FastSketch      1.547349  1.692708  3.594401  1.614621  1.379167  1.481411
# S3-Forecaster      3.378206  2.227758  1.960694  1.813790  1.925205  1.990294
#
# history_size            97        108
# model_name
# AR                 2.820635  2.264767
# ARIMA              2.430865  2.280980
# ARKAN              9.175381  5.446940
# CNN                4.327729  4.005436
# Chronos            2.785665  2.076720
# ETS                2.645703  2.670650
# EasyTSF (NLinear)  2.727279  1.869619
# Gaussian Process   3.937624  3.766474
# Kernel Ridge       3.640657  2.734125
# LSTM               3.472081  3.426146
# S3-FastSketch      1.275979  1.247685
# S3-Forecaster      2.106662  1.919736
# (<Figure size 1300x700 with 1 Axes>,
#  <Axes: xlabel='Available history (N)', ylabel='MSIS'>)

# %% [markdown]
# # 14.MULTI-PRIOR ROBUSTNESS

# %%
# ============================================================
# CELL 8 — MULTI-PRIOR ROBUSTNESS
# Fixed model hyperparameters; no new HPO.
# ============================================================

try:
    import prophet  # noqa: F401
except ImportError:
    subprocess.run(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "-q",
            "prophet",
        ],
        check=True,
    )

import logging

logging.getLogger(
    "cmdstanpy"
).setLevel(logging.WARNING)

logging.getLogger(
    "prophet"
).setLevel(logging.WARNING)

prior_factories = {
    "Rolling": lambda: RollingPrior(
        window_size=int(
            S3_POINT_PARAMS[
                "foundation_window"
            ]
        )
    ),
    "ETS": lambda: ETSPrior(
        error="add",
        trend="add",
        seasonal="add",
        seasonal_periods=(
            SEASONAL_PERIOD
        ),
        damped_trend=True,
    ),
    "Prophet": lambda: ProphetPrior(
        yearly_seasonality=True,
        weekly_seasonality=False,
        daily_seasonality=False,
        seasonality_mode="additive",
        changepoint_prior_scale=0.05,
    ),
}

if RUN_CHRONOS_PRIOR:
    prior_factories["Chronos"] = lambda: ChronosPrior(**CHRONOS_KWARGS)

multi_prior = run_multi_prior_robustness(
    train_series=train_series,
    test_series=test_series,
    prior_factories=prior_factories,
    s3_params=S3_POINT_PARAMS,
    fastsketch_params=(
        FASTSKETCH_POINT_PARAMS
    ),
    s3_uq=S3_UQ_PARAMS,
    fastsketch_uq=(
        FASTSKETCH_UQ_PARAMS
    ),
    include_prior_only=True,
    alpha=ALPHA,
    seasonal_period=SEASONAL_PERIOD,
)

multi_prior_summary = (
    multi_prior["summary"]
)

print("Multi-prior robustness results")
display(multi_prior_summary)

multi_prior_summary.to_csv(
    OUTPUT_DIR
    / "cif_multi_prior_robustness.csv",
    index=False,
)
# Out:
# 20:30:45 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:45 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:46 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:46 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:47 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:47 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:47 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:47 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:47 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:47 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:47 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:47 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:47 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:47 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:47 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:48 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:49 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:49 - cmdstanpy - INFO - Chain [1] done processing
# 20:30:49 - cmdstanpy - INFO - Chain [1] start processing
# 20:30:49 - cmdstanpy - INFO - Chain [1] done processing
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/143 [00:00<?, ?it/s]
# Multi-prior robustness results
#       prior          model status error       mae       mse      rmse  \
# 0   Chronos     Prior-only     ok  None  0.017090  0.000422  0.020536
# 1   Chronos  S3-FastSketch     ok  None  0.018016  0.000410  0.020255
# 2   Chronos  S3-Forecaster     ok  None  0.016723  0.000391  0.019770
# 3       ETS     Prior-only     ok  None  0.018161  0.000505  0.022481
# 4       ETS  S3-FastSketch     ok  None  0.018530  0.000519  0.022773
# 5       ETS  S3-Forecaster     ok  None  0.017397  0.000482  0.021949
# 6   Prophet     Prior-only     ok  None  0.015567  0.000258  0.016074
# 7   Prophet  S3-FastSketch     ok  None  0.017155  0.000304  0.017423
# 8   Prophet  S3-Forecaster     ok  None  0.015595  0.000259  0.016103
# 9   Rolling     Prior-only     ok  None  0.027259  0.000964  0.031041
# 10  Rolling  S3-FastSketch     ok  None  0.038330  0.001907  0.043665
# 11  Rolling  S3-Forecaster     ok  None  0.032958  0.001479  0.038454
#
#           r2  mape_percent      mape  ...       ecp  coverage_error        iw  \
# 0   0.189060      0.230288  0.002303  ...       NaN             NaN       NaN
# 1   0.211115      0.242975  0.002430  ...  1.000000        0.100000  0.162528
# 2   0.248434      0.225439  0.002254  ...  1.000000        0.100000  0.130942
# 3   0.028154      0.244572  0.002446  ...       NaN             NaN       NaN
# 4   0.002782      0.249534  0.002495  ...  1.000000        0.100000  0.172645
# 5   0.073589      0.234298  0.002343  ...  1.000000        0.100000  0.120048
# 6   0.503195      0.209888  0.002099  ...       NaN             NaN       NaN
# 7   0.416270      0.231247  0.002312  ...  1.000000        0.100000  0.154947
# 8   0.501378      0.210265  0.002103  ...  1.000000        0.100000  0.109802
# 9  -0.852795      0.366928  0.003669  ...       NaN             NaN       NaN
# 10 -2.666252      0.517003  0.005170  ...  1.000000        0.100000  0.188632
# 11 -1.843427      0.444923  0.004449  ...  0.916667        0.016667  0.125998
#
#     mean_width       mis  interval_score      msis    scale  elapsed_seconds  \
# 0          NaN       NaN             NaN       NaN      NaN         4.518306
# 1     0.162528  0.162528        0.162528  2.215175  0.07337        50.156317
# 2     0.130942  0.130942        0.130942  1.784674  0.07337         9.938471
# 3          NaN       NaN             NaN       NaN      NaN         0.126340
# 4     0.172645  0.172645        0.172645  2.353056  0.07337         2.402338
# 5     0.120048  0.120048        0.120048  1.636197  0.07337         0.519612
# 6          NaN       NaN             NaN       NaN      NaN         2.505538
# 7     0.154947  0.154947        0.154947  2.111852  0.07337         1.982797
# 8     0.109802  0.109802        0.109802  1.496549  0.07337         0.945525
# 9          NaN       NaN             NaN       NaN      NaN         0.003215
# 10    0.188632  0.188632        0.188632  2.570958  0.07337         0.216805
# 11    0.125998  0.140852        0.140852  1.919736  0.07337         0.063231
#
#     trainable_params
# 0                  0
# 1                 24
# 2                554
# 3                  0
# 4                 24
# 5                554
# 6                  0
# 7                 24
# 8                554
# 9                  0
# 10                24
# 11               554
#
# [12 rows x 22 columns]

# %%
# ============================================================
# CELL 9 — MULTI-PRIOR TABLES AND FIGURES
# ============================================================

def plot_multi_prior_metric(
    summary,
    metric,
    *,
    figsize=(12, 6),
):
    valid = summary[
        (summary["status"] == "ok")
        & summary[metric].notna()
        & np.isfinite(summary[metric])
    ].copy()

    pivot = valid.pivot_table(
        index="prior",
        columns="model",
        values=metric,
        aggfunc="first",
    )

    fig, ax = plt.subplots(
        figsize=figsize
    )

    pivot.plot(
        kind="bar",
        ax=ax,
    )

    ax.set_xlabel(
        "Foundation prior",
        fontsize=14,
    )

    ax.set_ylabel(
        metric.replace("_", " ").upper(),
        fontsize=14,
    )

    ax.tick_params(
        axis="both",
        labelsize=12,
    )

    ax.legend(
        title="Model",
        fontsize=11,
    )

    fig.tight_layout()
    plt.show()

    return pivot, fig, ax


multi_prior_mape, _, _ = (
    plot_multi_prior_metric(
        multi_prior_summary,
        "mape_percent",
    )
)

multi_prior_rmse, _, _ = (
    plot_multi_prior_metric(
        multi_prior_summary,
        "rmse",
    )
)

multi_prior_msis, _, _ = (
    plot_multi_prior_metric(
        multi_prior_summary,
        "msis",
    )
)

multi_prior_mape.to_csv(
    OUTPUT_DIR
    / "cif_multi_prior_mape_pivot.csv"
)

multi_prior_rmse.to_csv(
    OUTPUT_DIR
    / "cif_multi_prior_rmse_pivot.csv"
)

multi_prior_msis.to_csv(
    OUTPUT_DIR
    / "cif_multi_prior_msis_pivot.csv"
)

print("Saved analysis files:")

for path in sorted(
    OUTPUT_DIR.glob("cif_*")
):
    print(path.name)
# Out:
# Saved analysis files:
# cif_data_efficiency_all_models_cpu.csv
# cif_data_efficiency_mape_pivot.csv
# cif_data_efficiency_msis_pivot.csv
# cif_data_efficiency_rmse_pivot.csv
# cif_fastsketch_ablation.csv
# cif_multi_prior_mape_pivot.csv
# cif_multi_prior_msis_pivot.csv
# cif_multi_prior_rmse_pivot.csv
# cif_multi_prior_robustness.csv
# cif_s3_ablation.csv
# cif_shock_details_ar.csv
# cif_shock_details_arima.csv
# cif_shock_details_arkan.csv
# cif_shock_details_chronos.csv
# cif_shock_details_cnn.csv
# cif_shock_details_easytsf_nlinear.csv
# cif_shock_details_ets.csv
# cif_shock_details_gaussian_process.csv
# cif_shock_details_kernel_ridge.csv
# cif_shock_details_lstm.csv
# cif_shock_details_s3_fastsketch.csv
# cif_shock_details_s3_forecaster.csv
# cif_shock_mape_pivot.csv
# cif_shock_msis_pivot.csv
# cif_shock_nonshock_failures.csv
# cif_shock_nonshock_summary.csv
# cif_shock_rmse_pivot.csv

# %% [markdown]
# ## 15. Forecast plots

# %%
def plot_forecast(model_name, history_points=60):
    frame = original_forecasts[model_name]
    fig, ax = plt.subplots(figsize=(12, 4))
    ax.plot(raw_train.index[-history_points:], raw_train.iloc[-history_points:], label="Train")
    ax.plot(raw_test.index, raw_test, label="Observed test")
    ax.plot(frame.index, frame["pred"], label=model_name)
    if {"lower", "upper"}.issubset(frame.columns):
        ax.fill_between(frame.index, frame["lower"], frame["upper"], alpha=0.20, label="90% interval")
    ax.set_xlabel("Time")
    ax.set_ylabel("Original CIF Monthly scale")
    ax.legend()
    fig.tight_layout()
    plt.show()


plot_forecast("S3-Forecaster")
plot_forecast("S3-FastSketch")

# %% [markdown]
# ## 16. Residual analysis of the proposed approaches

# %%
residual_rows = []
residual_reports = {}

for model_name in ("S3-Forecaster", "S3-FastSketch"):
    forecast = original_forecasts[model_name]
    report = analyze_forecast_residuals(
        raw_test,
        forecast["pred"],
        seasonal_period=SEASONAL_PERIOD,
        alpha=0.05,
    )
    residual_reports[model_name] = report
    diagnostics = report["diagnostics"]
    residual_rows.append(
        {
            "Model": model_name,
            "Residual mean": diagnostics["mean"],
            "Residual std": diagnostics["std"],
            "Skewness": diagnostics["skewness"],
            "Excess kurtosis": diagnostics["excess_kurtosis"],
            "Seasonal ACF": diagnostics["seasonal_acf"],
            "Ljung-Box independence not rejected": diagnostics["serial_independence_not_rejected_all"],
            "Normality not rejected by all tests": diagnostics["normality_not_rejected_all"],
        }
    )

residual_summary = pd.DataFrame(residual_rows)
display(residual_summary)

# Publication-oriented diagnostic figures for the best proposed model by MAPE.
best_proposed = (
    original_scale_results[
        original_scale_results["Model"].isin(["S3-Forecaster", "S3-FastSketch"])
    ]
    .sort_values("MAPE (%)")
    .iloc[0]["Model"]
)
print("Residual figures for:", best_proposed)
figures = plot_residual_diagnostics(
    residual_reports[best_proposed]["residuals"],
    fitted=original_forecasts[best_proposed]["pred"],
    seasonal_period=SEASONAL_PERIOD,
)
plt.show()
# Out:
#            Model  Residual mean  Residual std  Skewness  Excess kurtosis  \
# 0  S3-Forecaster     -54.871146     35.499200 -0.141702        -0.261152
# 1  S3-FastSketch      18.266648     30.855813  0.167407        -1.267530
#
#    Seasonal ACF  Ljung-Box independence not rejected  \
# 0           NaN                                 True
# 1           NaN                                 True
#
#    Normality not rejected by all tests
# 0                                 True
# 1                                 True
# Residual figures for: S3-FastSketch

# %% [markdown]
# ## 17. Export all reproducible outputs

# %%
def json_ready(value):
    if isinstance(value, dict):
        return {str(key): json_ready(item) for key, item in value.items()}
    if isinstance(value, (list, tuple)):
        return [json_ready(item) for item in value]
    if isinstance(value, np.generic):
        return value.item()
    return value


model_scale_results.to_csv(OUTPUT_DIR / "cif_results_model_scale.csv", index=False)
original_scale_results.to_csv(OUTPUT_DIR / "cif_results_original_scale.csv", index=False)
residual_summary.to_csv(OUTPUT_DIR / "cif_residual_summary.csv", index=False)
pd.DataFrame(baseline_failures).to_csv(OUTPUT_DIR / "cif_baseline_failures.csv", index=False)

for model_name, frame in original_forecasts.items():
    safe_name = model_name.lower().replace(" ", "_").replace("(", "").replace(")", "")
    frame.to_csv(OUTPUT_DIR / f"forecast_{safe_name}.csv")

with open(OUTPUT_DIR / "s3_best_params.json", "w", encoding="utf-8") as file:
    json.dump(
        json_ready({
            "point": s3_result["best_point_params"],
            "uq": s3_result["best_uq_params"],
        }),
        file,
        indent=2,
    )

with open(OUTPUT_DIR / "fastsketch_best_params.json", "w", encoding="utf-8") as file:
    json.dump(
        json_ready({
            "point": fastsketch_result["best_point_params"],
            "uq": fastsketch_result["best_uq_params"],
        }),
        file,
        indent=2,
    )

with open(OUTPUT_DIR / "fixed_baseline_params_original.json", "w", encoding="utf-8") as file:
    json.dump(json_ready(BASELINE_PARAMS_ORIGINAL), file, indent=2)

s3_result["point_study"].trials_dataframe().to_csv(OUTPUT_DIR / "s3_point_trials.csv", index=False)
s3_result["uq_study"].trials_dataframe().to_csv(OUTPUT_DIR / "s3_uq_trials.csv", index=False)
fastsketch_result["point_study"].trials_dataframe().to_csv(OUTPUT_DIR / "fastsketch_point_trials.csv", index=False)
fastsketch_result["uq_study"].trials_dataframe().to_csv(OUTPUT_DIR / "fastsketch_uq_trials.csv", index=False)

print("Saved files:")
for path in sorted(OUTPUT_DIR.iterdir()):
    print(path.name)
# Out:
# Saved files:
# cif_baseline_failures.csv
# cif_data_efficiency_all_models_cpu.csv
# cif_data_efficiency_mape_pivot.csv
# cif_data_efficiency_msis_pivot.csv
# cif_data_efficiency_rmse_pivot.csv
# cif_fastsketch_ablation.csv
# cif_multi_prior_mape_pivot.csv
# cif_multi_prior_msis_pivot.csv
# cif_multi_prior_rmse_pivot.csv
# cif_multi_prior_robustness.csv
# cif_residual_summary.csv
# cif_results_model_scale.csv
# cif_results_original_scale.csv
# cif_s3_ablation.csv
# cif_shock_details_ar.csv
# cif_shock_details_arima.csv
# cif_shock_details_arkan.csv
# cif_shock_details_chronos.csv
# cif_shock_details_cnn.csv
# cif_shock_details_easytsf_nlinear.csv
# cif_shock_details_ets.csv
# cif_shock_details_gaussian_process.csv
# cif_shock_details_kernel_ridge.csv
# cif_shock_details_lstm.csv
# cif_shock_details_s3_fastsketch.csv
# cif_shock_details_s3_forecaster.csv
# cif_shock_mape_pivot.csv
# cif_shock_msis_pivot.csv
# cif_shock_nonshock_failures.csv
# cif_shock_nonshock_summary.csv
# cif_shock_rmse_pivot.csv
# fastsketch_best_params.json
# fastsketch_point_trials.csv
# fastsketch_uq_trials.csv
# fixed_baseline_params_original.json
# forecast_ar.csv
# forecast_arima.csv
# forecast_arkan.csv
# forecast_chronos.csv
# forecast_cnn.csv
# forecast_easytsf_nlinear.csv
# forecast_ets.csv
# forecast_gaussian_process.csv
# forecast_kernel_ridge.csv
# forecast_lstm.csv
# forecast_s3-fastsketch.csv
# forecast_s3-forecaster.csv
# s3_best_params.json
# s3_point_trials.csv
# s3_uq_trials.csv

# %% [markdown]
# ## Notebook scope
#
# This notebook contains the same complete sequence of experiments as the final M4 notebook:
#
# 1. proposed-model point and uncertainty optimization;
# 2. fixed-parameter baseline evaluation on CPU;
# 3. consolidated point and interval metrics;
# 4. S3-Forecaster and S3-FastSketch ablation studies;
# 5. shock versus non-shock analysis;
# 6. data-efficiency curves;
# 7. multi-prior robustness;
# 8. forecast and residual figures;
# 9. export of all tables, forecasts, trials, and parameters.
#
# The dataset-specific components are limited to loading, temporal indexing, series selection, and the fixed baseline parameters reported by the original **CIF Monthly** notebook.
